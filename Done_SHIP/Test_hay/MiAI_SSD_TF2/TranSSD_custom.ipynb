# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 86622, done.
# remote: Counting objects: 100% (376/376), done.
# remote: Compressing objects: 100% (214/214), done.
# remote: Total 86622 (delta 173), reused 357 (delta 158), pack-reused 86246
# Receiving objects: 100% (86622/86622), 598.82 MiB | 7.54 MiB/s, done.
# Resolving deltas: 100% (62055/62055), done.
# Updating files: 100% (3545/3545), done.

# %%
# !pwd
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research

# %%
# 5. Compile the protos -  
# Protocol Buffers (Protobuf) is a free and open-source cross-platform data format used to serialize structured data.
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research

# %%
# 6. Cài dặt API
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
# !cp object_detection/packages/tf2/setup.py . 
# !python -m pip install .
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
# Processing /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696991 sha256=d6806d56cab96c18f0e4eeb5b5082c09e1676f49d1a453af767feb84d1f27884
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7fgpocxx/wheels/a0/2e/54/65bcb2c823dc3ab23a2971481c211789442e5d6bf240215dab
# Successfully built object-detection
# ...
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# ...

# %%
# !pip install protobuf==3.20.3
# Out:
# ...
#   Using cached protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.4
#     Uninstalling protobuf-4.23.4:
#       Successfully uninstalled protobuf-4.23.4
# ...

# %%
# 7. Test API
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
# 2023-07-15 21:54:18.776624: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/skm/anaconda3/envs/tensorflow2/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/skm/anaconda3/envs/tensorflow2/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/skm/anaconda3/envs/tensorflow2/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
# !pwd
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research

# %%
# 8. CSV to TFRecord. With help from MiAI git hub
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
# !git clone https://github.com/thangnch/MiAI_SSD_TF2
# !cp MiAI_SSD_TF2/generate_tfrecord.py .
# !cp MiAI_SSD_TF2/label_map.txt /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/data

import os
if not os.path.exists("/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/"):
  os.mkdir("/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/")

# !python generate_tfrecord.py --image_dir=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/train --csv_input=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/train_labels.csv --output_path=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/train.record 
# !python generate_tfrecord.py --image_dir=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/test --csv_input=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/test_labels.csv --output_path=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/test.record
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
# 2023-07-15 00:57:19.912835: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Successfully created the TFRecords: /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/data/tfrecord_data/train.record
# 2023-07-15 00:57:25.869997: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Successfully created the TFRecords: /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/data/tfrecord_data/test.record

# %%
# 9. Download pretrain and config
import os
if not os.path.exists("/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/pretrained"):
  os.mkdir("/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/pretrained")

# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/pretrained
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Unzip
# !tar -xzvf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz

# Config pipeline.config, label_map.txt if needed
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/pretrained
# --2023-07-15 00:58:52--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.199.80, 2404:6800:4005:80b::2010
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.199.80|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19,56M  9,29MB/s    in 2,1s
#
# 2023-07-15 00:58:55 (9,29 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ...

# %%
# Upload label file object-detection.txt to data folder
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models
# !pip install -r /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research/MiAI_SSD_TF2/setup.txt
# !pip install --upgrade opencv-python
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models
# ...
#   Using cached tensorflow-2.13.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (524.1 MB)
# ...
#   Using cached tensorflow_io-0.32.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.0 MB)
# ...
#   Using cached tensorflow_addons-0.21.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
# ...
#   Using cached tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# ...
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# ...
#   Using cached lvis-0.5.3-py3-none-any.whl (14 kB)
# ...
#   Using cached gin_config-0.5.0-py3-none-any.whl (61 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached libclang-16.0.0-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
# ...
#   Using cached wrapt-1.15.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
# ...
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# ...

# %% [markdown]
# # Cai nay fix loi thu vien no k tim dk 1 so goi cua keras

# %%
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.8 #khong dk, phai chay dk cuda 11.8
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %%
# Train
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
# %cp /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research/object_detection/model_main_tf2.py .

#train 
# !python model_main_tf2.py \
--pipeline_config_path=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/pretrained/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config \
--model_dir=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/output_model --alsologtostderr --num_train_steps=1000
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/research
# 2023-07-15 23:14:56.854503: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/skm/anaconda3/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/skm/anaconda3/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/skm/anaconda3/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
# !pip install -r /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MiAI_SSD_TF2/models/official/requirements.txt

# %%
a = ["sudo apt-get --purge remove cuda-cccl-12-2                  -y",
"sudo apt-get --purge remove cuda-command-line-tools-12-2    -y",
"sudo apt-get --purge remove cuda-compiler-12-2              -y",
"sudo apt-get --purge remove cuda-cudart-11-4                -y",
"sudo apt-get --purge remove cuda-cudart-12-2                -y",
"sudo apt-get --purge remove cuda-cudart-dev-12-2            -y",
"sudo apt-get --purge remove cuda-cuobjdump-11-4             -y",
"sudo apt-get --purge remove cuda-cuobjdump-12-2             -y",
"sudo apt-get --purge remove cuda-cupti-12-2                 -y",
"sudo apt-get --purge remove cuda-cupti-dev-12-2             -y",
"sudo apt-get --purge remove cuda-cuxxfilt-11-4              -y",
"sudo apt-get --purge remove cuda-cuxxfilt-12-2              -y",
"sudo apt-get --purge remove cuda-demo-suite-12-2            -y",
"sudo apt-get --purge remove cuda-documentation-12-2         -y",
"sudo apt-get --purge remove cuda-driver-dev-11-4            -y",
"sudo apt-get --purge remove cuda-driver-dev-12-2            -y",
"sudo apt-get --purge remove cuda-drivers                    -y",
"sudo apt-get --purge remove cuda-drivers-535                -y",
"sudo apt-get --purge remove cuda-gdb-11-4                   -y",
"sudo apt-get --purge remove cuda-gdb-12-2                   -y",
"sudo apt-get --purge remove cuda-keyring                    -y",
"sudo apt-get --purge remove cuda-libraries-11-4             -y",
"sudo apt-get --purge remove cuda-libraries-12-2             -y",
"sudo apt-get --purge remove cuda-libraries-dev-12-2         -y",
"sudo apt-get --purge remove cuda-memcheck-11-4              -y",
"sudo apt-get --purge remove cuda-nsight-11-4                -y",
"sudo apt-get --purge remove cuda-nsight-12-2                -y",
"sudo apt-get --purge remove cuda-nsight-compute-11-4        -y",
"sudo apt-get --purge remove cuda-nsight-compute-12-2        -y",
"sudo apt-get --purge remove cuda-nsight-systems-11-4        -y",
"sudo apt-get --purge remove cuda-nsight-systems-12-2        -y",
"sudo apt-get --purge remove cuda-nvcc-12-2                  -y",
"sudo apt-get --purge remove cuda-nvdisasm-11-4              -y",
"sudo apt-get --purge remove cuda-nvdisasm-12-2              -y",
"sudo apt-get --purge remove cuda-nvml-dev-11-4              -y",
"sudo apt-get --purge remove cuda-nvml-dev-12-2              -y",
"sudo apt-get --purge remove cuda-nvprof-11-4                -y",
"sudo apt-get --purge remove cuda-nvprof-12-2                -y",
"sudo apt-get --purge remove cuda-nvprune-11-4               -y",
"sudo apt-get --purge remove cuda-nvprune-12-2               -y",
"sudo apt-get --purge remove cuda-nvrtc-11-4                 -y",
"sudo apt-get --purge remove cuda-nvrtc-12-2                 -y",
"sudo apt-get --purge remove cuda-nvrtc-dev-11-4             -y",
"sudo apt-get --purge remove cuda-nvrtc-dev-12-2             -y",
"sudo apt-get --purge remove cuda-nvtx-11-4                  -y",
"sudo apt-get --purge remove cuda-nvtx-12-2                  -y",
"sudo apt-get --purge remove cuda-nvvp-11-4                  -y",
"sudo apt-get --purge remove cuda-nvvp-12-2                  -y",
"sudo apt-get --purge remove cuda-opencl-12-2                -y",
"sudo apt-get --purge remove cuda-opencl-dev-12-2            -y",
"sudo apt-get --purge remove cuda-profiler-api-12-2          -y",
"sudo apt-get --purge remove cuda-repo-ubuntu2004-11-2-local -y",
"sudo apt-get --purge remove cuda-repo-ubuntu2004-11-8-local -y",
"sudo apt-get --purge remove cuda-runtime-12-2               -y",
"sudo apt-get --purge remove cuda-sanitizer-11-4             -y",
"sudo apt-get --purge remove cuda-sanitizer-12-2             -y",
"sudo apt-get --purge remove cuda-toolkit-11-4-config-common -y",
"sudo apt-get --purge remove cuda-toolkit-11-config-common   -y",
"sudo apt-get --purge remove cuda-toolkit-12-2               -y",
"sudo apt-get --purge remove cuda-toolkit-12-2-config-common -y",
"sudo apt-get --purge remove cuda-toolkit-12-config-common   -y",
"sudo apt-get --purge remove cuda-toolkit-config-common      -y",
"sudo apt-get --purge remove cuda-tools-12-2                 -y",
"sudo apt-get --purge remove cuda-visual-tools-12-2          -y",
"sudo apt-get --purge remove libcudart10.1:amd64             -y",
"sudo apt-get --purge remove nvidia-cuda-dev                 -y",
"sudo apt-get --purge remove nvidia-cuda-doc                 -y"]

# %%
from getpass import getpass
import subprocess

password = getpass("Enter your password: ")
for command in a:
    sudo_command = f'echo {password} | sudo -S {command}'

    subprocess.run(sudo_command, shell=True, executable="/bin/bash")
