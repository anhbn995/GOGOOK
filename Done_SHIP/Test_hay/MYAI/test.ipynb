# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 86672, done.
# remote: Counting objects: 100% (426/426), done.
# remote: Compressing objects: 100% (211/211), done.
# remote: Total 86672 (delta 214), reused 414 (delta 210), pack-reused 86246
# Receiving objects: 100% (86672/86672), 598.83 MiB | 9.05 MiB/s, done.
# Resolving deltas: 100% (62088/62088), done.
# Updating files: 100% (3558/3558), done.

# %%
# !pwd
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI

# %%
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research

# %%
# 6. Cài dặt API
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
# !cp object_detection/packages/tf2/setup.py . 
# !python -m pip install .
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
# Processing /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696991 sha256=18ce5e49abe4982114f03dee142461c27a8d5ffaf1b94ea7eade8478fd2a5770
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4s255gsb/wheels/57/87/a4/d4f289f12a845598d1a39f245b7f9bb90ccedb0b25fd43491e
# Successfully built object-detection
# ...
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# ...

# %%
# !pip install protobuf==3.20.3

# %%
# 7. Test API
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# 2023-07-17 01:06:02.813903: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
# 8. CSV to TFRecord. With help from MiAI git hub
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
# !git clone https://github.com/thangnch/MiAI_SSD_TF2
# !cp MiAI_SSD_TF2/generate_tfrecord.py .
# !cp MiAI_SSD_TF2/label_map.txt /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/data

import os
os.makedirs(r"/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data/tf_records", exist_ok=True)

# !python generate_tfrecord.py --image_dir=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data/split_data/train --csv_input=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data/split_data/train_labels.csv --output_path=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data/tf_records/train.record 
# !python generate_tfrecord.py --image_dir=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data/split_data/test --csv_input=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data/split_data/test_labels.csv --output_path=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data/tf_records/test.record
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
# 2023-07-16 01:04:32.971468: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Successfully created the TFRecords: /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/data/tfrecord_data/train.record
# 2023-07-16 01:04:38.867645: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Successfully created the TFRecords: /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/data/tfrecord_data/test.record

# %%
# 9. Download pretrain and config
import os
if not os.path.exists("/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/pretrained"):
  os.mkdir("/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/pretrained")

# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/pretrained
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Unzip
# !tar -xzvf ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz

# Config pipeline.config, label_map.txt if needed
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/pretrained
# --2023-07-17 01:37:35--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.199.80, 2404:6800:4005:80b::2010
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.199.80|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244817203 (233M) [application/x-tar]
# Saving to: ‘ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’
#
# ssd_resnet50_v1_fpn 100%[===================>] 233,48M  11,1MB/s    in 22s
#
# 2023-07-17 01:37:57 (10,6 MB/s) - ‘ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’ saved [244817203/244817203]
#
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ...

# %%
# Upload label file object-detection.txt to data folder
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models
# !pip install -r /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research/MiAI_SSD_TF2/setup.txt
# !pip install --upgrade opencv-python
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models
# ...

# %%
# Train
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
# %cp /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research/object_detection/model_main_tf2.py .

#train 
# !python model_main_tf2.py \
--pipeline_config_path=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/pretrained/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config \
--model_dir=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu_640 --alsologtostderr --num_train_steps=30000
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
# 2023-07-17 11:29:11.907793: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
128/26

640/128
# Out:
# 5.0

# %%
# Export model
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
# %cp /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research/object_detection/exporter_main_v2.py .

# !python exporter_main_v2.py \
--trained_checkpoint_dir=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu_640 \
--pipeline_config_path=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/pretrained/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config \
--output_directory=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/export_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu_640
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
# 2023-07-17 13:55:54.811380: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
import io
import os
import scipy.misc
import numpy as np
import six
import time
import glob
from IPython.display import display

from six import BytesIO

import matplotlib
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont

import tensorflow as tf
from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util

#Load model
tf.keras.backend.clear_session()
model = tf.saved_model.load("/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/export_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu_640a/saved_model")

# %%
# Out:
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.33' not found (required by /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorboard_data_server/bin/server)
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.34' not found (required by /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorboard_data_server/bin/server)
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.32' not found (required by /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorboard_data_server/bin/server)
# 'http://localhost:6006/'
# WARNING:tensorflow:FailedPreconditionError: /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/export_model/checkpoint; Is a directory
# ...

# %%
# Các hàm inference

import cv2
def run_inference_for_single_image(model, image):
  
  image = np.asarray(image)
  input_tensor = tf.convert_to_tensor(image)
  input_tensor = input_tensor[tf.newaxis,...]

  model_fn = model.signatures['serving_default']
  output_dict = model_fn(input_tensor)

  num_detections = int(output_dict.pop('num_detections'))
  output_dict = {key:value[0, :num_detections].numpy() 
                 for key,value in output_dict.items()}
  output_dict['num_detections'] = num_detections
  output_dict['detection_classes'] = output_dict['detection_classes'].astype(np.int64)
   
  if 'detection_masks' in output_dict:
    detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
              output_dict['detection_masks'], output_dict['detection_boxes'],
               image.shape[0], image.shape[1])      
    detection_masks_reframed = tf.cast(detection_masks_reframed > 0.5,
                                       tf.uint8)
    output_dict['detection_masks_reframed'] = detection_masks_reframed.numpy()
    
  return output_dict

def load_image_into_numpy_array(path):
  img_data = tf.io.gfile.GFile(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %%
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
category_index = label_map_util.create_category_index_from_labelmap("/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/data/label_map.txt", use_display_name=True)
import cv2
# image_path = '/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/data/split_data/test/DaNang_23_07_2009_LowAccuracy_1_4413.jpg'
import random
TEST_IMAGE_PATHS = glob.glob('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/data/split_data/test/*.jpg')
image_path = random.choice(TEST_IMAGE_PATHS)
a = 1
image_np = load_image_into_numpy_array(image_path)
print(f"Done load image with shape :{image_np.shape}")
image_np = cv2.resize(image_np, dsize=None, fx=a, fy=a)
output_dict = run_inference_for_single_image(model, image_np)
# print(output_dict)
# print(f"Done inference with shape :{output_dict['detection_boxes'],}")
vis_util.visualize_boxes_and_labels_on_image_array(
    image_np,
    output_dict['detection_boxes'],
    output_dict['detection_classes'],
    output_dict['detection_scores'],
    category_index,
    instance_masks=output_dict.get('detection_masks_reframed', None),
    use_normalized_coordinates=True,
    line_thickness=1)
print("Done draw on image ")
display(Image.fromarray(image_np))
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/models/research
# Done load image with shape :(128, 128, 3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 12
#      10 print(f"Done load image with shape :{image_np.shape}")
#      11 image_np = cv2.resize(image_np, dsize=None, fx=a, fy=a)
# ---> 12 output_dict = run_inference_for_single_image(model, image_np)
#      13 # print(output_dict)
#      14 # print(f"Done inference with shape :{output_dict['detection_boxes'],}")
#      15 vis_util.visualize_boxes_and_labels_on_image_array(
#      16     image_np,
#      17     output_dict['detection_boxes'],
#    (...)
#      22     use_normalized_coordinates=True,
#      23     line_thickness=1)
#
# NameError: name 'run_inference_for_single_image' is not defined

# %% [markdown]
# ## Khac

# %%
def plot_detections(image_np,
                    boxes,
                    classes,
                    scores,
                    category_index,
                    figsize=(12, 16),
                    image_name=None):
  """Wrapper function to visualize detections.
  Args:
    image_np: uint8 numpy array with shape (img_height, img_width, 3)
    boxes: a numpy array of shape [N, 4]
    classes: a numpy array of shape [N]. Note that class indices are 1-based,
      and match the keys in the label map.
    scores: a numpy array of shape [N] or None.  If scores=None, then
      this function assumes that the boxes to be plotted are groundtruth
      boxes and plot all boxes as black with no classes or scores.
    category_index: a dict containing category dictionaries (each holding
      category index `id` and category name `name`) keyed by category indices.
    figsize: size for the figure.
    image_name: a name for the image file.
  """
  image_np_with_annotations = image_np.copy()
  viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_annotations,
      boxes,
      classes,
      scores,
      category_index,
      use_normalized_coordinates=True,
      min_score_thresh=0.8)
  if image_name:
    plt.imsave(image_name, image_np_with_annotations)
  else:
    plt.imshow(image_np_with_annotations)

# %%
import pathlib
from object_detection.utils import config_util
from object_detection.builders import model_builder

pipeline_file = r'/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/pretrained/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config'
filenames = list(pathlib.Path('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu/').glob('*.index'))

filenames.sort()
print(filenames)

#recover our saved model
model_dir = '/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu/'
#generally you want to put the last ckpt from training in here
configs = config_util.get_configs_from_pipeline_file(pipeline_file)
model_config = configs['model']
detection_model = model_builder.build(
      model_config=model_config, is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(
      model=detection_model)
ckpt.restore(os.path.join(str(filenames[-1]).replace('.index','')))


def get_model_detection_function(model):
  """Get a tf.function for detection."""

  @tf.function
  def detect_fn(image):
    """Detect objects in image."""

    image, shapes = model.preprocess(image)
    prediction_dict = model.predict(image, shapes)
    detections = model.postprocess(prediction_dict, shapes)

    return detections, prediction_dict, tf.reshape(shapes, [-1])

  return detect_fn

detect_fn = get_model_detection_function(detection_model)
# Out:
# [PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu/ckpt-25.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu/ckpt-26.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu/ckpt-27.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu/ckpt-28.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu/ckpt-29.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu/ckpt-30.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/output_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu/ckpt-31.index')]

# %%
#map labels for inference decoding
label_map_path = configs['eval_input_config'].label_map_path
label_map = label_map_util.load_labelmap(label_map_path)
categories = label_map_util.convert_label_map_to_categories(
    label_map,
    max_num_classes=label_map_util.get_max_label_map_index(label_map),
    use_display_name=True)
category_index = label_map_util.create_category_index(categories)
label_map_dict = label_map_util.get_label_map_dict(label_map, use_display_name=True)

# %%
import numpy as np
from six import BytesIO
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings
import os, glob

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder

tf.get_logger().setLevel('ERROR')           # Suppress TensorFlow logging (2)


PATH_TO_CFG = r'/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/pretrained/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config'
PATH_TO_CKPT = r'/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/export_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu_640a/checkpoint/'

# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(PATH_TO_CFG)
model_config = configs['model']
detection_model = model_builder.build(model_config=model_config, is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(
      model=detection_model)
ckpt.restore(os.path.join(PATH_TO_CKPT, 'ckpt-0')).expect_partial()


@tf.function
def detect_fn(image):
    """Detect objects in image."""

    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)

    return detections, prediction_dict, tf.reshape(shapes, [-1])

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.

    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.

    Args:
      path: the file path to the image

    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    img_data = tf.io.gfile.GFile(path, 'rb').read()
    image = Image.open(BytesIO(img_data))
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

from object_detection.utils import label_map_util
PATH_TO_LABELS = r'/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/MYAI/data/label_map.txt'
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)


import random
TEST_IMAGE_PATHS = glob.glob('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/data/split_data/test/*.jpg')
image_path = random.choice(TEST_IMAGE_PATHS)
# image_path 
for image_np in [random.choice(TEST_IMAGE_PATHS), random.choice(TEST_IMAGE_PATHS)]:
    image_np = load_image_into_numpy_array(image_path)

    # Things to try:
    # Flip horizontally
    # image_np = np.fliplr(image_np).copy()

    # Convert image to grayscale
    # image_np = np.tile(
    #     np.mean(image_np, 2, keepdims=True), (1, 1, 3)).astype(np.uint8)

    input_tensor = tf.convert_to_tensor(
        np.expand_dims(image_np, 0), dtype=tf.float32)
    detections, predictions_dict, shapes = detect_fn(input_tensor)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
          image_np_with_detections,
          detections['detection_boxes'][0].numpy(),
          (detections['detection_classes'][0].numpy() + label_id_offset).astype(int),
          detections['detection_scores'][0].numpy(),
          category_index,
          use_normalized_coordinates=True,
          max_boxes_to_draw=200,
          min_score_thresh=.30,
          agnostic_mode=False)

    plt.figure()
    plt.imshow(image_np_with_detections)
# print('Done')
plt.show()
