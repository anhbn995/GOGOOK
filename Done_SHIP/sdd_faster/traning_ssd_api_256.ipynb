# %% [markdown]
# Tai bo phat hien doi tuong cua tf2

# %% [markdown]
# # Thiet lap chuong trinh tren moi truong myai

# %%
import matplotlib
import matplotlib.pyplot as plt
import os
import random
import io
import imageio
import glob
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage

import tensorflow as tf
# from google.colab import files
import pathlib
import itertools
import random

from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

from object_detection.utils import config_util
# from object_detection.utils import colab_utils
from object_detection.builders import model_builder
# %matplotlib inline
# Out:
# 2023-07-25 15:18:20.691870: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# ### Tai pretrain model vao dung cho dam bao jupyter dang o dung diem

# %%
import os
dir_pretrain = '/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/pretrain_model'
link_pretrain_model = "http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz"
os.makedirs(dir_pretrain, exist_ok=True)

# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/pretrain_model
# !pwd
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/pretrain_model
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/pretrain_model

# %%
import os
name_model = os.path.basename(link_pretrain_model)
file_will_download = os.path.join(dir_pretrain, name_model)

import wget
if os.path.isfile(os.path.join(dir_pretrain, name_model)):
    pass
else:
    model_link = link_pretrain_model
    wget.download(model_link)
    print('download done!')
    import tarfile
    tar = tarfile.open(os.path.join(dir_pretrain, name_model))
    tar.extractall('.') 
    tar.close()
    print('extract done!')
# Out:
# download done!
# extract done!

# %% [markdown]
# ## Luyen model

# %%
# !python /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/models/research/object_detection/model_main_tf2.py\
    --pipeline_config_path=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/pretrain_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline_256.config \
    --model_dir=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size \
    --alsologtostderr \
    # --num_train_steps=1000
# Out:
# 2023-07-24 19:09:00.136167: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# 2023-07-24 19:09:04.035075: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2977 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:05:00.0, compute capability: 6.1
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0724 19:09:04.038042 139687352496768 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0724 19:09:04.139407 139687352496768 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0724 19:09:04.139594 139687352496768 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0724 19:09:04.174305 139687352496768 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/train.record']
# I0724 19:09:04.186125 139687352496768 dataset_builder.py:162] Reading unweighted datasets: ['/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/train.record']
# I0724 19:09:04.186711 139687352496768 dataset_builder.py:79] Reading record datasets for input file: ['/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0724 19:09:04.186804 139687352496768 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0724 19:09:04.186885 139687352496768 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0724 19:09:04.196132 139687352496768 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0724 19:09:04.221060 139687352496768 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0724 19:09:13.512445 139687352496768 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0724 19:09:17.497193 139687352496768 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0724 19:09:19.862868 139687352496768 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0724 19:09:30.328932 139670432237312 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0724 19:09:42.047367 139670432237312 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# 2023-07-24 19:09:48.051853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:09:51.527579 139687352496768 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:09:51.531461 139687352496768 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:09:51.532979 139687352496768 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:09:51.534032 139687352496768 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:09:51.538623 139687352496768 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:09:51.539703 139687352496768 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:09:51.540815 139687352496768 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:09:51.541829 139687352496768 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:09:51.546234 139687352496768 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:09:51.547323 139687352496768 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0724 19:09:54.736949 139669333333760 deprecation.py:569] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0724 19:09:56.158938 139669333333760 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0724 19:10:04.468395 139669333333760 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0724 19:10:12.210401 139669333333760 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0724 19:10:19.835341 139669333333760 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# 2023-07-24 19:10:36.244597: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.29GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-07-24 19:10:36.307866: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# INFO:tensorflow:Step 100 per-step time 0.513s
# I0724 19:10:45.527205 139687352496768 model_lib_v2.py:705] Step 100 per-step time 0.513s
# INFO:tensorflow:{'Loss/classification_loss': 1.020894,
#  'Loss/localization_loss': 1.1282443,
#  'Loss/regularization_loss': 2.2840345,
#  'Loss/total_loss': 4.433173,
#  'learning_rate': 0.014666351}
# I0724 19:10:45.528028 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 1.020894,
#  'Loss/localization_loss': 1.1282443,
#  'Loss/regularization_loss': 2.2840345,
#  'Loss/total_loss': 4.433173,
#  'learning_rate': 0.014666351}
# INFO:tensorflow:Step 200 per-step time 0.089s
# I0724 19:10:54.408717 139687352496768 model_lib_v2.py:705] Step 200 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.9678307,
#  'Loss/localization_loss': 0.9275434,
#  'Loss/regularization_loss': 2.2773237,
#  'Loss/total_loss': 4.172698,
#  'learning_rate': 0.0159997}
# I0724 19:10:54.409701 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.9678307,
#  'Loss/localization_loss': 0.9275434,
#  'Loss/regularization_loss': 2.2773237,
#  'Loss/total_loss': 4.172698,
#  'learning_rate': 0.0159997}
# INFO:tensorflow:Step 300 per-step time 0.089s
# I0724 19:11:03.273698 139687352496768 model_lib_v2.py:705] Step 300 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.7777921,
#  'Loss/localization_loss': 0.71615314,
#  'Loss/regularization_loss': 2.2503495,
#  'Loss/total_loss': 3.7442946,
#  'learning_rate': 0.01733305}
# I0724 19:11:03.274666 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.7777921,
#  'Loss/localization_loss': 0.71615314,
#  'Loss/regularization_loss': 2.2503495,
#  'Loss/total_loss': 3.7442946,
#  'learning_rate': 0.01733305}
# INFO:tensorflow:Step 400 per-step time 0.090s
# I0724 19:11:12.224120 139687352496768 model_lib_v2.py:705] Step 400 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 1.340478,
#  'Loss/localization_loss': 1.0000604,
#  'Loss/regularization_loss': 2.2227583,
#  'Loss/total_loss': 4.563297,
#  'learning_rate': 0.0186664}
# I0724 19:11:12.224804 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 1.340478,
#  'Loss/localization_loss': 1.0000604,
#  'Loss/regularization_loss': 2.2227583,
#  'Loss/total_loss': 4.563297,
#  'learning_rate': 0.0186664}
# INFO:tensorflow:Step 500 per-step time 0.089s
# I0724 19:11:21.104729 139687352496768 model_lib_v2.py:705] Step 500 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.7611359,
#  'Loss/localization_loss': 0.99764395,
#  'Loss/regularization_loss': 2.205677,
#  'Loss/total_loss': 3.9644568,
#  'learning_rate': 0.01999975}
# I0724 19:11:21.105418 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.7611359,
#  'Loss/localization_loss': 0.99764395,
#  'Loss/regularization_loss': 2.205677,
#  'Loss/total_loss': 3.9644568,
#  'learning_rate': 0.01999975}
# INFO:tensorflow:Step 600 per-step time 0.089s
# I0724 19:11:30.025944 139687352496768 model_lib_v2.py:705] Step 600 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.99251515,
#  'Loss/localization_loss': 0.6973393,
#  'Loss/regularization_loss': 2.1714785,
#  'Loss/total_loss': 3.861333,
#  'learning_rate': 0.0213331}
# I0724 19:11:30.026352 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.99251515,
#  'Loss/localization_loss': 0.6973393,
#  'Loss/regularization_loss': 2.1714785,
#  'Loss/total_loss': 3.861333,
#  'learning_rate': 0.0213331}
# INFO:tensorflow:Step 700 per-step time 0.089s
# I0724 19:11:38.936358 139687352496768 model_lib_v2.py:705] Step 700 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.5238219,
#  'Loss/localization_loss': 0.49722356,
#  'Loss/regularization_loss': 2.1354737,
#  'Loss/total_loss': 3.1565192,
#  'learning_rate': 0.02266645}
# I0724 19:11:38.937009 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.5238219,
#  'Loss/localization_loss': 0.49722356,
#  'Loss/regularization_loss': 2.1354737,
#  'Loss/total_loss': 3.1565192,
#  'learning_rate': 0.02266645}
# INFO:tensorflow:Step 800 per-step time 0.088s
# I0724 19:11:47.766146 139687352496768 model_lib_v2.py:705] Step 800 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.7418907,
#  'Loss/localization_loss': 0.67780393,
#  'Loss/regularization_loss': 2.097496,
#  'Loss/total_loss': 3.5171907,
#  'learning_rate': 0.023999799}
# I0724 19:11:47.766860 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.7418907,
#  'Loss/localization_loss': 0.67780393,
#  'Loss/regularization_loss': 2.097496,
#  'Loss/total_loss': 3.5171907,
#  'learning_rate': 0.023999799}
# INFO:tensorflow:Step 900 per-step time 0.089s
# I0724 19:11:56.666438 139687352496768 model_lib_v2.py:705] Step 900 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.77151,
#  'Loss/localization_loss': 0.6709165,
#  'Loss/regularization_loss': 2.0589957,
#  'Loss/total_loss': 3.5014222,
#  'learning_rate': 0.025333151}
# I0724 19:11:56.666794 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.77151,
#  'Loss/localization_loss': 0.6709165,
#  'Loss/regularization_loss': 2.0589957,
#  'Loss/total_loss': 3.5014222,
#  'learning_rate': 0.025333151}
# INFO:tensorflow:Step 1000 per-step time 0.090s
# I0724 19:12:05.651830 139687352496768 model_lib_v2.py:705] Step 1000 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.5666138,
#  'Loss/localization_loss': 0.7376329,
#  'Loss/regularization_loss': 2.0325994,
#  'Loss/total_loss': 3.336846,
#  'learning_rate': 0.0266665}
# I0724 19:12:05.652419 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.5666138,
#  'Loss/localization_loss': 0.7376329,
#  'Loss/regularization_loss': 2.0325994,
#  'Loss/total_loss': 3.336846,
#  'learning_rate': 0.0266665}
# INFO:tensorflow:Step 1100 per-step time 0.138s
# I0724 19:12:19.418060 139687352496768 model_lib_v2.py:705] Step 1100 per-step time 0.138s
# INFO:tensorflow:{'Loss/classification_loss': 0.78683555,
#  'Loss/localization_loss': 0.72043043,
#  'Loss/regularization_loss': 1.9940645,
#  'Loss/total_loss': 3.5013304,
#  'learning_rate': 0.02799985}
# I0724 19:12:19.418442 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.78683555,
#  'Loss/localization_loss': 0.72043043,
#  'Loss/regularization_loss': 1.9940645,
#  'Loss/total_loss': 3.5013304,
#  'learning_rate': 0.02799985}
# INFO:tensorflow:Step 1200 per-step time 0.090s
# I0724 19:12:28.375948 139687352496768 model_lib_v2.py:705] Step 1200 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.85020363,
#  'Loss/localization_loss': 0.6298302,
#  'Loss/regularization_loss': 1.9533715,
#  'Loss/total_loss': 3.4334054,
#  'learning_rate': 0.0293332}
# I0724 19:12:28.376571 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.85020363,
#  'Loss/localization_loss': 0.6298302,
#  'Loss/regularization_loss': 1.9533715,
#  'Loss/total_loss': 3.4334054,
#  'learning_rate': 0.0293332}
# INFO:tensorflow:Step 1300 per-step time 0.089s
# I0724 19:12:37.246097 139687352496768 model_lib_v2.py:705] Step 1300 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.8370522,
#  'Loss/localization_loss': 0.70919997,
#  'Loss/regularization_loss': 1.9148638,
#  'Loss/total_loss': 3.461116,
#  'learning_rate': 0.03066655}
# I0724 19:12:37.246534 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.8370522,
#  'Loss/localization_loss': 0.70919997,
#  'Loss/regularization_loss': 1.9148638,
#  'Loss/total_loss': 3.461116,
#  'learning_rate': 0.03066655}
# INFO:tensorflow:Step 1400 per-step time 0.089s
# I0724 19:12:46.158850 139687352496768 model_lib_v2.py:705] Step 1400 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.70457417,
#  'Loss/localization_loss': 0.610101,
#  'Loss/regularization_loss': 1.8739009,
#  'Loss/total_loss': 3.188576,
#  'learning_rate': 0.0319999}
# I0724 19:12:46.159182 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.70457417,
#  'Loss/localization_loss': 0.610101,
#  'Loss/regularization_loss': 1.8739009,
#  'Loss/total_loss': 3.188576,
#  'learning_rate': 0.0319999}
# INFO:tensorflow:Step 1500 per-step time 0.089s
# I0724 19:12:55.030218 139687352496768 model_lib_v2.py:705] Step 1500 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.5741278,
#  'Loss/localization_loss': 0.81836975,
#  'Loss/regularization_loss': 1.8290324,
#  'Loss/total_loss': 3.22153,
#  'learning_rate': 0.03333325}
# I0724 19:12:55.030550 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.5741278,
#  'Loss/localization_loss': 0.81836975,
#  'Loss/regularization_loss': 1.8290324,
#  'Loss/total_loss': 3.22153,
#  'learning_rate': 0.03333325}
# INFO:tensorflow:Step 1600 per-step time 0.089s
# I0724 19:13:03.954864 139687352496768 model_lib_v2.py:705] Step 1600 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.4704023,
#  'Loss/localization_loss': 0.8599696,
#  'Loss/regularization_loss': 1.7844332,
#  'Loss/total_loss': 3.1148052,
#  'learning_rate': 0.034666598}
# I0724 19:13:03.955446 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.4704023,
#  'Loss/localization_loss': 0.8599696,
#  'Loss/regularization_loss': 1.7844332,
#  'Loss/total_loss': 3.1148052,
#  'learning_rate': 0.034666598}
# INFO:tensorflow:Step 1700 per-step time 0.089s
# I0724 19:13:12.869377 139687352496768 model_lib_v2.py:705] Step 1700 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.6206467,
#  'Loss/localization_loss': 0.61662114,
#  'Loss/regularization_loss': 1.7376764,
#  'Loss/total_loss': 2.974944,
#  'learning_rate': 0.03599995}
# I0724 19:13:12.869695 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.6206467,
#  'Loss/localization_loss': 0.61662114,
#  'Loss/regularization_loss': 1.7376764,
#  'Loss/total_loss': 2.974944,
#  'learning_rate': 0.03599995}
# INFO:tensorflow:Step 1800 per-step time 0.089s
# I0724 19:13:21.780078 139687352496768 model_lib_v2.py:705] Step 1800 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.8505518,
#  'Loss/localization_loss': 0.7235947,
#  'Loss/regularization_loss': 1.6906598,
#  'Loss/total_loss': 3.2648063,
#  'learning_rate': 0.037333302}
# I0724 19:13:21.780464 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.8505518,
#  'Loss/localization_loss': 0.7235947,
#  'Loss/regularization_loss': 1.6906598,
#  'Loss/total_loss': 3.2648063,
#  'learning_rate': 0.037333302}
# INFO:tensorflow:Step 1900 per-step time 0.089s
# I0724 19:13:30.728069 139687352496768 model_lib_v2.py:705] Step 1900 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.6940812,
#  'Loss/localization_loss': 0.64266336,
#  'Loss/regularization_loss': 1.64414,
#  'Loss/total_loss': 2.9808846,
#  'learning_rate': 0.03866665}
# I0724 19:13:30.728877 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.6940812,
#  'Loss/localization_loss': 0.64266336,
#  'Loss/regularization_loss': 1.64414,
#  'Loss/total_loss': 2.9808846,
#  'learning_rate': 0.03866665}
# INFO:tensorflow:Step 2000 per-step time 0.089s
# I0724 19:13:39.667505 139687352496768 model_lib_v2.py:705] Step 2000 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.635059,
#  'Loss/localization_loss': 0.62229294,
#  'Loss/regularization_loss': 1.5993488,
#  'Loss/total_loss': 2.8567007,
#  'learning_rate': 0.04}
# I0724 19:13:39.667913 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.635059,
#  'Loss/localization_loss': 0.62229294,
#  'Loss/regularization_loss': 1.5993488,
#  'Loss/total_loss': 2.8567007,
#  'learning_rate': 0.04}
# INFO:tensorflow:Step 2100 per-step time 0.132s
# I0724 19:13:52.856176 139687352496768 model_lib_v2.py:705] Step 2100 per-step time 0.132s
# INFO:tensorflow:{'Loss/classification_loss': 0.87015474,
#  'Loss/localization_loss': 1.4472054,
#  'Loss/regularization_loss': 1.5523244,
#  'Loss/total_loss': 3.8696847,
#  'learning_rate': 0.039999977}
# I0724 19:13:52.856911 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.87015474,
#  'Loss/localization_loss': 1.4472054,
#  'Loss/regularization_loss': 1.5523244,
#  'Loss/total_loss': 3.8696847,
#  'learning_rate': 0.039999977}
# INFO:tensorflow:Step 2200 per-step time 0.089s
# I0724 19:14:01.793360 139687352496768 model_lib_v2.py:705] Step 2200 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.5875834,
#  'Loss/localization_loss': 0.7312798,
#  'Loss/regularization_loss': 1.5075035,
#  'Loss/total_loss': 2.8263667,
#  'learning_rate': 0.0399999}
# I0724 19:14:01.793694 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.5875834,
#  'Loss/localization_loss': 0.7312798,
#  'Loss/regularization_loss': 1.5075035,
#  'Loss/total_loss': 2.8263667,
#  'learning_rate': 0.0399999}
# INFO:tensorflow:Step 2300 per-step time 0.090s
# I0724 19:14:10.762298 139687352496768 model_lib_v2.py:705] Step 2300 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.5219311,
#  'Loss/localization_loss': 0.5339133,
#  'Loss/regularization_loss': 1.4629622,
#  'Loss/total_loss': 2.5188065,
#  'learning_rate': 0.039999772}
# I0724 19:14:10.762893 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.5219311,
#  'Loss/localization_loss': 0.5339133,
#  'Loss/regularization_loss': 1.4629622,
#  'Loss/total_loss': 2.5188065,
#  'learning_rate': 0.039999772}
# INFO:tensorflow:Step 2400 per-step time 0.089s
# I0724 19:14:19.701290 139687352496768 model_lib_v2.py:705] Step 2400 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.53488445,
#  'Loss/localization_loss': 0.6213213,
#  'Loss/regularization_loss': 1.4202431,
#  'Loss/total_loss': 2.576449,
#  'learning_rate': 0.039999597}
# I0724 19:14:19.701705 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.53488445,
#  'Loss/localization_loss': 0.6213213,
#  'Loss/regularization_loss': 1.4202431,
#  'Loss/total_loss': 2.576449,
#  'learning_rate': 0.039999597}
# INFO:tensorflow:Step 2500 per-step time 0.090s
# I0724 19:14:28.679671 139687352496768 model_lib_v2.py:705] Step 2500 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.5297213,
#  'Loss/localization_loss': 0.4790611,
#  'Loss/regularization_loss': 1.3783427,
#  'Loss/total_loss': 2.387125,
#  'learning_rate': 0.03999937}
# I0724 19:14:28.680034 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.5297213,
#  'Loss/localization_loss': 0.4790611,
#  'Loss/regularization_loss': 1.3783427,
#  'Loss/total_loss': 2.387125,
#  'learning_rate': 0.03999937}
# INFO:tensorflow:Step 2600 per-step time 0.090s
# I0724 19:14:37.657219 139687352496768 model_lib_v2.py:705] Step 2600 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.4862301,
#  'Loss/localization_loss': 0.8347322,
#  'Loss/regularization_loss': 1.3386605,
#  'Loss/total_loss': 2.6596227,
#  'learning_rate': 0.039999094}
# I0724 19:14:37.657561 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.4862301,
#  'Loss/localization_loss': 0.8347322,
#  'Loss/regularization_loss': 1.3386605,
#  'Loss/total_loss': 2.6596227,
#  'learning_rate': 0.039999094}
# INFO:tensorflow:Step 2700 per-step time 0.090s
# I0724 19:14:46.651794 139687352496768 model_lib_v2.py:705] Step 2700 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.59823054,
#  'Loss/localization_loss': 0.56245124,
#  'Loss/regularization_loss': 1.2999908,
#  'Loss/total_loss': 2.4606724,
#  'learning_rate': 0.039998762}
# I0724 19:14:46.652403 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.59823054,
#  'Loss/localization_loss': 0.56245124,
#  'Loss/regularization_loss': 1.2999908,
#  'Loss/total_loss': 2.4606724,
#  'learning_rate': 0.039998762}
# INFO:tensorflow:Step 2800 per-step time 0.090s
# I0724 19:14:55.615746 139687352496768 model_lib_v2.py:705] Step 2800 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.43700013,
#  'Loss/localization_loss': 0.71134,
#  'Loss/regularization_loss': 1.2637991,
#  'Loss/total_loss': 2.4121392,
#  'learning_rate': 0.039998386}
# I0724 19:14:55.616070 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.43700013,
#  'Loss/localization_loss': 0.71134,
#  'Loss/regularization_loss': 1.2637991,
#  'Loss/total_loss': 2.4121392,
#  'learning_rate': 0.039998386}
# INFO:tensorflow:Step 2900 per-step time 0.089s
# I0724 19:15:04.550140 139687352496768 model_lib_v2.py:705] Step 2900 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.48981428,
#  'Loss/localization_loss': 0.36707783,
#  'Loss/regularization_loss': 1.2275959,
#  'Loss/total_loss': 2.084488,
#  'learning_rate': 0.039997958}
# I0724 19:15:04.550570 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.48981428,
#  'Loss/localization_loss': 0.36707783,
#  'Loss/regularization_loss': 1.2275959,
#  'Loss/total_loss': 2.084488,
#  'learning_rate': 0.039997958}
# INFO:tensorflow:Step 3000 per-step time 0.090s
# I0724 19:15:13.512140 139687352496768 model_lib_v2.py:705] Step 3000 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.4006761,
#  'Loss/localization_loss': 0.36532408,
#  'Loss/regularization_loss': 1.193514,
#  'Loss/total_loss': 1.9595141,
#  'learning_rate': 0.03999748}
# I0724 19:15:13.512474 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.4006761,
#  'Loss/localization_loss': 0.36532408,
#  'Loss/regularization_loss': 1.193514,
#  'Loss/total_loss': 1.9595141,
#  'learning_rate': 0.03999748}
# INFO:tensorflow:Step 3100 per-step time 0.131s
# I0724 19:15:26.609622 139687352496768 model_lib_v2.py:705] Step 3100 per-step time 0.131s
# INFO:tensorflow:{'Loss/classification_loss': 0.74418414,
#  'Loss/localization_loss': 0.6773961,
#  'Loss/regularization_loss': 1.1600382,
#  'Loss/total_loss': 2.5816185,
#  'learning_rate': 0.03999695}
# I0724 19:15:26.610275 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.74418414,
#  'Loss/localization_loss': 0.6773961,
#  'Loss/regularization_loss': 1.1600382,
#  'Loss/total_loss': 2.5816185,
#  'learning_rate': 0.03999695}
# INFO:tensorflow:Step 3200 per-step time 0.089s
# I0724 19:15:35.501705 139687352496768 model_lib_v2.py:705] Step 3200 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.44235027,
#  'Loss/localization_loss': 0.42059863,
#  'Loss/regularization_loss': 1.1287875,
#  'Loss/total_loss': 1.9917364,
#  'learning_rate': 0.039996374}
# I0724 19:15:35.502076 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.44235027,
#  'Loss/localization_loss': 0.42059863,
#  'Loss/regularization_loss': 1.1287875,
#  'Loss/total_loss': 1.9917364,
#  'learning_rate': 0.039996374}
# INFO:tensorflow:Step 3300 per-step time 0.089s
# I0724 19:15:44.423555 139687352496768 model_lib_v2.py:705] Step 3300 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.5137598,
#  'Loss/localization_loss': 0.6742493,
#  'Loss/regularization_loss': 1.0986092,
#  'Loss/total_loss': 2.2866182,
#  'learning_rate': 0.039995745}
# I0724 19:15:44.423899 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.5137598,
#  'Loss/localization_loss': 0.6742493,
#  'Loss/regularization_loss': 1.0986092,
#  'Loss/total_loss': 2.2866182,
#  'learning_rate': 0.039995745}
# INFO:tensorflow:Step 3400 per-step time 0.090s
# I0724 19:15:53.387533 139687352496768 model_lib_v2.py:705] Step 3400 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.41077942,
#  'Loss/localization_loss': 0.586984,
#  'Loss/regularization_loss': 1.0687453,
#  'Loss/total_loss': 2.0665088,
#  'learning_rate': 0.039995063}
# I0724 19:15:53.387860 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.41077942,
#  'Loss/localization_loss': 0.586984,
#  'Loss/regularization_loss': 1.0687453,
#  'Loss/total_loss': 2.0665088,
#  'learning_rate': 0.039995063}
# INFO:tensorflow:Step 3500 per-step time 0.090s
# I0724 19:16:02.359682 139687352496768 model_lib_v2.py:705] Step 3500 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.92449415,
#  'Loss/localization_loss': 1.0460713,
#  'Loss/regularization_loss': 1.0390973,
#  'Loss/total_loss': 3.0096626,
#  'learning_rate': 0.039994333}
# I0724 19:16:02.360290 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.92449415,
#  'Loss/localization_loss': 1.0460713,
#  'Loss/regularization_loss': 1.0390973,
#  'Loss/total_loss': 3.0096626,
#  'learning_rate': 0.039994333}
# INFO:tensorflow:Step 3600 per-step time 0.090s
# I0724 19:16:11.325102 139687352496768 model_lib_v2.py:705] Step 3600 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.63465625,
#  'Loss/localization_loss': 0.70866424,
#  'Loss/regularization_loss': 1.0117419,
#  'Loss/total_loss': 2.3550625,
#  'learning_rate': 0.039993554}
# I0724 19:16:11.325481 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.63465625,
#  'Loss/localization_loss': 0.70866424,
#  'Loss/regularization_loss': 1.0117419,
#  'Loss/total_loss': 2.3550625,
#  'learning_rate': 0.039993554}
# INFO:tensorflow:Step 3700 per-step time 0.090s
# I0724 19:16:20.277851 139687352496768 model_lib_v2.py:705] Step 3700 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.37402913,
#  'Loss/localization_loss': 0.33740175,
#  'Loss/regularization_loss': 0.9835279,
#  'Loss/total_loss': 1.6949588,
#  'learning_rate': 0.039992724}
# I0724 19:16:20.278177 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.37402913,
#  'Loss/localization_loss': 0.33740175,
#  'Loss/regularization_loss': 0.9835279,
#  'Loss/total_loss': 1.6949588,
#  'learning_rate': 0.039992724}
# INFO:tensorflow:Step 3800 per-step time 0.090s
# I0724 19:16:29.236079 139687352496768 model_lib_v2.py:705] Step 3800 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.38305286,
#  'Loss/localization_loss': 0.6082248,
#  'Loss/regularization_loss': 0.95624584,
#  'Loss/total_loss': 1.9475236,
#  'learning_rate': 0.039991844}
# I0724 19:16:29.236735 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.38305286,
#  'Loss/localization_loss': 0.6082248,
#  'Loss/regularization_loss': 0.95624584,
#  'Loss/total_loss': 1.9475236,
#  'learning_rate': 0.039991844}
# INFO:tensorflow:Step 3900 per-step time 0.090s
# I0724 19:16:38.224137 139687352496768 model_lib_v2.py:705] Step 3900 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.52906793,
#  'Loss/localization_loss': 0.533762,
#  'Loss/regularization_loss': 0.92945474,
#  'Loss/total_loss': 1.9922848,
#  'learning_rate': 0.03999091}
# I0724 19:16:38.224479 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.52906793,
#  'Loss/localization_loss': 0.533762,
#  'Loss/regularization_loss': 0.92945474,
#  'Loss/total_loss': 1.9922848,
#  'learning_rate': 0.03999091}
# INFO:tensorflow:Step 4000 per-step time 0.090s
# I0724 19:16:47.185734 139687352496768 model_lib_v2.py:705] Step 4000 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.37344962,
#  'Loss/localization_loss': 0.5384812,
#  'Loss/regularization_loss': 0.9033421,
#  'Loss/total_loss': 1.8152729,
#  'learning_rate': 0.03998993}
# I0724 19:16:47.186058 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.37344962,
#  'Loss/localization_loss': 0.5384812,
#  'Loss/regularization_loss': 0.9033421,
#  'Loss/total_loss': 1.8152729,
#  'learning_rate': 0.03998993}
# INFO:tensorflow:Step 4100 per-step time 0.131s
# I0724 19:17:00.289769 139687352496768 model_lib_v2.py:705] Step 4100 per-step time 0.131s
# INFO:tensorflow:{'Loss/classification_loss': 0.44121107,
#  'Loss/localization_loss': 0.48196194,
#  'Loss/regularization_loss': 0.8790343,
#  'Loss/total_loss': 1.8022072,
#  'learning_rate': 0.039988898}
# I0724 19:17:00.290411 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.44121107,
#  'Loss/localization_loss': 0.48196194,
#  'Loss/regularization_loss': 0.8790343,
#  'Loss/total_loss': 1.8022072,
#  'learning_rate': 0.039988898}
# INFO:tensorflow:Step 4200 per-step time 0.089s
# I0724 19:17:09.132426 139687352496768 model_lib_v2.py:705] Step 4200 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.43106043,
#  'Loss/localization_loss': 0.7576679,
#  'Loss/regularization_loss': 0.8551432,
#  'Loss/total_loss': 2.0438714,
#  'learning_rate': 0.039987817}
# I0724 19:17:09.132735 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.43106043,
#  'Loss/localization_loss': 0.7576679,
#  'Loss/regularization_loss': 0.8551432,
#  'Loss/total_loss': 2.0438714,
#  'learning_rate': 0.039987817}
# INFO:tensorflow:Step 4300 per-step time 0.089s
# I0724 19:17:18.058632 139687352496768 model_lib_v2.py:705] Step 4300 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.39337158,
#  'Loss/localization_loss': 0.5583482,
#  'Loss/regularization_loss': 0.8331443,
#  'Loss/total_loss': 1.7848641,
#  'learning_rate': 0.039986685}
# I0724 19:17:18.059055 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.39337158,
#  'Loss/localization_loss': 0.5583482,
#  'Loss/regularization_loss': 0.8331443,
#  'Loss/total_loss': 1.7848641,
#  'learning_rate': 0.039986685}
# INFO:tensorflow:Step 4400 per-step time 0.089s
# I0724 19:17:26.987542 139687352496768 model_lib_v2.py:705] Step 4400 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.4483986,
#  'Loss/localization_loss': 0.8395633,
#  'Loss/regularization_loss': 0.8115372,
#  'Loss/total_loss': 2.0994992,
#  'learning_rate': 0.0399855}
# I0724 19:17:26.987920 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.4483986,
#  'Loss/localization_loss': 0.8395633,
#  'Loss/regularization_loss': 0.8115372,
#  'Loss/total_loss': 2.0994992,
#  'learning_rate': 0.0399855}
# INFO:tensorflow:Step 4500 per-step time 0.090s
# I0724 19:17:35.958627 139687352496768 model_lib_v2.py:705] Step 4500 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.3686837,
#  'Loss/localization_loss': 0.39103794,
#  'Loss/regularization_loss': 0.79001504,
#  'Loss/total_loss': 1.5497367,
#  'learning_rate': 0.039984267}
# I0724 19:17:35.958962 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.3686837,
#  'Loss/localization_loss': 0.39103794,
#  'Loss/regularization_loss': 0.79001504,
#  'Loss/total_loss': 1.5497367,
#  'learning_rate': 0.039984267}
# INFO:tensorflow:Step 4600 per-step time 0.089s
# I0724 19:17:44.898230 139687352496768 model_lib_v2.py:705] Step 4600 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.48590225,
#  'Loss/localization_loss': 0.2661502,
#  'Loss/regularization_loss': 0.7685403,
#  'Loss/total_loss': 1.5205927,
#  'learning_rate': 0.039982982}
# I0724 19:17:44.898824 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.48590225,
#  'Loss/localization_loss': 0.2661502,
#  'Loss/regularization_loss': 0.7685403,
#  'Loss/total_loss': 1.5205927,
#  'learning_rate': 0.039982982}
# INFO:tensorflow:Step 4700 per-step time 0.088s
# I0724 19:17:53.744476 139687352496768 model_lib_v2.py:705] Step 4700 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.36307502,
#  'Loss/localization_loss': 0.36736256,
#  'Loss/regularization_loss': 0.7482078,
#  'Loss/total_loss': 1.4786453,
#  'learning_rate': 0.039981652}
# I0724 19:17:53.744847 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.36307502,
#  'Loss/localization_loss': 0.36736256,
#  'Loss/regularization_loss': 0.7482078,
#  'Loss/total_loss': 1.4786453,
#  'learning_rate': 0.039981652}
# INFO:tensorflow:Step 4800 per-step time 0.089s
# I0724 19:18:02.625014 139687352496768 model_lib_v2.py:705] Step 4800 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.46025982,
#  'Loss/localization_loss': 0.52262974,
#  'Loss/regularization_loss': 0.72940207,
#  'Loss/total_loss': 1.7122916,
#  'learning_rate': 0.039980266}
# I0724 19:18:02.625325 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.46025982,
#  'Loss/localization_loss': 0.52262974,
#  'Loss/regularization_loss': 0.72940207,
#  'Loss/total_loss': 1.7122916,
#  'learning_rate': 0.039980266}
# INFO:tensorflow:Step 4900 per-step time 0.089s
# I0724 19:18:11.568509 139687352496768 model_lib_v2.py:705] Step 4900 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.44592446,
#  'Loss/localization_loss': 0.41562203,
#  'Loss/regularization_loss': 0.7145642,
#  'Loss/total_loss': 1.5761107,
#  'learning_rate': 0.039978832}
# I0724 19:18:11.569052 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.44592446,
#  'Loss/localization_loss': 0.41562203,
#  'Loss/regularization_loss': 0.7145642,
#  'Loss/total_loss': 1.5761107,
#  'learning_rate': 0.039978832}
# INFO:tensorflow:Step 5000 per-step time 0.090s
# I0724 19:18:20.529308 139687352496768 model_lib_v2.py:705] Step 5000 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.40122765,
#  'Loss/localization_loss': 0.55288726,
#  'Loss/regularization_loss': 0.6968503,
#  'Loss/total_loss': 1.6509652,
#  'learning_rate': 0.039977346}
# I0724 19:18:20.529934 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.40122765,
#  'Loss/localization_loss': 0.55288726,
#  'Loss/regularization_loss': 0.6968503,
#  'Loss/total_loss': 1.6509652,
#  'learning_rate': 0.039977346}
# INFO:tensorflow:Step 5100 per-step time 0.130s
# I0724 19:18:33.553364 139687352496768 model_lib_v2.py:705] Step 5100 per-step time 0.130s
# INFO:tensorflow:{'Loss/classification_loss': 0.3371386,
#  'Loss/localization_loss': 0.40529236,
#  'Loss/regularization_loss': 0.6794877,
#  'Loss/total_loss': 1.4219186,
#  'learning_rate': 0.03997581}
# I0724 19:18:33.553683 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.3371386,
#  'Loss/localization_loss': 0.40529236,
#  'Loss/regularization_loss': 0.6794877,
#  'Loss/total_loss': 1.4219186,
#  'learning_rate': 0.03997581}
# INFO:tensorflow:Step 5200 per-step time 0.089s
# I0724 19:18:42.469427 139687352496768 model_lib_v2.py:705] Step 5200 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.37225223,
#  'Loss/localization_loss': 0.48426682,
#  'Loss/regularization_loss': 0.6620969,
#  'Loss/total_loss': 1.518616,
#  'learning_rate': 0.039974228}
# I0724 19:18:42.470062 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.37225223,
#  'Loss/localization_loss': 0.48426682,
#  'Loss/regularization_loss': 0.6620969,
#  'Loss/total_loss': 1.518616,
#  'learning_rate': 0.039974228}
# INFO:tensorflow:Step 5300 per-step time 0.089s
# I0724 19:18:51.337860 139687352496768 model_lib_v2.py:705] Step 5300 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.35855758,
#  'Loss/localization_loss': 0.6481875,
#  'Loss/regularization_loss': 0.64504695,
#  'Loss/total_loss': 1.651792,
#  'learning_rate': 0.039972592}
# I0724 19:18:51.338238 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.35855758,
#  'Loss/localization_loss': 0.6481875,
#  'Loss/regularization_loss': 0.64504695,
#  'Loss/total_loss': 1.651792,
#  'learning_rate': 0.039972592}
# INFO:tensorflow:Step 5400 per-step time 0.089s
# I0724 19:19:00.246078 139687352496768 model_lib_v2.py:705] Step 5400 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.47820583,
#  'Loss/localization_loss': 0.517669,
#  'Loss/regularization_loss': 0.62792706,
#  'Loss/total_loss': 1.623802,
#  'learning_rate': 0.0399709}
# I0724 19:19:00.246408 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.47820583,
#  'Loss/localization_loss': 0.517669,
#  'Loss/regularization_loss': 0.62792706,
#  'Loss/total_loss': 1.623802,
#  'learning_rate': 0.0399709}
# INFO:tensorflow:Step 5500 per-step time 0.089s
# I0724 19:19:09.125645 139687352496768 model_lib_v2.py:705] Step 5500 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.4494574,
#  'Loss/localization_loss': 0.4631347,
#  'Loss/regularization_loss': 0.6125269,
#  'Loss/total_loss': 1.5251191,
#  'learning_rate': 0.03996917}
# I0724 19:19:09.126240 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.4494574,
#  'Loss/localization_loss': 0.4631347,
#  'Loss/regularization_loss': 0.6125269,
#  'Loss/total_loss': 1.5251191,
#  'learning_rate': 0.03996917}
# INFO:tensorflow:Step 5600 per-step time 0.089s
# I0724 19:19:18.020761 139687352496768 model_lib_v2.py:705] Step 5600 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.44581223,
#  'Loss/localization_loss': 0.54265374,
#  'Loss/regularization_loss': 0.59845376,
#  'Loss/total_loss': 1.5869198,
#  'learning_rate': 0.03996738}
# I0724 19:19:18.021223 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.44581223,
#  'Loss/localization_loss': 0.54265374,
#  'Loss/regularization_loss': 0.59845376,
#  'Loss/total_loss': 1.5869198,
#  'learning_rate': 0.03996738}
# INFO:tensorflow:Step 5700 per-step time 0.089s
# I0724 19:19:26.906358 139687352496768 model_lib_v2.py:705] Step 5700 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.41824794,
#  'Loss/localization_loss': 0.48008636,
#  'Loss/regularization_loss': 0.5846076,
#  'Loss/total_loss': 1.4829419,
#  'learning_rate': 0.039965544}
# I0724 19:19:26.906733 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.41824794,
#  'Loss/localization_loss': 0.48008636,
#  'Loss/regularization_loss': 0.5846076,
#  'Loss/total_loss': 1.4829419,
#  'learning_rate': 0.039965544}
# INFO:tensorflow:Step 5800 per-step time 0.089s
# I0724 19:19:35.837253 139687352496768 model_lib_v2.py:705] Step 5800 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.4406709,
#  'Loss/localization_loss': 0.5177599,
#  'Loss/regularization_loss': 0.5707246,
#  'Loss/total_loss': 1.5291555,
#  'learning_rate': 0.039963655}
# I0724 19:19:35.837576 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.4406709,
#  'Loss/localization_loss': 0.5177599,
#  'Loss/regularization_loss': 0.5707246,
#  'Loss/total_loss': 1.5291555,
#  'learning_rate': 0.039963655}
# INFO:tensorflow:Step 5900 per-step time 0.090s
# I0724 19:19:44.792166 139687352496768 model_lib_v2.py:705] Step 5900 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.51608175,
#  'Loss/localization_loss': 0.6176313,
#  'Loss/regularization_loss': 0.55801374,
#  'Loss/total_loss': 1.6917267,
#  'learning_rate': 0.039961718}
# I0724 19:19:44.792503 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.51608175,
#  'Loss/localization_loss': 0.6176313,
#  'Loss/regularization_loss': 0.55801374,
#  'Loss/total_loss': 1.6917267,
#  'learning_rate': 0.039961718}
# INFO:tensorflow:Step 6000 per-step time 0.090s
# I0724 19:19:53.754319 139687352496768 model_lib_v2.py:705] Step 6000 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.51644415,
#  'Loss/localization_loss': 0.7208953,
#  'Loss/regularization_loss': 0.54618585,
#  'Loss/total_loss': 1.7835253,
#  'learning_rate': 0.039959732}
# I0724 19:19:53.754928 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.51644415,
#  'Loss/localization_loss': 0.7208953,
#  'Loss/regularization_loss': 0.54618585,
#  'Loss/total_loss': 1.7835253,
#  'learning_rate': 0.039959732}
# INFO:tensorflow:Step 6100 per-step time 0.132s
# I0724 19:20:07.006675 139687352496768 model_lib_v2.py:705] Step 6100 per-step time 0.132s
# INFO:tensorflow:{'Loss/classification_loss': 0.412437,
#  'Loss/localization_loss': 0.42652234,
#  'Loss/regularization_loss': 0.53335714,
#  'Loss/total_loss': 1.3723165,
#  'learning_rate': 0.039957695}
# ...
#  'Loss/regularization_loss': 0.10189964,
#  'Loss/total_loss': 0.15774554,
#  'learning_rate': 1.8349885e-05}
# INFO:tensorflow:Step 197400 per-step time 0.088s
# I0725 00:18:11.781569 139687352496768 model_lib_v2.py:705] Step 197400 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.043165274,
#  'Loss/localization_loss': 0.0223779,
#  'Loss/regularization_loss': 0.101898156,
#  'Loss/total_loss': 0.16744134,
#  'learning_rate': 1.7015933e-05}
# I0725 00:18:11.781871 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.043165274,
#  'Loss/localization_loss': 0.0223779,
#  'Loss/regularization_loss': 0.101898156,
#  'Loss/total_loss': 0.16744134,
#  'learning_rate': 1.7015933e-05}
# INFO:tensorflow:Step 197500 per-step time 0.089s
# I0725 00:18:20.683389 139687352496768 model_lib_v2.py:705] Step 197500 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.052784894,
#  'Loss/localization_loss': 0.022568481,
#  'Loss/regularization_loss': 0.10189688,
#  'Loss/total_loss': 0.17725027,
#  'learning_rate': 1.573205e-05}
# I0725 00:18:20.683695 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.052784894,
#  'Loss/localization_loss': 0.022568481,
#  'Loss/regularization_loss': 0.10189688,
#  'Loss/total_loss': 0.17725027,
#  'learning_rate': 1.573205e-05}
# INFO:tensorflow:Step 197600 per-step time 0.090s
# I0725 00:18:29.654232 139687352496768 model_lib_v2.py:705] Step 197600 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.032476917,
#  'Loss/localization_loss': 0.007222517,
#  'Loss/regularization_loss': 0.10189575,
#  'Loss/total_loss': 0.14159518,
#  'learning_rate': 1.4499426e-05}
# I0725 00:18:29.654558 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.032476917,
#  'Loss/localization_loss': 0.007222517,
#  'Loss/regularization_loss': 0.10189575,
#  'Loss/total_loss': 0.14159518,
#  'learning_rate': 1.4499426e-05}
# INFO:tensorflow:Step 197700 per-step time 0.089s
# I0725 00:18:38.543700 139687352496768 model_lib_v2.py:705] Step 197700 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.05808361,
#  'Loss/localization_loss': 0.0331269,
#  'Loss/regularization_loss': 0.10189468,
#  'Loss/total_loss': 0.19310519,
#  'learning_rate': 1.3315677e-05}
# I0725 00:18:38.544065 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.05808361,
#  'Loss/localization_loss': 0.0331269,
#  'Loss/regularization_loss': 0.10189468,
#  'Loss/total_loss': 0.19310519,
#  'learning_rate': 1.3315677e-05}
# INFO:tensorflow:Step 197800 per-step time 0.089s
# I0725 00:18:47.426090 139687352496768 model_lib_v2.py:705] Step 197800 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.048265368,
#  'Loss/localization_loss': 0.014634855,
#  'Loss/regularization_loss': 0.10189361,
#  'Loss/total_loss': 0.16479383,
#  'learning_rate': 1.2183189e-05}
# I0725 00:18:47.426393 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.048265368,
#  'Loss/localization_loss': 0.014634855,
#  'Loss/regularization_loss': 0.10189361,
#  'Loss/total_loss': 0.16479383,
#  'learning_rate': 1.2183189e-05}
# INFO:tensorflow:Step 197900 per-step time 0.089s
# I0725 00:18:56.330181 139687352496768 model_lib_v2.py:705] Step 197900 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.03412246,
#  'Loss/localization_loss': 0.022056172,
#  'Loss/regularization_loss': 0.10189273,
#  'Loss/total_loss': 0.15807137,
#  'learning_rate': 1.11007685e-05}
# I0725 00:18:56.330502 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.03412246,
#  'Loss/localization_loss': 0.022056172,
#  'Loss/regularization_loss': 0.10189273,
#  'Loss/total_loss': 0.15807137,
#  'learning_rate': 1.11007685e-05}
# INFO:tensorflow:Step 198000 per-step time 0.089s
# I0725 00:19:05.264827 139687352496768 model_lib_v2.py:705] Step 198000 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.05562603,
#  'Loss/localization_loss': 0.051978216,
#  'Loss/regularization_loss': 0.1018919,
#  'Loss/total_loss': 0.20949614,
#  'learning_rate': 1.0069609e-05}
# I0725 00:19:05.265148 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.05562603,
#  'Loss/localization_loss': 0.051978216,
#  'Loss/regularization_loss': 0.1018919,
#  'Loss/total_loss': 0.20949614,
#  'learning_rate': 1.0069609e-05}
# INFO:tensorflow:Step 198100 per-step time 0.132s
# I0725 00:19:18.488795 139687352496768 model_lib_v2.py:705] Step 198100 per-step time 0.132s
# INFO:tensorflow:{'Loss/classification_loss': 0.035685882,
#  'Loss/localization_loss': 0.009442503,
#  'Loss/regularization_loss': 0.1018912,
#  'Loss/total_loss': 0.14701958,
#  'learning_rate': 9.087324e-06}
# I0725 00:19:18.489777 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.035685882,
#  'Loss/localization_loss': 0.009442503,
#  'Loss/regularization_loss': 0.1018912,
#  'Loss/total_loss': 0.14701958,
#  'learning_rate': 9.087324e-06}
# INFO:tensorflow:Step 198200 per-step time 0.089s
# I0725 00:19:27.400069 139687352496768 model_lib_v2.py:705] Step 198200 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.025600385,
#  'Loss/localization_loss': 0.017105516,
#  'Loss/regularization_loss': 0.10189057,
#  'Loss/total_loss': 0.14459647,
#  'learning_rate': 8.156299e-06}
# I0725 00:19:27.400370 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.025600385,
#  'Loss/localization_loss': 0.017105516,
#  'Loss/regularization_loss': 0.10189057,
#  'Loss/total_loss': 0.14459647,
#  'learning_rate': 8.156299e-06}
# INFO:tensorflow:Step 198300 per-step time 0.089s
# I0725 00:19:36.326289 139687352496768 model_lib_v2.py:705] Step 198300 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.05363503,
#  'Loss/localization_loss': 0.0289805,
#  'Loss/regularization_loss': 0.101889975,
#  'Loss/total_loss': 0.1845055,
#  'learning_rate': 7.275343e-06}
# I0725 00:19:36.326592 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.05363503,
#  'Loss/localization_loss': 0.0289805,
#  'Loss/regularization_loss': 0.101889975,
#  'Loss/total_loss': 0.1845055,
#  'learning_rate': 7.275343e-06}
# INFO:tensorflow:Step 198400 per-step time 0.089s
# I0725 00:19:45.211442 139687352496768 model_lib_v2.py:705] Step 198400 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.064713396,
#  'Loss/localization_loss': 0.016580025,
#  'Loss/regularization_loss': 0.101889454,
#  'Loss/total_loss': 0.18318287,
#  'learning_rate': 6.444454e-06}
# I0725 00:19:45.211832 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.064713396,
#  'Loss/localization_loss': 0.016580025,
#  'Loss/regularization_loss': 0.101889454,
#  'Loss/total_loss': 0.18318287,
#  'learning_rate': 6.444454e-06}
# INFO:tensorflow:Step 198500 per-step time 0.089s
# I0725 00:19:54.124383 139687352496768 model_lib_v2.py:705] Step 198500 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.17136936,
#  'Loss/localization_loss': 0.13974133,
#  'Loss/regularization_loss': 0.101888984,
#  'Loss/total_loss': 0.41299966,
#  'learning_rate': 5.663633e-06}
# I0725 00:19:54.124687 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.17136936,
#  'Loss/localization_loss': 0.13974133,
#  'Loss/regularization_loss': 0.101888984,
#  'Loss/total_loss': 0.41299966,
#  'learning_rate': 5.663633e-06}
# INFO:tensorflow:Step 198600 per-step time 0.088s
# I0725 00:20:02.932563 139687352496768 model_lib_v2.py:705] Step 198600 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.046444193,
#  'Loss/localization_loss': 0.03599977,
#  'Loss/regularization_loss': 0.101888575,
#  'Loss/total_loss': 0.18433255,
#  'learning_rate': 4.9340724e-06}
# I0725 00:20:02.932875 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.046444193,
#  'Loss/localization_loss': 0.03599977,
#  'Loss/regularization_loss': 0.101888575,
#  'Loss/total_loss': 0.18433255,
#  'learning_rate': 4.9340724e-06}
# INFO:tensorflow:Step 198700 per-step time 0.089s
# I0725 00:20:11.859020 139687352496768 model_lib_v2.py:705] Step 198700 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.09544475,
#  'Loss/localization_loss': 0.057647277,
#  'Loss/regularization_loss': 0.10188822,
#  'Loss/total_loss': 0.25498024,
#  'learning_rate': 4.2545794e-06}
# I0725 00:20:11.859336 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.09544475,
#  'Loss/localization_loss': 0.057647277,
#  'Loss/regularization_loss': 0.10188822,
#  'Loss/total_loss': 0.25498024,
#  'learning_rate': 4.2545794e-06}
# INFO:tensorflow:Step 198800 per-step time 0.089s
# I0725 00:20:20.739548 139687352496768 model_lib_v2.py:705] Step 198800 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.08015932,
#  'Loss/localization_loss': 0.025930388,
#  'Loss/regularization_loss': 0.10188792,
#  'Loss/total_loss': 0.20797762,
#  'learning_rate': 3.6251545e-06}
# I0725 00:20:20.739874 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.08015932,
#  'Loss/localization_loss': 0.025930388,
#  'Loss/regularization_loss': 0.10188792,
#  'Loss/total_loss': 0.20797762,
#  'learning_rate': 3.6251545e-06}
# INFO:tensorflow:Step 198900 per-step time 0.090s
# I0725 00:20:29.699720 139687352496768 model_lib_v2.py:705] Step 198900 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.081768334,
#  'Loss/localization_loss': 0.029050985,
#  'Loss/regularization_loss': 0.10188764,
#  'Loss/total_loss': 0.21270695,
#  'learning_rate': 3.0457973e-06}
# I0725 00:20:29.700062 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.081768334,
#  'Loss/localization_loss': 0.029050985,
#  'Loss/regularization_loss': 0.10188764,
#  'Loss/total_loss': 0.21270695,
#  'learning_rate': 3.0457973e-06}
# INFO:tensorflow:Step 199000 per-step time 0.089s
# I0725 00:20:38.631733 139687352496768 model_lib_v2.py:705] Step 199000 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.04601518,
#  'Loss/localization_loss': 0.06103454,
#  'Loss/regularization_loss': 0.10188744,
#  'Loss/total_loss': 0.20893717,
#  'learning_rate': 2.5177e-06}
# I0725 00:20:38.632097 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.04601518,
#  'Loss/localization_loss': 0.06103454,
#  'Loss/regularization_loss': 0.10188744,
#  'Loss/total_loss': 0.20893717,
#  'learning_rate': 2.5177e-06}
# INFO:tensorflow:Step 199100 per-step time 0.134s
# I0725 00:20:51.987450 139687352496768 model_lib_v2.py:705] Step 199100 per-step time 0.134s
# INFO:tensorflow:{'Loss/classification_loss': 0.059907414,
#  'Loss/localization_loss': 0.036799878,
#  'Loss/regularization_loss': 0.10188727,
#  'Loss/total_loss': 0.19859457,
#  'learning_rate': 2.0396708e-06}
# I0725 00:20:51.987813 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.059907414,
#  'Loss/localization_loss': 0.036799878,
#  'Loss/regularization_loss': 0.10188727,
#  'Loss/total_loss': 0.19859457,
#  'learning_rate': 2.0396708e-06}
# INFO:tensorflow:Step 199200 per-step time 0.089s
# I0725 00:21:00.913199 139687352496768 model_lib_v2.py:705] Step 199200 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.059229247,
#  'Loss/localization_loss': 0.0069497502,
#  'Loss/regularization_loss': 0.10188713,
#  'Loss/total_loss': 0.16806613,
#  'learning_rate': 1.6117095e-06}
# I0725 00:21:00.913531 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.059229247,
#  'Loss/localization_loss': 0.0069497502,
#  'Loss/regularization_loss': 0.10188713,
#  'Loss/total_loss': 0.16806613,
#  'learning_rate': 1.6117095e-06}
# INFO:tensorflow:Step 199300 per-step time 0.090s
# I0725 00:21:09.886649 139687352496768 model_lib_v2.py:705] Step 199300 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.081501395,
#  'Loss/localization_loss': 0.013759233,
#  'Loss/regularization_loss': 0.10188703,
#  'Loss/total_loss': 0.19714767,
#  'learning_rate': 1.2338161e-06}
# I0725 00:21:09.887225 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.081501395,
#  'Loss/localization_loss': 0.013759233,
#  'Loss/regularization_loss': 0.10188703,
#  'Loss/total_loss': 0.19714767,
#  'learning_rate': 1.2338161e-06}
# INFO:tensorflow:Step 199400 per-step time 0.090s
# I0725 00:21:18.897503 139687352496768 model_lib_v2.py:705] Step 199400 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.034957238,
#  'Loss/localization_loss': 0.008429096,
#  'Loss/regularization_loss': 0.10188694,
#  'Loss/total_loss': 0.14527327,
#  'learning_rate': 9.059906e-07}
# I0725 00:21:18.897817 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.034957238,
#  'Loss/localization_loss': 0.008429096,
#  'Loss/regularization_loss': 0.10188694,
#  'Loss/total_loss': 0.14527327,
#  'learning_rate': 9.059906e-07}
# INFO:tensorflow:Step 199500 per-step time 0.090s
# I0725 00:21:27.869560 139687352496768 model_lib_v2.py:705] Step 199500 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.07513103,
#  'Loss/localization_loss': 0.05244047,
#  'Loss/regularization_loss': 0.10188688,
#  'Loss/total_loss': 0.22945838,
#  'learning_rate': 6.29425e-07}
# I0725 00:21:27.869866 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.07513103,
#  'Loss/localization_loss': 0.05244047,
#  'Loss/regularization_loss': 0.10188688,
#  'Loss/total_loss': 0.22945838,
#  'learning_rate': 6.29425e-07}
# INFO:tensorflow:Step 199600 per-step time 0.090s
# I0725 00:21:36.841723 139687352496768 model_lib_v2.py:705] Step 199600 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.08771755,
#  'Loss/localization_loss': 0.023713099,
#  'Loss/regularization_loss': 0.101886846,
#  'Loss/total_loss': 0.21331748,
#  'learning_rate': 4.0292738e-07}
# I0725 00:21:36.842091 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.08771755,
#  'Loss/localization_loss': 0.023713099,
#  'Loss/regularization_loss': 0.101886846,
#  'Loss/total_loss': 0.21331748,
#  'learning_rate': 4.0292738e-07}
# INFO:tensorflow:Step 199700 per-step time 0.090s
# I0725 00:21:45.798887 139687352496768 model_lib_v2.py:705] Step 199700 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.05125371,
#  'Loss/localization_loss': 0.01714169,
#  'Loss/regularization_loss': 0.10188682,
#  'Loss/total_loss': 0.17028221,
#  'learning_rate': 2.2649765e-07}
# I0725 00:21:45.799196 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.05125371,
#  'Loss/localization_loss': 0.01714169,
#  'Loss/regularization_loss': 0.10188682,
#  'Loss/total_loss': 0.17028221,
#  'learning_rate': 2.2649765e-07}
# INFO:tensorflow:Step 199800 per-step time 0.089s
# I0725 00:21:54.723548 139687352496768 model_lib_v2.py:705] Step 199800 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.13018355,
#  'Loss/localization_loss': 0.04575473,
#  'Loss/regularization_loss': 0.10188682,
#  'Loss/total_loss': 0.2778251,
#  'learning_rate': 1.001358e-07}
# I0725 00:21:54.723874 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.13018355,
#  'Loss/localization_loss': 0.04575473,
#  'Loss/regularization_loss': 0.10188682,
#  'Loss/total_loss': 0.2778251,
#  'learning_rate': 1.001358e-07}
# INFO:tensorflow:Step 199900 per-step time 0.089s
# I0725 00:22:03.652748 139687352496768 model_lib_v2.py:705] Step 199900 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.17013334,
#  'Loss/localization_loss': 0.1576422,
#  'Loss/regularization_loss': 0.10188682,
#  'Loss/total_loss': 0.42966235,
#  'learning_rate': 2.503395e-08}
# I0725 00:22:03.653076 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.17013334,
#  'Loss/localization_loss': 0.1576422,
#  'Loss/regularization_loss': 0.10188682,
#  'Loss/total_loss': 0.42966235,
#  'learning_rate': 2.503395e-08}
# INFO:tensorflow:Step 200000 per-step time 0.089s
# I0725 00:22:12.547330 139687352496768 model_lib_v2.py:705] Step 200000 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.055529285,
#  'Loss/localization_loss': 0.029622933,
#  'Loss/regularization_loss': 0.10188682,
#  'Loss/total_loss': 0.18703903,
#  'learning_rate': 0.0}
# I0725 00:22:12.547639 139687352496768 model_lib_v2.py:708] {'Loss/classification_loss': 0.055529285,
#  'Loss/localization_loss': 0.029622933,
#  'Loss/regularization_loss': 0.10188682,
#  'Loss/total_loss': 0.18703903,
#  'learning_rate': 0.0}

# %%
# !python /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/models/research/object_detection/model_main_tf2.py\
    --pipeline_config_path=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/pretrain_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline_256.config \
    --model_dir=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size \
    --alsologtostderr \
    --checkpoint_dir=/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size
# Out:
# 2023-07-25 23:03:20.143673: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0725 23:03:23.025210 140611125674624 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0725 23:03:23.025454 140611125674624 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0725 23:03:23.025544 140611125674624 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0725 23:03:23.025637 140611125674624 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0725 23:03:23.025761 140611125674624 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2023-07-25 23:03:24.012323: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10401 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:05:00.0, compute capability: 6.1
# INFO:tensorflow:Reading unweighted datasets: ['/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/test.record']
# I0725 23:03:24.295834 140611125674624 dataset_builder.py:162] Reading unweighted datasets: ['/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/test.record']
# I0725 23:03:24.296613 140611125674624 dataset_builder.py:79] Reading record datasets for input file: ['/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/tf_records/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0725 23:03:24.296710 140611125674624 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0725 23:03:24.296793 140611125674624 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0725 23:03:24.301445 140611125674624 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0725 23:03:24.326151 140611125674624 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0725 23:03:29.821002 140611125674624 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0725 23:03:31.499250 140611125674624 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size
# I0725 23:03:35.016393 140611125674624 checkpoint_utils.py:168] Waiting for new checkpoint at /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size
# INFO:tensorflow:Found new checkpoint at /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/ckpt-201
# I0725 23:03:35.019897 140611125674624 checkpoint_utils.py:177] Found new checkpoint at /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/ckpt-201
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0725 23:03:42.959674 140611125674624 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0725 23:04:00.706974 140611125674624 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# 2023-07-25 23:04:06.443445: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0725 23:04:07.332221 140611125674624 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0725 23:04:07.370455 140611125674624 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0725 23:04:07.574143 140611125674624 deprecation.py:364] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0725 23:04:14.967720 140611125674624 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0725 23:04:21.446832 140611125674624 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Performing evaluation on 211 images.
# I0725 23:04:22.115785 140611125674624 coco_evaluation.py:293] Performing evaluation on 211 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0725 23:04:22.118890 140611125674624 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.02s)
# I0725 23:04:22.136253 140611125674624 coco_tools.py:138] DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.49s).
# Accumulating evaluation results...
# DONE (t=0.21s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.562
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.868
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.594
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.527
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.878
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.907
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.900
# INFO:tensorflow:Eval metrics at step 200000
# I0725 23:04:24.876281 140611125674624 model_lib_v2.py:1015] Eval metrics at step 200000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.562145
# I0725 23:04:24.898349 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.562145
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.868385
# I0725 23:04:24.900713 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.868385
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.594008
# I0725 23:04:24.902371 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.594008
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.527054
# I0725 23:04:24.903986 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.527054
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.877558
# I0725 23:04:24.905560 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.877558
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.900000
# I0725 23:04:24.907229 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.900000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.149955
# I0725 23:04:24.908789 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.149955
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.467180
# I0725 23:04:24.910298 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.467180
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.674343
# I0725 23:04:24.912072 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.674343
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.655632
# I0725 23:04:24.914130 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.655632
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.907407
# I0725 23:04:24.915682 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.907407
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.900000
# I0725 23:04:24.917417 140611125674624 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.900000
# INFO:tensorflow:	+ Loss/localization_loss: 0.109761
# I0725 23:04:24.918601 140611125674624 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.109761
# INFO:tensorflow:	+ Loss/classification_loss: 0.178279
# I0725 23:04:24.919670 140611125674624 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.178279
# INFO:tensorflow:	+ Loss/regularization_loss: 0.101887
# I0725 23:04:24.920718 140611125674624 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.101887
# INFO:tensorflow:	+ Loss/total_loss: 0.389926
# I0725 23:04:24.921743 140611125674624 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.389926
# INFO:tensorflow:Exiting evaluation at step 200000
# I0725 23:04:25.122647 140611125674624 model_lib_v2.py:1168] Exiting evaluation at step 200000

# %% [markdown]
# ## Export trained inference graph

# %%
## Export trained inference graph
import os
pipeline_file = r'/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/pretrain_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline_256.config'
last_model_path = '/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/'
output_directory = "/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/export_model_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size"
os.makedirs(output_directory, exist_ok=True)

# %%
# !python /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/models/research/object_detection/exporter_main_v2.py \
    --trained_checkpoint_dir {last_model_path} \
    --output_directory {output_directory} \
    --pipeline_config_path {pipeline_file}
# Out:
# 2023-07-25 15:15:11.748727: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# 2023-07-25 15:15:15.507963: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2977 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:05:00.0, compute capability: 6.1
# WARNING:tensorflow:From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0725 15:15:15.833645 140253513331328 deprecation.py:641] From /home/skm/anaconda3/envs/myai/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0725 15:15:22.706593 140253513331328 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0725 15:15:35.749199 140253513331328 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0725 15:15:40.566701 140253513331328 signature_serialization.py:148] Function `call_func` contains input name(s) resource with unsupported characters which will be renamed to weightsharedconvolutionalboxpredictor_classpredictiontower_conv2d_3_batchnorm_feature_4_fusedbatchnormv3_readvariableop_1_resource in the SavedModel.
# I0725 15:15:42.448921 140253513331328 api.py:460] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f8e50551160>, because it is not built.
# W0725 15:15:45.179489 140253513331328 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f8e50551160>, because it is not built.
# I0725 15:16:02.619900 140253513331328 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 278). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/export_model_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/saved_model/assets
# I0725 15:16:14.215031 140253513331328 builder_impl.py:804] Assets written to: /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/export_model_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/saved_model/assets
# I0725 15:16:14.677773 140253513331328 fingerprinting_utils.py:48] Writing fingerprint to /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/export_model_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/saved_model/fingerprint.pb
# INFO:tensorflow:Writing pipeline config file to /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/export_model_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/pipeline.config
# I0725 15:16:15.421499 140253513331328 config_util.py:253] Writing pipeline config file to /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/export_model_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/pipeline.config

# %% [markdown]
# ### Load an image from file into a numpy array

# %%
# Load an image from file into a numpy array
def load_image_into_numpy_array(path):
  """Load an image from file into a numpy array.

  Puts image into numpy array to feed into tensorflow graph.
  Note that by convention we put it into a numpy array with shape
  (height, width, channels), where channels=3 for RGB.

  Args:
    path: a file path.

  Returns:
    uint8 numpy array with shape (img_height, img_width, 3)
  """
  img_data = tf.io.gfile.GFile(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# ### Visualize detections

# %%
def plot_detections(image_np,
                    boxes,
                    classes,
                    scores,
                    category_index,
                    figsize=(12, 16),
                    image_name=None):
  """Wrapper function to visualize detections.

  Args:
    image_np: uint8 numpy array with shape (img_height, img_width, 3)
    boxes: a numpy array of shape [N, 4]
    classes: a numpy array of shape [N]. Note that class indices are 1-based,
      and match the keys in the label map.
    scores: a numpy array of shape [N] or None.  If scores=None, then
      this function assumes that the boxes to be plotted are groundtruth
      boxes and plot all boxes as black with no classes or scores.
    category_index: a dict containing category dictionaries (each holding
      category index `id` and category name `name`) keyed by category indices.
    figsize: size for the figure.
    image_name: a name for the image file.
  """
  image_np_with_annotations = image_np.copy()
  viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_annotations,
      boxes,
      classes,
      scores,
      category_index,
      use_normalized_coordinates=True,
      min_score_thresh=0.5)
  if image_name:
    plt.imsave(image_name, image_np_with_annotations)
  else:
    plt.imshow(image_np_with_annotations)

# %% [markdown]
# ## Create model from the last checkpoint

# %%
ch_dir = r'/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD'
filenames = list(pathlib.Path(f'{ch_dir}/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/').glob('*.index'))

filenames.sort()
print(filenames)

#recover our saved model
model_dir = f'{ch_dir}/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/'
#generally you want to put the last ckpt from training in here
configs = config_util.get_configs_from_pipeline_file(pipeline_file)
model_config = configs['model']
detection_model = model_builder.build(
      model_config=model_config, is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(
      model=detection_model)
ckpt.restore(os.path.join(str(filenames[-1]).replace('.index','')))


def get_model_detection_function(model):
  """Get a tf.function for detection."""

  @tf.function
  def detect_fn(image):
    """Detect objects in image."""

    image, shapes = model.preprocess(image)
    prediction_dict = model.predict(image, shapes)
    detections = model.postprocess(prediction_dict, shapes)

    return detections, prediction_dict, tf.reshape(shapes, [-1])

  return detect_fn

detect_fn = get_model_detection_function(detection_model)
# Out:
# [PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/ckpt-195.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/ckpt-196.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/ckpt-197.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/ckpt-198.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/ckpt-199.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/ckpt-200.index'), PosixPath('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/train_custom/ssd_resnet50_v1_fpn_640x640_coco17_tpu_model_256size/ckpt-201.index')]
# 2023-07-25 15:18:27.498082: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2977 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:05:00.0, compute capability: 6.1

# %%
model_config
# Out:
# ssd {
#   num_classes: 1
#   image_resizer {
#     fixed_shape_resizer {
#       height: 256
#       width: 256
#     }
#   }
#   feature_extractor {
#     type: "ssd_resnet50_v1_fpn_keras"
#     depth_multiplier: 1.0
#     min_depth: 16
#     conv_hyperparams {
#       regularizer {
#         l2_regularizer {
#           weight: 0.00039999998989515007
#         }
#       }
#       initializer {
#         truncated_normal_initializer {
#           mean: 0.0
#           stddev: 0.029999999329447746
#         }
#       }
#       activation: RELU_6
#       batch_norm {
#         decay: 0.996999979019165
#         scale: true
#         epsilon: 0.0010000000474974513
#       }
#     }
#     override_base_feature_extractor_hyperparams: true
#     fpn {
#       min_level: 3
#       max_level: 7
#     }
#   }
#   box_coder {
#     faster_rcnn_box_coder {
#       y_scale: 10.0
#       x_scale: 10.0
#       height_scale: 5.0
#       width_scale: 5.0
#     }
#   }
#   matcher {
#     argmax_matcher {
#       matched_threshold: 0.5
#       unmatched_threshold: 0.5
#       ignore_thresholds: false
#       negatives_lower_than_unmatched: true
#       force_match_for_each_row: true
#       use_matmul_gather: true
#     }
#   }
#   similarity_calculator {
#     iou_similarity {
#     }
#   }
#   box_predictor {
#     weight_shared_convolutional_box_predictor {
#       conv_hyperparams {
#         regularizer {
#           l2_regularizer {
#             weight: 0.00039999998989515007
#           }
#         }
#         initializer {
#           random_normal_initializer {
#             mean: 0.0
#             stddev: 0.009999999776482582
#           }
#         }
#         activation: RELU_6
#         batch_norm {
#           decay: 0.996999979019165
#           scale: true
#           epsilon: 0.0010000000474974513
#         }
#       }
#       depth: 256
#       num_layers_before_predictor: 4
#       kernel_size: 3
#       class_prediction_bias_init: -4.599999904632568
#     }
#   }
#   anchor_generator {
#     multiscale_anchor_generator {
#       min_level: 3
#       max_level: 7
#       anchor_scale: 4.0
#       aspect_ratios: 1.0
#       aspect_ratios: 2.0
#       aspect_ratios: 0.5
#       scales_per_octave: 2
#     }
#   }
#   post_processing {
#     batch_non_max_suppression {
#       score_threshold: 9.99999993922529e-09
#       iou_threshold: 0.6000000238418579
#       max_detections_per_class: 100
#       max_total_detections: 100
#       use_static_shapes: false
#     }
#     score_converter: SIGMOID
#   }
#   normalize_loss_by_num_matches: true
#   loss {
#     localization_loss {
#       weighted_smooth_l1 {
#       }
#     }
#     classification_loss {
#       weighted_sigmoid_focal {
#         gamma: 2.0
#         alpha: 0.25
#       }
#     }
#     classification_weight: 1.0
#     localization_weight: 1.0
#   }
#   encode_background_as_zeros: true
#   normalize_loc_loss_by_codesize: true
#   inplace_batchnorm_update: true
#   freeze_batchnorm: false
# }

# %% [markdown]
# ## Map labels for inference decoding

# %%
#map labels for inference decoding
# label_map_path = configs['eval_input_config'].label_map_path
label_map_path = '/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/data_ship/label_map.txt'
label_map = label_map_util.load_labelmap(label_map_path)
categories = label_map_util.convert_label_map_to_categories(
    label_map,
    max_num_classes=label_map_util.get_max_label_map_index(label_map),
    use_display_name=True)
category_index = label_map_util.create_category_index(categories)
label_map_dict = label_map_util.get_label_map_dict(label_map, use_display_name=True)
category_index
# Out:
# {1: {'id': 1, 'name': 'ship'}}

# %%
category_index
# Out:
# {1: {'id': 1, 'name': 'ship'}}

# %% [markdown]
# ### Run detector on test image

# %%
import cv2
#run detector on test image
#it takes a little longer on the first run and then runs at normal speed. 
TEST_IMAGE_PATHS = glob.glob('/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/Try/SSD/maskrcnn/data_256/train/*.jpg')
image_path = random.choice(TEST_IMAGE_PATHS)
image_np = load_image_into_numpy_array(image_path)
# image_np = cv2.resize(image_np, dsize=None, fx=0.2, fy=0.2)

# Things to try:
# Flip horizontally
# image_np = np.fliplr(image_np).copy()

# Convert image to grayscale
# image_np = np.tile(
#     np.mean(image_np, 2, keepdims=True), (1, 1, 3)).astype(np.uint8)

input_tensor = tf.convert_to_tensor(
    np.expand_dims(image_np, 0), dtype=tf.float32)
detections, predictions_dict, shapes = detect_fn(input_tensor)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_detections,
      detections['detection_boxes'][0].numpy(),
      (detections['detection_classes'][0].numpy() + label_id_offset).astype(int),
      detections['detection_scores'][0].numpy(),
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=200,
      min_score_thresh=0.3,
      agnostic_mode=False,
)

plt.figure(figsize=(12,16))
plt.imshow(image_np_with_detections)
plt.axis("off")
plt.show()
# Out:
# 2023-07-25 15:19:16.448917: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600

# %%
category_index
# Out:
# {1: {'id': 1, 'name': 'ship'}}
