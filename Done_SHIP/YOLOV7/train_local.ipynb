# %% [markdown]
# ## Su dung trong moi truong yolo7

# %%
# !pwd
# !git clone https://github.com/augmentedstartups/yolov7.git
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7
# Cloning into 'yolov7'...
# remote: Enumerating objects: 597, done.
# remote: Total 597 (delta 0), reused 0 (delta 0), pack-reused 597
# Receiving objects: 100% (597/597), 52.44 MiB | 6.18 MiB/s, done.
# Resolving deltas: 100% (265/265), done.

# %%
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# !pip install -r requirements.txt
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# ...
#   Using cached matplotlib-3.7.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# ...
#   Using cached numpy-1.25.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.7 MB)
# ...
#   Using cached opencv_python-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
# ...
#   Using cached Pillow-10.0.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
# ...
#   Using cached scipy-1.11.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.5 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 9.5 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.8/407.8 kB 10.8 MB/s eta 0:00:000:00:01
# ...
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# ...

# %%
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# !mkdir pretrain
# %cd pretrain
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7/pretrain
# --2023-07-17 15:51:24--  https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# ## Tao bo test

# %%
# Tải ảnh sample từ internet
# %cd /content/drive/MyDrive/yolov7_train/yolov7
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# !mkdir test_images
# %cd test_images
# !wget https://cdn.theculturetrip.com/wp-content/uploads/2017/11/15271255494_fcc90d3f9b_k.jpg
# !wget https://cdnimgen.vietnamplus.vn/t620/uploaded/wbxx/2020_05_13/85896_3585300525545474_a1.jpg
# !wget https://media-cdn-v2.laodong.vn/Storage/NewsPortal/2020/4/22/800234/Chay-Pho-Co-9.jpg
# !wget https://i-vnexpress.vnecdn.net/2019/03/23/chay-1-3737-1553317413.jpg
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7/test_images
# --2023-07-22 01:51:52--  https://cdn.theculturetrip.com/wp-content/uploads/2017/11/15271255494_fcc90d3f9b_k.jpg
# Resolving cdn.theculturetrip.com (cdn.theculturetrip.com)... 108.157.14.8, 108.157.14.47, 108.157.14.82, ...
# Connecting to cdn.theculturetrip.com (cdn.theculturetrip.com)|108.157.14.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 697019 (681K) [image/jpeg]
# Saving to: ‘15271255494_fcc90d3f9b_k.jpg’
#
# 15271255494_fcc90d3 100%[===================>] 680,68K   637KB/s    in 1,1s
#
# 2023-07-22 01:51:54 (637 KB/s) - ‘15271255494_fcc90d3f9b_k.jpg’ saved [697019/697019]
#
# --2023-07-22 01:51:55--  https://cdnimgen.vietnamplus.vn/t620/uploaded/wbxx/2020_05_13/85896_3585300525545474_a1.jpg
# Resolving cdnimgen.vietnamplus.vn (cdnimgen.vietnamplus.vn)... 103.216.122.48
# ...

# %% [markdown]
# ## TAO DATA TRAIN

# %% [markdown]
# Tai du lieu train test firedata.zip

# %%
# pass
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7
# !mkdir train_data
# %cd train_data
# !unzip ../firedata.zip
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7
# mkdir: cannot create directory ‘train_data’: File exists
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/train_data
# unzip:  cannot find or open ../firedata.zip, ../firedata.zip.zip or ../firedata.zip.ZIP.

# %%
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/train_data
# !mkdir train
# !mkdir train/images
# !mkdir train/labels
# !mv *.jpg train/images
# !mv *.txt train/labels
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/train_data
# mkdir: cannot create directory ‘train’: File exists
# mkdir: cannot create directory ‘train/images’: File exists
# mkdir: cannot create directory ‘train/labels’: File exists

# %% [markdown]
# # TEST THU VS DU LIEU TEST NHAN DIEN THU

# %%
# Nhận diện thử với weight pretrain 
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# !python detect.py --weights runs/train/exp2/weights/best.pt --source /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/train_data/val_ship_128/images/DaNang_23_07_2009_LowAccuracy_1_4141.jpg
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# Namespace(weights=['runs/train/exp2/weights/best.pt'], source='/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/train_data/val_ship_128/images/DaNang_23_07_2009_LowAccuracy_1_4141.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-104-g941b94c torch 2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11171.125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# ...

# %%
# Xem ảnh đã nhận diện
from IPython.display import Image, display
display(Image(filename="/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7/runs/detect/exp/15271255494_fcc90d3f9b_k.jpg"))

# %% [markdown]
# # TRAIN MODEL

# %%
# Khai báo 1 file yaml để YOLOv7 biết:
# - Đường dẫn đến thư mục train, test (nếu có, nếu không thì dùng luôn đường dẫn đến train)
# - Số lượng class qua biến nc (number of class)
# - Tên của các class
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# !rm data/mydataset.yaml # nếu có
# !echo 'train: ../train_data/train_ship_256' >> data/mydataset.yaml
# !echo 'val: ../train_data/val_ship_256' >> data/mydataset.yaml
# !echo 'nc: 1' >> data/mydataset.yaml
# !echo "names: ['ship']" >> data/mydataset.yaml
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7

# %%
# Neu train tu dau thi weights se chi can '' la xong

# Train model YOLOv7 với dữ liệu fire
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# !python train.py --batch 5 --cfg cfg/training/yolov7.yaml --epochs 400 --data data/mydataset.yaml --weights 'pretrain/yolov7.pt'
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# YOLOR 🚀 v0.1-104-g941b94c torch 2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11171.125MB)
#
# Namespace(weights='pretrain/yolov7.pt', cfg='cfg/training/yolov7.yaml', data='data/mydataset.yaml', hyp='data/hyp.scratch.p5.yaml', epochs=400, batch_size=5, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='exp', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], world_size=1, global_rank=-1, save_dir='runs/train/exp3', total_batch_size=5)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# %cd /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# !python detect.py --weights /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7/runs/train/exp3/weights/best.pt \
                  --source /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7/test_images/DaNang_23_07_2009_LowAccuracy_1_521.jpg
# Out:
# /home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7
# Namespace(weights=['/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7/runs/train/exp3/weights/best.pt'], source='/home/skm/SKM16/IMAGE/ZZ_ZZ/TauBien/code/YOLO/Custom/TrainYOLOv7/yolov7/test_images/DaNang_23_07_2009_LowAccuracy_1_521.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-104-g941b94c torch 2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11171.125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# ...
