# %%
import torch
from torch import nn
from models import senet, modules
from torchviz import make_dot

# %%
original_model = senet.senet154(pretrained=None)
# Encoder = modules.E_senet(original_model)
# model = net.model(Encoder, num_features=2048, block_channel = [256, 512, 1024, 2048])

# %%
original_model
# Out:
# SENet(
#   (layer0): Sequential(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#     (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu3): ReLU(inplace=True)
#     (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   )
#   (layer1): Sequential(
#     (0): SEBottleneck(
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
Encoder = modules.E_senet(original_model)

# %%
next(Encoder.parameters()).device
# Out:
# device(type='cpu')

# %%
from torchsummary import summary
summary(Encoder, input_size=(3,440,440), device="cpu")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 220, 220]           1,728
#        BatchNorm2d-2         [-1, 64, 220, 220]             128
#               ReLU-3         [-1, 64, 220, 220]               0
#             Conv2d-4         [-1, 64, 220, 220]          36,864
#        BatchNorm2d-5         [-1, 64, 220, 220]             128
#               ReLU-6         [-1, 64, 220, 220]               0
#             Conv2d-7        [-1, 128, 220, 220]          73,728
#        BatchNorm2d-8        [-1, 128, 220, 220]             256
#               ReLU-9        [-1, 128, 220, 220]               0
#         MaxPool2d-10        [-1, 128, 110, 110]               0
#            Conv2d-11        [-1, 128, 110, 110]          16,384
#       BatchNorm2d-12        [-1, 128, 110, 110]             256
#              ReLU-13        [-1, 128, 110, 110]               0
# ...

# %%
x = torch.zeros(1, 3, 440, 440, dtype=torch.float, requires_grad=False)
out=Encoder(x)
make_dot(out).render("encoder", format='png')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.513775 to fit
# 'encoder.png'

# %%
x.shape
# Out:
# torch.Size([1, 3, 440, 440])
