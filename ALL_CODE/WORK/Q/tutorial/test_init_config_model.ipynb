# %%
import os
import sys
import json
import inspect

sys.path.append('../')

from models import core
from models.core import *
from inspect import getmembers, isfunction

def get_model(model, dict_params = {}):
    args_model = inspect.getfullargspec(model).args
    defaults_model = inspect.getfullargspec(model).defaults
    if not dict_params:
        for n, i in enumerate(args_model):
            num_arg = len(args_model)
            num_def = len(defaults_model)
            if (n + num_def) > (num_arg-1):
                a = (n + num_def)-(num_arg-1) -1
                dict_params.update({i:defaults_model[a]})
            else:
                dict_params.update({i:None})

    print("Args of model:")
    print(dict_params)
    for i in dict_params:
        inputt = input("Enter %s:"%(i))
        if '' != inputt:
            if '[' and ']' in inputt:
                a = json.loads(inputt)
            else:
                if inputt.isnumeric():
                    a = int(inputt)
                else:
                    try:
                        a = float(inputt)
                    except ValueError:
                        a = inputt

            dict_params.update({i:a})
    return dict_params

def main(re_params=True):
    print("List avaiable model:")
    list_model = getmembers(core, isfunction)
    for i in list_model:
        print(i[0])
    
    use_model = input("Enter name model:")
    config_path = os.path.join('..', 'configs', '%s.json'%(use_model))
    model = eval(use_model)

    if not os.path.exists(config_path):
        print("Config file isn't exists")
        dict_params = get_model(model)
        with open('../configs/%s.json'%(use_model), 'w') as outfile:
                json.dump(dict_params, outfile, indent = 4)
    else:
        if re_params:
            dict_params = json.load(open(config_path))
            dict_params = get_model(model, dict_params)
            with open('../configs/%s.json'%(use_model), 'w') as outfile:
                json.dump(dict_params, outfile, indent = 4)
        else:
            dict_params = json.load(open(config_path))

    print("Init model:")
    print(dict_params)
    init_model = model(**dict_params)
    init_model.summary()

if __name__=="__main__":
    main(re_params=False)
# Out:
# List avaiable model:
# att_unet
# swin_unet
# unet
# unet_3plus
# upernet
# Enter name model: unet_3plus
# Init model:
# {'input_size': [256, 256, 4], 'n_labels': 1, 'filter_num_down': [64, 128, 256, 512, 1024], 'filter_num_skip': 'auto', 'filter_num_aggregate': 'auto', 'stack_num_down': 2, 'stack_num_up': 1, 'activation': 'ReLU', 'output_activation': 'Softmax', 'batch_norm': False, 'pool': True, 'unpool': True, 'deep_supervision': False, 'multi_input': True, 'backbone': None, 'weights': 'imagenet', 'freeze_backbone': True, 'freeze_batch_norm': True, 'name': 'unet3plus'}
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of convolution filters after each full-scale skip connection: filter_num_skip = [64, 64, 64, 64]
# 	Number of channels of full-scale aggregated feature maps: filter_num_aggregate = 320
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 256, 256, 4  0           []
#                                 )]
#
#  unet3plus_down0_0 (Conv2D)     (None, 256, 256, 64  2368        ['input_9[0][0]']
#                                 )
#
#  unet3plus_down0_0_activation (  (None, 256, 256, 64  0          ['unet3plus_down0_0[0][0]']
#  ReLU)                          )
#
#  unet3plus_down0_1 (Conv2D)     (None, 256, 256, 64  36928       ['unet3plus_down0_0_activation[0]
#                                 )                                [0]']
#
#  unet3plus_down0_1_activation (  (None, 256, 256, 64  0          ['unet3plus_down0_1[0][0]']
#  ReLU)                          )
#
#  unet3plus_down1_encode_maxpool  (None, 128, 128, 64  0          ['unet3plus_down0_1_activation[0]
#   (MaxPooling2D)                )                                [0]']
#
#  unet3plus_down1_conv_0 (Conv2D  (None, 128, 128, 12  73856      ['unet3plus_down1_encode_maxpool[
#  )                              8)                               0][0]']
#
#  unet3plus_down1_conv_0_activat  (None, 128, 128, 12  0          ['unet3plus_down1_conv_0[0][0]']
#  ion (ReLU)                     8)
#
#  unet3plus_down1_conv_1 (Conv2D  (None, 128, 128, 12  147584     ['unet3plus_down1_conv_0_activati
#  )                              8)                               on[0][0]']
#
#  unet3plus_down1_conv_1_activat  (None, 128, 128, 12  0          ['unet3plus_down1_conv_1[0][0]']
#  ion (ReLU)                     8)
#
#  unet3plus_down2_encode_maxpool  (None, 64, 64, 128)  0          ['unet3plus_down1_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  unet3plus_down2_conv_0 (Conv2D  (None, 64, 64, 256)  295168     ['unet3plus_down2_encode_maxpool[
#  )                                                               0][0]']
#
#  unet3plus_down2_conv_0_activat  (None, 64, 64, 256)  0          ['unet3plus_down2_conv_0[0][0]']
#  ion (ReLU)
#
#  unet3plus_down2_conv_1 (Conv2D  (None, 64, 64, 256)  590080     ['unet3plus_down2_conv_0_activati
#  )                                                               on[0][0]']
#
#  unet3plus_down2_conv_1_activat  (None, 64, 64, 256)  0          ['unet3plus_down2_conv_1[0][0]']
#  ion (ReLU)
#
#  unet3plus_down3_encode_maxpool  (None, 32, 32, 256)  0          ['unet3plus_down2_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  unet3plus_down3_conv_0 (Conv2D  (None, 32, 32, 512)  1180160    ['unet3plus_down3_encode_maxpool[
#  )                                                               0][0]']
#
#  unet3plus_down3_conv_0_activat  (None, 32, 32, 512)  0          ['unet3plus_down3_conv_0[0][0]']
#  ion (ReLU)
#
#  unet3plus_down3_conv_1 (Conv2D  (None, 32, 32, 512)  2359808    ['unet3plus_down3_conv_0_activati
#  )                                                               on[0][0]']
#
#  unet3plus_down3_conv_1_activat  (None, 32, 32, 512)  0          ['unet3plus_down3_conv_1[0][0]']
#  ion (ReLU)
#
#  unet3plus_down4_encode_maxpool  (None, 16, 16, 512)  0          ['unet3plus_down3_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  unet3plus_down4_conv_0 (Conv2D  (None, 16, 16, 1024  4719616    ['unet3plus_down4_encode_maxpool[
#  )                              )                                0][0]']
#
#  unet3plus_down4_conv_0_activat  (None, 16, 16, 1024  0          ['unet3plus_down4_conv_0[0][0]']
#  ion (ReLU)                     )
#
#  unet3plus_down4_conv_1 (Conv2D  (None, 16, 16, 1024  9438208    ['unet3plus_down4_conv_0_activati
#  )                              )                                on[0][0]']
#
#  unet3plus_down4_conv_1_activat  (None, 16, 16, 1024  0          ['unet3plus_down4_conv_1[0][0]']
#  ion (ReLU)                     )
#
#  unet3plus_up_0_en0_unpool (UpS  (None, 32, 32, 1024  0          ['unet3plus_down4_conv_1_activati
#  ampling2D)                     )                                on[0][0]']
#
#  unet3plus_down_0_en2_maxpool (  (None, 32, 32, 256)  0          ['unet3plus_down2_conv_1_activati
#  MaxPooling2D)                                                   on[0][0]']
#
#  unet3plus_down_0_en3_maxpool (  (None, 32, 32, 128)  0          ['unet3plus_down1_conv_1_activati
#  MaxPooling2D)                                                   on[0][0]']
#
#  unet3plus_down_from0_to0_0 (Co  (None, 32, 32, 64)  589888      ['unet3plus_up_0_en0_unpool[0][0]
#  nv2D)                                                           ']
#
#  unet3plus_down_from0_to1_0 (Co  (None, 32, 32, 64)  294976      ['unet3plus_down3_conv_1_activati
#  nv2D)                                                           on[0][0]']
#
#  unet3plus_down_from0_to2_0 (Co  (None, 32, 32, 64)  147520      ['unet3plus_down_0_en2_maxpool[0]
#  nv2D)                                                           [0]']
#
#  unet3plus_down_from0_to3_0 (Co  (None, 32, 32, 64)  73792       ['unet3plus_down_0_en3_maxpool[0]
#  nv2D)                                                           [0]']
#
#  unet3plus_down_from0_to0_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from0_to0_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from0_to1_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from0_to1_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from0_to2_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from0_to2_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from0_to3_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from0_to3_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_concat_0 (Concatenat  (None, 32, 32, 256)  0          ['unet3plus_down_from0_to0_0_acti
#  e)                                                              vation[0][0]',
#                                                                   'unet3plus_down_from0_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from0_to2_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from0_to3_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_0_0 (Con  (None, 32, 32, 320)  737280     ['unet3plus_concat_0[0][0]']
#  v2D)
#
#  unet3plus_fusion_conv_0_0_bn (  (None, 32, 32, 320)  1280       ['unet3plus_fusion_conv_0_0[0][0]
#  BatchNormalization)                                             ']
#
#  unet3plus_fusion_conv_0_0_acti  (None, 32, 32, 320)  0          ['unet3plus_fusion_conv_0_0_bn[0]
#  vation (ReLU)                                                   [0]']
#
#  unet3plus_up_1_en0_unpool (UpS  (None, 64, 64, 1024  0          ['unet3plus_down4_conv_1_activati
#  ampling2D)                     )                                on[0][0]']
#
#  unet3plus_up_1_en1_unpool (UpS  (None, 64, 64, 320)  0          ['unet3plus_fusion_conv_0_0_activ
#  ampling2D)                                                      ation[0][0]']
#
#  unet3plus_down_1_en3_maxpool (  (None, 64, 64, 128)  0          ['unet3plus_down1_conv_1_activati
#  MaxPooling2D)                                                   on[0][0]']
#
#  unet3plus_down_from1_to0_0 (Co  (None, 64, 64, 64)  589888      ['unet3plus_up_1_en0_unpool[0][0]
#  nv2D)                                                           ']
#
#  unet3plus_down_from1_to1_0 (Co  (None, 64, 64, 64)  184384      ['unet3plus_up_1_en1_unpool[0][0]
#  nv2D)                                                           ']
#
#  unet3plus_down_from1_to2_0 (Co  (None, 64, 64, 64)  147520      ['unet3plus_down2_conv_1_activati
#  nv2D)                                                           on[0][0]']
#
#  unet3plus_down_from1_to3_0 (Co  (None, 64, 64, 64)  73792       ['unet3plus_down_1_en3_maxpool[0]
#  nv2D)                                                           [0]']
#
#  unet3plus_down_from1_to0_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from1_to0_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from1_to1_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from1_to1_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from1_to2_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from1_to2_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from1_to3_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from1_to3_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_concat_1 (Concatenat  (None, 64, 64, 256)  0          ['unet3plus_down_from1_to0_0_acti
#  e)                                                              vation[0][0]',
#                                                                   'unet3plus_down_from1_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from1_to2_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from1_to3_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_1_0 (Con  (None, 64, 64, 320)  737280     ['unet3plus_concat_1[0][0]']
#  v2D)
#
#  unet3plus_fusion_conv_1_0_bn (  (None, 64, 64, 320)  1280       ['unet3plus_fusion_conv_1_0[0][0]
#  BatchNormalization)                                             ']
#
#  unet3plus_fusion_conv_1_0_acti  (None, 64, 64, 320)  0          ['unet3plus_fusion_conv_1_0_bn[0]
#  vation (ReLU)                                                   [0]']
#
#  unet3plus_up_2_en0_unpool (UpS  (None, 128, 128, 10  0          ['unet3plus_down4_conv_1_activati
#  ampling2D)                     24)                              on[0][0]']
#
#  unet3plus_up_2_en1_unpool (UpS  (None, 128, 128, 32  0          ['unet3plus_fusion_conv_0_0_activ
#  ampling2D)                     0)                               ation[0][0]']
#
#  unet3plus_up_2_en2_unpool (UpS  (None, 128, 128, 32  0          ['unet3plus_fusion_conv_1_0_activ
#  ampling2D)                     0)                               ation[0][0]']
#
#  unet3plus_down_from2_to0_0 (Co  (None, 128, 128, 64  589888     ['unet3plus_up_2_en0_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from2_to1_0 (Co  (None, 128, 128, 64  184384     ['unet3plus_up_2_en1_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from2_to2_0 (Co  (None, 128, 128, 64  184384     ['unet3plus_up_2_en2_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from2_to3_0 (Co  (None, 128, 128, 64  73792      ['unet3plus_down1_conv_1_activati
#  nv2D)                          )                                on[0][0]']
#
#  unet3plus_down_from2_to0_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from2_to0_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_down_from2_to1_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from2_to1_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_down_from2_to2_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from2_to2_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_down_from2_to3_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from2_to3_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_concat_2 (Concatenat  (None, 128, 128, 25  0          ['unet3plus_down_from2_to0_0_acti
#  e)                             6)                               vation[0][0]',
#                                                                   'unet3plus_down_from2_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from2_to2_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from2_to3_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_2_0 (Con  (None, 128, 128, 32  737280     ['unet3plus_concat_2[0][0]']
#  v2D)                           0)
#
#  unet3plus_fusion_conv_2_0_bn (  (None, 128, 128, 32  1280       ['unet3plus_fusion_conv_2_0[0][0]
#  BatchNormalization)            0)                               ']
#
#  unet3plus_fusion_conv_2_0_acti  (None, 128, 128, 32  0          ['unet3plus_fusion_conv_2_0_bn[0]
#  vation (ReLU)                  0)                               [0]']
#
#  unet3plus_up_3_en0_unpool (UpS  (None, 256, 256, 10  0          ['unet3plus_down4_conv_1_activati
#  ampling2D)                     24)                              on[0][0]']
#
#  unet3plus_up_3_en1_unpool (UpS  (None, 256, 256, 32  0          ['unet3plus_fusion_conv_0_0_activ
#  ampling2D)                     0)                               ation[0][0]']
#
#  unet3plus_up_3_en2_unpool (UpS  (None, 256, 256, 32  0          ['unet3plus_fusion_conv_1_0_activ
#  ampling2D)                     0)                               ation[0][0]']
#
#  unet3plus_up_3_en3_unpool (UpS  (None, 256, 256, 32  0          ['unet3plus_fusion_conv_2_0_activ
#  ampling2D)                     0)                               ation[0][0]']
#
#  unet3plus_down_from3_to0_0 (Co  (None, 256, 256, 64  589888     ['unet3plus_up_3_en0_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from3_to1_0 (Co  (None, 256, 256, 64  184384     ['unet3plus_up_3_en1_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from3_to2_0 (Co  (None, 256, 256, 64  184384     ['unet3plus_up_3_en2_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from3_to3_0 (Co  (None, 256, 256, 64  184384     ['unet3plus_up_3_en3_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from3_to0_0_act  (None, 256, 256, 64  0          ['unet3plus_down_from3_to0_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_down_from3_to1_0_act  (None, 256, 256, 64  0          ['unet3plus_down_from3_to1_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_down_from3_to2_0_act  (None, 256, 256, 64  0          ['unet3plus_down_from3_to2_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_down_from3_to3_0_act  (None, 256, 256, 64  0          ['unet3plus_down_from3_to3_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_concat_3 (Concatenat  (None, 256, 256, 25  0          ['unet3plus_down_from3_to0_0_acti
#  e)                             6)                               vation[0][0]',
#                                                                   'unet3plus_down_from3_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from3_to2_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from3_to3_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_3_0 (Con  (None, 256, 256, 32  737280     ['unet3plus_concat_3[0][0]']
#  v2D)                           0)
#
#  unet3plus_fusion_conv_3_0_bn (  (None, 256, 256, 32  1280       ['unet3plus_fusion_conv_3_0[0][0]
#  BatchNormalization)            0)                               ']
#
#  unet3plus_fusion_conv_3_0_acti  (None, 256, 256, 32  0          ['unet3plus_fusion_conv_3_0_bn[0]
#  vation (ReLU)                  0)                               [0]']
#
#  unet3plus_output_final (Conv2D  (None, 256, 256, 1)  2881       ['unet3plus_fusion_conv_3_0_activ
#  )                                                               ation[0][0]']
#
#  unet3plus_output_final_activat  (None, 256, 256, 1)  0          ['unet3plus_output_final[0][0]']
#  ion (Softmax)
#
# ==================================================================================================
# Total params: 26,078,145
# Trainable params: 26,075,585
# Non-trainable params: 2,560
# __________________________________________________________________________________________________

# %%
from models.core.unet3plus import unet_3plus

model = unet_3plus(input_size=[128,128,4], n_labels=1, filter_num_down=[64, 128, 256, 512, 1024], filter_num_skip='auto', filter_num_aggregate='auto', 
                stack_num_down=2, stack_num_up=1, activation='ReLU', output_activation='Sigmoid',
                batch_norm=False, pool=True, unpool=True, deep_supervision=False, multi_input=True,
                backbone=None, weights='imagenet', freeze_backbone=True, freeze_batch_norm=True, name='unet3plus')
# Out:
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of convolution filters after each full-scale skip connection: filter_num_skip = [64, 64, 64, 64]
# 	Number of channels of full-scale aggregated feature maps: filter_num_aggregate = 320

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 128, 128, 4  0           []
#                                 )]
#
#  unet3plus_down0_0 (Conv2D)     (None, 128, 128, 64  2368        ['input_8[0][0]']
#                                 )
#
#  unet3plus_down0_0_activation (  (None, 128, 128, 64  0          ['unet3plus_down0_0[0][0]']
#  ReLU)                          )
#
#  unet3plus_down0_1 (Conv2D)     (None, 128, 128, 64  36928       ['unet3plus_down0_0_activation[0]
#                                 )                                [0]']
#
#  unet3plus_down0_1_activation (  (None, 128, 128, 64  0          ['unet3plus_down0_1[0][0]']
#  ReLU)                          )
#
#  unet3plus_down1_encode_maxpool  (None, 64, 64, 64)  0           ['unet3plus_down0_1_activation[0]
#   (MaxPooling2D)                                                 [0]']
#
#  unet3plus_down1_conv_0 (Conv2D  (None, 64, 64, 128)  73856      ['unet3plus_down1_encode_maxpool[
#  )                                                               0][0]']
#
#  unet3plus_down1_conv_0_activat  (None, 64, 64, 128)  0          ['unet3plus_down1_conv_0[0][0]']
#  ion (ReLU)
#
#  unet3plus_down1_conv_1 (Conv2D  (None, 64, 64, 128)  147584     ['unet3plus_down1_conv_0_activati
#  )                                                               on[0][0]']
#
#  unet3plus_down1_conv_1_activat  (None, 64, 64, 128)  0          ['unet3plus_down1_conv_1[0][0]']
#  ion (ReLU)
#
#  unet3plus_down2_encode_maxpool  (None, 32, 32, 128)  0          ['unet3plus_down1_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  unet3plus_down2_conv_0 (Conv2D  (None, 32, 32, 256)  295168     ['unet3plus_down2_encode_maxpool[
#  )                                                               0][0]']
#
#  unet3plus_down2_conv_0_activat  (None, 32, 32, 256)  0          ['unet3plus_down2_conv_0[0][0]']
#  ion (ReLU)
#
#  unet3plus_down2_conv_1 (Conv2D  (None, 32, 32, 256)  590080     ['unet3plus_down2_conv_0_activati
#  )                                                               on[0][0]']
#
#  unet3plus_down2_conv_1_activat  (None, 32, 32, 256)  0          ['unet3plus_down2_conv_1[0][0]']
#  ion (ReLU)
#
#  unet3plus_down3_encode_maxpool  (None, 16, 16, 256)  0          ['unet3plus_down2_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  unet3plus_down3_conv_0 (Conv2D  (None, 16, 16, 512)  1180160    ['unet3plus_down3_encode_maxpool[
#  )                                                               0][0]']
#
#  unet3plus_down3_conv_0_activat  (None, 16, 16, 512)  0          ['unet3plus_down3_conv_0[0][0]']
#  ion (ReLU)
#
#  unet3plus_down3_conv_1 (Conv2D  (None, 16, 16, 512)  2359808    ['unet3plus_down3_conv_0_activati
#  )                                                               on[0][0]']
#
#  unet3plus_down3_conv_1_activat  (None, 16, 16, 512)  0          ['unet3plus_down3_conv_1[0][0]']
#  ion (ReLU)
#
#  unet3plus_down4_encode_maxpool  (None, 8, 8, 512)   0           ['unet3plus_down3_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  unet3plus_down4_conv_0 (Conv2D  (None, 8, 8, 1024)  4719616     ['unet3plus_down4_encode_maxpool[
#  )                                                               0][0]']
#
#  unet3plus_down4_conv_0_activat  (None, 8, 8, 1024)  0           ['unet3plus_down4_conv_0[0][0]']
#  ion (ReLU)
#
#  unet3plus_down4_conv_1 (Conv2D  (None, 8, 8, 1024)  9438208     ['unet3plus_down4_conv_0_activati
#  )                                                               on[0][0]']
#
#  unet3plus_down4_conv_1_activat  (None, 8, 8, 1024)  0           ['unet3plus_down4_conv_1[0][0]']
#  ion (ReLU)
#
#  unet3plus_up_0_en0_unpool (UpS  (None, 16, 16, 1024  0          ['unet3plus_down4_conv_1_activati
#  ampling2D)                     )                                on[0][0]']
#
#  unet3plus_down_0_en2_maxpool (  (None, 16, 16, 256)  0          ['unet3plus_down2_conv_1_activati
#  MaxPooling2D)                                                   on[0][0]']
#
#  unet3plus_down_0_en3_maxpool (  (None, 16, 16, 128)  0          ['unet3plus_down1_conv_1_activati
#  MaxPooling2D)                                                   on[0][0]']
#
#  unet3plus_down_from0_to0_0 (Co  (None, 16, 16, 64)  589888      ['unet3plus_up_0_en0_unpool[0][0]
#  nv2D)                                                           ']
#
#  unet3plus_down_from0_to1_0 (Co  (None, 16, 16, 64)  294976      ['unet3plus_down3_conv_1_activati
#  nv2D)                                                           on[0][0]']
#
#  unet3plus_down_from0_to2_0 (Co  (None, 16, 16, 64)  147520      ['unet3plus_down_0_en2_maxpool[0]
#  nv2D)                                                           [0]']
#
#  unet3plus_down_from0_to3_0 (Co  (None, 16, 16, 64)  73792       ['unet3plus_down_0_en3_maxpool[0]
#  nv2D)                                                           [0]']
#
#  unet3plus_down_from0_to0_0_act  (None, 16, 16, 64)  0           ['unet3plus_down_from0_to0_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from0_to1_0_act  (None, 16, 16, 64)  0           ['unet3plus_down_from0_to1_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from0_to2_0_act  (None, 16, 16, 64)  0           ['unet3plus_down_from0_to2_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from0_to3_0_act  (None, 16, 16, 64)  0           ['unet3plus_down_from0_to3_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_concat_0 (Concatenat  (None, 16, 16, 256)  0          ['unet3plus_down_from0_to0_0_acti
#  e)                                                              vation[0][0]',
#                                                                   'unet3plus_down_from0_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from0_to2_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from0_to3_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_0_0 (Con  (None, 16, 16, 320)  737280     ['unet3plus_concat_0[0][0]']
#  v2D)
#
#  unet3plus_fusion_conv_0_0_bn (  (None, 16, 16, 320)  1280       ['unet3plus_fusion_conv_0_0[0][0]
#  BatchNormalization)                                             ']
#
#  unet3plus_fusion_conv_0_0_acti  (None, 16, 16, 320)  0          ['unet3plus_fusion_conv_0_0_bn[0]
#  vation (ReLU)                                                   [0]']
#
#  unet3plus_up_1_en0_unpool (UpS  (None, 32, 32, 1024  0          ['unet3plus_down4_conv_1_activati
#  ampling2D)                     )                                on[0][0]']
#
#  unet3plus_up_1_en1_unpool (UpS  (None, 32, 32, 320)  0          ['unet3plus_fusion_conv_0_0_activ
#  ampling2D)                                                      ation[0][0]']
#
#  unet3plus_down_1_en3_maxpool (  (None, 32, 32, 128)  0          ['unet3plus_down1_conv_1_activati
#  MaxPooling2D)                                                   on[0][0]']
#
#  unet3plus_down_from1_to0_0 (Co  (None, 32, 32, 64)  589888      ['unet3plus_up_1_en0_unpool[0][0]
#  nv2D)                                                           ']
#
#  unet3plus_down_from1_to1_0 (Co  (None, 32, 32, 64)  184384      ['unet3plus_up_1_en1_unpool[0][0]
#  nv2D)                                                           ']
#
#  unet3plus_down_from1_to2_0 (Co  (None, 32, 32, 64)  147520      ['unet3plus_down2_conv_1_activati
#  nv2D)                                                           on[0][0]']
#
#  unet3plus_down_from1_to3_0 (Co  (None, 32, 32, 64)  73792       ['unet3plus_down_1_en3_maxpool[0]
#  nv2D)                                                           [0]']
#
#  unet3plus_down_from1_to0_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from1_to0_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from1_to1_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from1_to1_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from1_to2_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from1_to2_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from1_to3_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from1_to3_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_concat_1 (Concatenat  (None, 32, 32, 256)  0          ['unet3plus_down_from1_to0_0_acti
#  e)                                                              vation[0][0]',
#                                                                   'unet3plus_down_from1_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from1_to2_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from1_to3_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_1_0 (Con  (None, 32, 32, 320)  737280     ['unet3plus_concat_1[0][0]']
#  v2D)
#
#  unet3plus_fusion_conv_1_0_bn (  (None, 32, 32, 320)  1280       ['unet3plus_fusion_conv_1_0[0][0]
#  BatchNormalization)                                             ']
#
#  unet3plus_fusion_conv_1_0_acti  (None, 32, 32, 320)  0          ['unet3plus_fusion_conv_1_0_bn[0]
#  vation (ReLU)                                                   [0]']
#
#  unet3plus_up_2_en0_unpool (UpS  (None, 64, 64, 1024  0          ['unet3plus_down4_conv_1_activati
#  ampling2D)                     )                                on[0][0]']
#
#  unet3plus_up_2_en1_unpool (UpS  (None, 64, 64, 320)  0          ['unet3plus_fusion_conv_0_0_activ
#  ampling2D)                                                      ation[0][0]']
#
#  unet3plus_up_2_en2_unpool (UpS  (None, 64, 64, 320)  0          ['unet3plus_fusion_conv_1_0_activ
#  ampling2D)                                                      ation[0][0]']
#
#  unet3plus_down_from2_to0_0 (Co  (None, 64, 64, 64)  589888      ['unet3plus_up_2_en0_unpool[0][0]
#  nv2D)                                                           ']
#
#  unet3plus_down_from2_to1_0 (Co  (None, 64, 64, 64)  184384      ['unet3plus_up_2_en1_unpool[0][0]
#  nv2D)                                                           ']
#
#  unet3plus_down_from2_to2_0 (Co  (None, 64, 64, 64)  184384      ['unet3plus_up_2_en2_unpool[0][0]
#  nv2D)                                                           ']
#
#  unet3plus_down_from2_to3_0 (Co  (None, 64, 64, 64)  73792       ['unet3plus_down1_conv_1_activati
#  nv2D)                                                           on[0][0]']
#
#  unet3plus_down_from2_to0_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from2_to0_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from2_to1_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from2_to1_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from2_to2_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from2_to2_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_down_from2_to3_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from2_to3_0[0][0
#  ivation (ReLU)                                                  ]']
#
#  unet3plus_concat_2 (Concatenat  (None, 64, 64, 256)  0          ['unet3plus_down_from2_to0_0_acti
#  e)                                                              vation[0][0]',
#                                                                   'unet3plus_down_from2_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from2_to2_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from2_to3_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_2_0 (Con  (None, 64, 64, 320)  737280     ['unet3plus_concat_2[0][0]']
#  v2D)
#
#  unet3plus_fusion_conv_2_0_bn (  (None, 64, 64, 320)  1280       ['unet3plus_fusion_conv_2_0[0][0]
#  BatchNormalization)                                             ']
#
#  unet3plus_fusion_conv_2_0_acti  (None, 64, 64, 320)  0          ['unet3plus_fusion_conv_2_0_bn[0]
#  vation (ReLU)                                                   [0]']
#
#  unet3plus_up_3_en0_unpool (UpS  (None, 128, 128, 10  0          ['unet3plus_down4_conv_1_activati
#  ampling2D)                     24)                              on[0][0]']
#
#  unet3plus_up_3_en1_unpool (UpS  (None, 128, 128, 32  0          ['unet3plus_fusion_conv_0_0_activ
#  ampling2D)                     0)                               ation[0][0]']
#
#  unet3plus_up_3_en2_unpool (UpS  (None, 128, 128, 32  0          ['unet3plus_fusion_conv_1_0_activ
#  ampling2D)                     0)                               ation[0][0]']
#
#  unet3plus_up_3_en3_unpool (UpS  (None, 128, 128, 32  0          ['unet3plus_fusion_conv_2_0_activ
#  ampling2D)                     0)                               ation[0][0]']
#
#  unet3plus_down_from3_to0_0 (Co  (None, 128, 128, 64  589888     ['unet3plus_up_3_en0_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from3_to1_0 (Co  (None, 128, 128, 64  184384     ['unet3plus_up_3_en1_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from3_to2_0 (Co  (None, 128, 128, 64  184384     ['unet3plus_up_3_en2_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from3_to3_0 (Co  (None, 128, 128, 64  184384     ['unet3plus_up_3_en3_unpool[0][0]
#  nv2D)                          )                                ']
#
#  unet3plus_down_from3_to0_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from3_to0_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_down_from3_to1_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from3_to1_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_down_from3_to2_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from3_to2_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_down_from3_to3_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from3_to3_0[0][0
#  ivation (ReLU)                 )                                ]']
#
#  unet3plus_concat_3 (Concatenat  (None, 128, 128, 25  0          ['unet3plus_down_from3_to0_0_acti
#  e)                             6)                               vation[0][0]',
#                                                                   'unet3plus_down_from3_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from3_to2_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from3_to3_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_3_0 (Con  (None, 128, 128, 32  737280     ['unet3plus_concat_3[0][0]']
#  v2D)                           0)
#
#  unet3plus_fusion_conv_3_0_bn (  (None, 128, 128, 32  1280       ['unet3plus_fusion_conv_3_0[0][0]
#  BatchNormalization)            0)                               ']
#
#  unet3plus_fusion_conv_3_0_acti  (None, 128, 128, 32  0          ['unet3plus_fusion_conv_3_0_bn[0]
#  vation (ReLU)                  0)                               [0]']
#
#  unet3plus_output_final (Conv2D  (None, 128, 128, 1)  2881       ['unet3plus_fusion_conv_3_0_activ
#  )                                                               ation[0][0]']
#
#  unet3plus_output_final_activat  (None, 128, 128, 1)  0          ['unet3plus_output_final[0][0]']
#  ion (Activation)
#
# ==================================================================================================
# Total params: 26,078,145
# Trainable params: 26,075,585
# Non-trainable params: 2,560
# __________________________________________________________________________________________________
