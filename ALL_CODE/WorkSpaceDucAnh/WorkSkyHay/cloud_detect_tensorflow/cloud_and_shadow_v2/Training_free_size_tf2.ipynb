# %% [markdown]
# ##### Cloud and shadow

# %%
import os
# import model as modellib
# import unet_new as modellib2
# import vgg16unet
import argparse
import numpy as np
import tensorflow as tf
import pandas as pd
import os
import h5py
from data_defores_generator import data_gen, create_list_id,data_gen_not_batch
from datetime import datetime
from tensorflow.keras.callbacks import (ModelCheckpoint, TensorBoard, CSVLogger, History, EarlyStopping, LambdaCallback,ReduceLROnPlateau)

from tensorflow.keras import layers, backend, Model, utils
from matplotlib import pyplot as plt
import rasterio
import cv2
from tensorflow.compat.v1.keras.backend import set_session

physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
config = tf.config.experimental.set_memory_growth(physical_devices[0], True)
# import wanrings
# warnings.filterwarnings("ignore")
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.allow_growth=True
# set_session(tf.compat.v1.Session(config=config))
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
# os.environ['TF_GPU_ALLOCATOR'] = "cuda_malloc_async"
# Out:
# 2022-10-31 17:06:32.176638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 17:06:32.203492: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 17:06:32.203642: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
FMT_VALMODEL_PATH ="{}_val_weights.h5"
FMT_VALMODEL_LAST_PATH = "{}_val_weights_last.h5"
FMT_VALMODEL_HIST = "{}_val_hist.csv"
PREFIX = "checkpoints"
INPUT_CHANNEL =  300
INPUT_SIZE = 512
early_stop = 50
num_class = 1
weight_path = r""
log_dir = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs"
num_epoch = 200
batch_size= 16
scale_neg = 0.1

# %%
from model import build_model
unet = build_model((None,None,4), 42) #36??
# unet = modellib2.build_model((None,None,3), 32)
# lowest size (None, 64, 64, 512)
# Out:
# 2022-10-31 17:06:32.315867: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-31 17:06:32.316434: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 17:06:32.316614: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 17:06:32.316718: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 17:06:32.708670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 17:06:32.708857: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 17:06:32.708971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 17:06:32.709059: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9620 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# weight_path = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0247_val_weights.h5"
if weight_path != "":
    unet.load_weights(weight_path)

# %%
if not os.path.exists(log_dir):
    os.mkdir(log_dir)

# %%
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  4)]
#
#  conv2d (Conv2D)                (None, None, None,   1554        ['input_1[0][0]']
#                                 42)
#
#  batch_normalization (BatchNorm  (None, None, None,   168        ['conv2d[0][0]']
#  alization)                     42)
#
#  leaky_re_lu (LeakyReLU)        (None, None, None,   0           ['batch_normalization[0][0]']
#                                 42)
#
#  conv2d_1 (Conv2D)              (None, None, None,   15918       ['leaky_re_lu[0][0]']
#                                 42)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   168        ['conv2d_1[0][0]']
#  rmalization)                   42)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 42)
#
#  conv2d_2 (Conv2D)              (None, None, None,   15918       ['leaky_re_lu_1[0][0]']
#                                 42)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   168        ['conv2d_2[0][0]']
#  rmalization)                   42)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 42)
#
#  add (Add)                      (None, None, None,   0           ['leaky_re_lu_2[0][0]',
#                                 42)                               'conv2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, None, None,   168        ['add[0][0]']
#  rmalization)                   42)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 42)
#
#  conv2d_3 (Conv2D)              (None, None, None,   15918       ['leaky_re_lu_3[0][0]']
#                                 42)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   168        ['conv2d_3[0][0]']
#  rmalization)                   42)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 42)
#
#  conv2d_4 (Conv2D)              (None, None, None,   15918       ['leaky_re_lu_4[0][0]']
#                                 42)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   168        ['conv2d_4[0][0]']
#  rmalization)                   42)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 42)
#
#  add_1 (Add)                    (None, None, None,   0           ['leaky_re_lu_5[0][0]',
#                                 42)                               'add[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, None, None,   168        ['add_1[0][0]']
#  rmalization)                   42)
#
#  leaky_re_lu_6 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 42)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['leaky_re_lu_6[0][0]']
#                                 42)
#
#  dropout (Dropout)              (None, None, None,   0           ['max_pooling2d[0][0]']
#                                 42)
#
#  conv2d_5 (Conv2D)              (None, None, None,   31836       ['dropout[0][0]']
#                                 84)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   336        ['conv2d_5[0][0]']
#  rmalization)                   84)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 84)
#
#  conv2d_6 (Conv2D)              (None, None, None,   63588       ['leaky_re_lu_7[0][0]']
#                                 84)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   336        ['conv2d_6[0][0]']
#  rmalization)                   84)
#
#  leaky_re_lu_8 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 84)
#
#  conv2d_7 (Conv2D)              (None, None, None,   63588       ['leaky_re_lu_8[0][0]']
#                                 84)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   336        ['conv2d_7[0][0]']
#  rmalization)                   84)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 84)
#
#  add_2 (Add)                    (None, None, None,   0           ['leaky_re_lu_9[0][0]',
#                                 84)                               'conv2d_5[0][0]']
#
#  batch_normalization_10 (BatchN  (None, None, None,   336        ['add_2[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_10 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 84)
#
#  conv2d_8 (Conv2D)              (None, None, None,   63588       ['leaky_re_lu_10[0][0]']
#                                 84)
#
#  batch_normalization_11 (BatchN  (None, None, None,   336        ['conv2d_8[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_11 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 84)
#
#  conv2d_9 (Conv2D)              (None, None, None,   63588       ['leaky_re_lu_11[0][0]']
#                                 84)
#
#  batch_normalization_12 (BatchN  (None, None, None,   336        ['conv2d_9[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_12 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 84)
#
#  add_3 (Add)                    (None, None, None,   0           ['leaky_re_lu_12[0][0]',
#                                 84)                               'add_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, None, None,   336        ['add_3[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 84)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['leaky_re_lu_13[0][0]']
#                                 84)
#
#  dropout_1 (Dropout)            (None, None, None,   0           ['max_pooling2d_1[0][0]']
#                                 84)
#
#  conv2d_10 (Conv2D)             (None, None, None,   127176      ['dropout_1[0][0]']
#                                 168)
#
#  batch_normalization_14 (BatchN  (None, None, None,   672        ['conv2d_10[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_14 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_14[0][0]']
#                                 168)
#
#  conv2d_11 (Conv2D)             (None, None, None,   254184      ['leaky_re_lu_14[0][0]']
#                                 168)
#
#  batch_normalization_15 (BatchN  (None, None, None,   672        ['conv2d_11[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 168)
#
#  conv2d_12 (Conv2D)             (None, None, None,   254184      ['leaky_re_lu_15[0][0]']
#                                 168)
#
#  batch_normalization_16 (BatchN  (None, None, None,   672        ['conv2d_12[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 168)
#
#  add_4 (Add)                    (None, None, None,   0           ['leaky_re_lu_16[0][0]',
#                                 168)                              'conv2d_10[0][0]']
#
#  batch_normalization_17 (BatchN  (None, None, None,   672        ['add_4[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_17 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 168)
#
#  conv2d_13 (Conv2D)             (None, None, None,   254184      ['leaky_re_lu_17[0][0]']
#                                 168)
#
#  batch_normalization_18 (BatchN  (None, None, None,   672        ['conv2d_13[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_18 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 168)
#
#  conv2d_14 (Conv2D)             (None, None, None,   254184      ['leaky_re_lu_18[0][0]']
#                                 168)
#
#  batch_normalization_19 (BatchN  (None, None, None,   672        ['conv2d_14[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 168)
#
#  add_5 (Add)                    (None, None, None,   0           ['leaky_re_lu_19[0][0]',
#                                 168)                              'add_4[0][0]']
#
#  batch_normalization_20 (BatchN  (None, None, None,   672        ['add_5[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_20 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 168)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['leaky_re_lu_20[0][0]']
#                                 168)
#
#  dropout_2 (Dropout)            (None, None, None,   0           ['max_pooling2d_2[0][0]']
#                                 168)
#
#  conv2d_15 (Conv2D)             (None, None, None,   508368      ['dropout_2[0][0]']
#                                 336)
#
#  batch_normalization_21 (BatchN  (None, None, None,   1344       ['conv2d_15[0][0]']
#  ormalization)                  336)
#
#  leaky_re_lu_21 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 336)
#
#  conv2d_16 (Conv2D)             (None, None, None,   1016400     ['leaky_re_lu_21[0][0]']
#                                 336)
#
#  batch_normalization_22 (BatchN  (None, None, None,   1344       ['conv2d_16[0][0]']
#  ormalization)                  336)
#
#  leaky_re_lu_22 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 336)
#
#  conv2d_17 (Conv2D)             (None, None, None,   1016400     ['leaky_re_lu_22[0][0]']
#                                 336)
#
#  batch_normalization_23 (BatchN  (None, None, None,   1344       ['conv2d_17[0][0]']
#  ormalization)                  336)
#
#  leaky_re_lu_23 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 336)
#
#  add_6 (Add)                    (None, None, None,   0           ['leaky_re_lu_23[0][0]',
#                                 336)                              'conv2d_15[0][0]']
#
#  batch_normalization_24 (BatchN  (None, None, None,   1344       ['add_6[0][0]']
#  ormalization)                  336)
#
#  leaky_re_lu_24 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 336)
#
#  conv2d_18 (Conv2D)             (None, None, None,   1016400     ['leaky_re_lu_24[0][0]']
#                                 336)
#
#  batch_normalization_25 (BatchN  (None, None, None,   1344       ['conv2d_18[0][0]']
#  ormalization)                  336)
#
#  leaky_re_lu_25 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 336)
#
#  conv2d_19 (Conv2D)             (None, None, None,   1016400     ['leaky_re_lu_25[0][0]']
#                                 336)
#
#  batch_normalization_26 (BatchN  (None, None, None,   1344       ['conv2d_19[0][0]']
#  ormalization)                  336)
#
#  leaky_re_lu_26 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 336)
#
#  add_7 (Add)                    (None, None, None,   0           ['leaky_re_lu_26[0][0]',
#                                 336)                              'add_6[0][0]']
#
#  batch_normalization_27 (BatchN  (None, None, None,   1344       ['add_7[0][0]']
#  ormalization)                  336)
#
#  leaky_re_lu_27 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 336)
#
#  conv2d_transpose (Conv2DTransp  (None, None, None,   508200     ['leaky_re_lu_27[0][0]']
#  ose)                           168)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['conv2d_transpose[0][0]',
#                                 336)                              'leaky_re_lu_20[0][0]']
#
#  dropout_3 (Dropout)            (None, None, None,   0           ['concatenate[0][0]']
#                                 336)
#
#  conv2d_20 (Conv2D)             (None, None, None,   508200      ['dropout_3[0][0]']
#                                 168)
#
#  batch_normalization_28 (BatchN  (None, None, None,   672        ['conv2d_20[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_28 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 168)
#
#  conv2d_21 (Conv2D)             (None, None, None,   254184      ['leaky_re_lu_28[0][0]']
#                                 168)
#
#  batch_normalization_29 (BatchN  (None, None, None,   672        ['conv2d_21[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_29 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 168)
#
#  conv2d_22 (Conv2D)             (None, None, None,   254184      ['leaky_re_lu_29[0][0]']
#                                 168)
#
#  batch_normalization_30 (BatchN  (None, None, None,   672        ['conv2d_22[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_30 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 168)
#
#  add_8 (Add)                    (None, None, None,   0           ['leaky_re_lu_30[0][0]',
#                                 168)                              'conv2d_20[0][0]']
#
#  batch_normalization_31 (BatchN  (None, None, None,   672        ['add_8[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_31 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 168)
#
#  conv2d_23 (Conv2D)             (None, None, None,   254184      ['leaky_re_lu_31[0][0]']
#                                 168)
#
#  batch_normalization_32 (BatchN  (None, None, None,   672        ['conv2d_23[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_32 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 168)
#
#  conv2d_24 (Conv2D)             (None, None, None,   254184      ['leaky_re_lu_32[0][0]']
#                                 168)
#
#  batch_normalization_33 (BatchN  (None, None, None,   672        ['conv2d_24[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_33 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 168)
#
#  add_9 (Add)                    (None, None, None,   0           ['leaky_re_lu_33[0][0]',
#                                 168)                              'add_8[0][0]']
#
#  batch_normalization_34 (BatchN  (None, None, None,   672        ['add_9[0][0]']
#  ormalization)                  168)
#
#  leaky_re_lu_34 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 168)
#
#  conv2d_transpose_1 (Conv2DTran  (None, None, None,   127092     ['leaky_re_lu_34[0][0]']
#  spose)                         84)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['conv2d_transpose_1[0][0]',
#                                 168)                              'leaky_re_lu_13[0][0]']
#
#  dropout_4 (Dropout)            (None, None, None,   0           ['concatenate_1[0][0]']
#                                 168)
#
#  conv2d_25 (Conv2D)             (None, None, None,   127092      ['dropout_4[0][0]']
#                                 84)
#
#  batch_normalization_35 (BatchN  (None, None, None,   336        ['conv2d_25[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_35 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 84)
#
#  conv2d_26 (Conv2D)             (None, None, None,   63588       ['leaky_re_lu_35[0][0]']
#                                 84)
#
#  batch_normalization_36 (BatchN  (None, None, None,   336        ['conv2d_26[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_36 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 84)
#
#  conv2d_27 (Conv2D)             (None, None, None,   63588       ['leaky_re_lu_36[0][0]']
#                                 84)
#
#  batch_normalization_37 (BatchN  (None, None, None,   336        ['conv2d_27[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_37 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 84)
#
#  add_10 (Add)                   (None, None, None,   0           ['leaky_re_lu_37[0][0]',
#                                 84)                               'conv2d_25[0][0]']
#
#  batch_normalization_38 (BatchN  (None, None, None,   336        ['add_10[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_38 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 84)
#
#  conv2d_28 (Conv2D)             (None, None, None,   63588       ['leaky_re_lu_38[0][0]']
#                                 84)
#
#  batch_normalization_39 (BatchN  (None, None, None,   336        ['conv2d_28[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_39 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 84)
#
#  conv2d_29 (Conv2D)             (None, None, None,   63588       ['leaky_re_lu_39[0][0]']
#                                 84)
#
#  batch_normalization_40 (BatchN  (None, None, None,   336        ['conv2d_29[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_40 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_40[0][0]']
#                                 84)
#
#  add_11 (Add)                   (None, None, None,   0           ['leaky_re_lu_40[0][0]',
#                                 84)                               'add_10[0][0]']
#
#  batch_normalization_41 (BatchN  (None, None, None,   336        ['add_11[0][0]']
#  ormalization)                  84)
#
#  leaky_re_lu_41 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 84)
#
#  conv2d_transpose_2 (Conv2DTran  (None, None, None,   31794      ['leaky_re_lu_41[0][0]']
#  spose)                         42)
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['conv2d_transpose_2[0][0]',
#                                 84)                               'leaky_re_lu_6[0][0]']
#
#  dropout_5 (Dropout)            (None, None, None,   0           ['concatenate_2[0][0]']
#                                 84)
#
#  conv2d_30 (Conv2D)             (None, None, None,   31794       ['dropout_5[0][0]']
#                                 42)
#
#  batch_normalization_42 (BatchN  (None, None, None,   168        ['conv2d_30[0][0]']
#  ormalization)                  42)
#
#  leaky_re_lu_42 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 42)
#
#  conv2d_31 (Conv2D)             (None, None, None,   15918       ['leaky_re_lu_42[0][0]']
#                                 42)
#
#  batch_normalization_43 (BatchN  (None, None, None,   168        ['conv2d_31[0][0]']
#  ormalization)                  42)
#
#  leaky_re_lu_43 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_43[0][0]']
#                                 42)
#
#  conv2d_32 (Conv2D)             (None, None, None,   15918       ['leaky_re_lu_43[0][0]']
#                                 42)
#
#  batch_normalization_44 (BatchN  (None, None, None,   168        ['conv2d_32[0][0]']
#  ormalization)                  42)
#
#  leaky_re_lu_44 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 42)
#
#  add_12 (Add)                   (None, None, None,   0           ['leaky_re_lu_44[0][0]',
#                                 42)                               'conv2d_30[0][0]']
#
#  batch_normalization_45 (BatchN  (None, None, None,   168        ['add_12[0][0]']
#  ormalization)                  42)
#
#  leaky_re_lu_45 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 42)
#
#  conv2d_33 (Conv2D)             (None, None, None,   15918       ['leaky_re_lu_45[0][0]']
#                                 42)
#
#  batch_normalization_46 (BatchN  (None, None, None,   168        ['conv2d_33[0][0]']
#  ormalization)                  42)
#
#  leaky_re_lu_46 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_46[0][0]']
#                                 42)
#
#  conv2d_34 (Conv2D)             (None, None, None,   15918       ['leaky_re_lu_46[0][0]']
#                                 42)
#
#  batch_normalization_47 (BatchN  (None, None, None,   168        ['conv2d_34[0][0]']
#  ormalization)                  42)
#
#  leaky_re_lu_47 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_47[0][0]']
#                                 42)
#
#  add_13 (Add)                   (None, None, None,   0           ['leaky_re_lu_47[0][0]',
#                                 42)                               'add_12[0][0]']
#
#  batch_normalization_48 (BatchN  (None, None, None,   168        ['add_13[0][0]']
#  ormalization)                  42)
#
#  leaky_re_lu_48 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_48[0][0]']
#                                 42)
#
#  conv2d_35 (Conv2D)             (None, None, None,   129         ['leaky_re_lu_48[0][0]']
#                                 3)
#
#  softmax (Softmax)              (None, None, None,   0           ['conv2d_35[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 8,764,227
# Trainable params: 8,751,291
# Non-trainable params: 12,936
# __________________________________________________________________________________________________

# %%
checkpoint_dir = os.path.join(log_dir, 'weights')
os.makedirs(checkpoint_dir, exist_ok=True)
model_checkpoint = ModelCheckpoint(
    os.path.join(checkpoint_dir, FMT_VALMODEL_PATH.format(PREFIX + "_{epoch:04d}")),
    verbose=1,
    save_best_only=False,
    save_weights_only=False)

# %%
model_earlystop = EarlyStopping(
    monitor='val_loss',   #val_jaccard_coef_int
    patience=early_stop,
    verbose=0,
    mode='auto'
)

# %%
model_history = History()

model_board = TensorBoard(
    log_dir=os.path.join(log_dir, 'logs'),
    histogram_freq=0,
    write_graph=True,
    embeddings_freq=0)

# %%
lr_reducer = ReduceLROnPlateau(
factor=np.sqrt(0.1),
verbose=1,
patience=30,
min_lr=0.5e-7)

# %%
fig_dir = os.path.join(log_dir, 'figs')
os.makedirs(fig_dir, exist_ok=True)

def visualize_weight(epoch, model, image_path,mask_path,pos_val):
    INPUT_SIZE = 512
    color = (0,0,0,0)
    list_id = pos_val
    indx= np.random.choice(len(list_id),4)
    x=[]
    y=[]
    for idx in indx: 
        im_name = list_id[idx]
        image_fn = os.path.join(image_path, im_name)
        mask_fn = os.path.join(mask_path, im_name)
        with rasterio.open(image_fn, 'r') as f1:
            width,height = f1.width,f1.height
            new_image_width = new_image_height = max(width,height)
            # if width < 512 and height < 512:
            values = f1.read().transpose(1,2,0)
            x_center = (new_image_width - width) // 2
            y_center = (new_image_height - height) // 2
            result = np.full((new_image_height,new_image_width, 4), color, dtype=np.float16)
            result[y_center:y_center+height, x_center:x_center+width] = values ## REMOVE indices if input 3 channels
            
            if result.dtype == np.float16: pass
            else: result = cv2.resize(result,(INPUT_SIZE, INPUT_SIZE), interpolation = cv2.INTER_CUBIC)
            image = result
            
            with rasterio.open(mask_fn, 'r') as f:
                mask = f.read().astype(np.uint8)
                # onehot_encode = OneHotEncoder(sparse=False)
                # mask = onehot_encode.fit_transform(mask.squeeze(0).reshape(-1,1)).reshape(512, 512, -1)[...,1:3].astype(np.uint8)
                mask_full = np.zeros((INPUT_SIZE, INPUT_SIZE, 3),dtype=np.uint8)
                mask2 = np.array((mask[0]==2).astype(np.uint8)) #255
                mask3 = np.array((mask[0]==3).astype(np.uint8)) #255
                mask1 = ((mask2+mask3)==0).astype(np.uint8)
                mask_full[...,0] = mask1   # 1st band red = backgroud
                mask_full[...,1] = mask2   # 2nd band red = cloud
                mask_full[...,2] = mask3   # 3rd band blue = shadow
                mask = mask_full
                # result_mask = np.full((new_image_height,new_image_width), 0, dtype=np.uint8)
                # result_mask[y_center:y_center+height, x_center:x_center+width] = mask
                # result_mask = cv2.resize(result_mask,(INPUT_SIZE, INPUT_SIZE), interpolation = cv2.INTER_CUBIC).astype(np.uint8)
#                 mask = np.expand_dims(result_mask,axis = -1)
                # mask = result_mask
            x.append(image)
            y.append(mask)
    y_predict = model.predict(np.array(x)/np.finfo(np.float16).max)
    
    import sys

    ressult_predict = []
    for i in range(len(x)):
        predict_mask = y_predict[i].reshape((INPUT_SIZE,INPUT_SIZE, 3))
        predict_mask = np.array(predict_mask).argmax(axis=2)
        new_mask = np.zeros((INPUT_SIZE,INPUT_SIZE, 3), dtype=np.uint8)
        new_mask[...,0] = (predict_mask==0)
        new_mask[...,1] = (predict_mask==1)
        new_mask[...,2] = (predict_mask==2)
        predict_mask = new_mask
        ressult_predict.append(predict_mask)
    fig = plt.figure(figsize=(7, 7))
    rows = 4
    columns = 3
    count = 0
    # if np.random.randint(0, 1000) < 100:
    for i in range(len(x)):
        count = count+1
        image = x[i]
        fig.add_subplot(4, 3, count)
        im_converted = np.array((image/np.finfo(np.float16).max)*255, dtype=np.uint8)
        plt.imshow(im_converted) ## Holy MOLY
#         plt.axis('off')
        plt.title("image_{}".format(str(i)))
        mask = y[i]
        count = count+1
        fig.add_subplot(4, 3, count)
        plt.imshow(np.array(mask)*255)
#         plt.axis('off')
        plt.title("mask_{}".format(str(i)))
        predict = ressult_predict[i]
        count = count+1
        fig.add_subplot(4, 3, count)
        plt.imshow(np.array(predict)*255)
#         plt.axis('off')
        plt.title("result{}".format(str(i)))
    plt.savefig(os.path.join(fig_dir,'line plot{}_epoch{}.jpg'.format(PREFIX,epoch+1)), dpi=200)
    plt.close(fig)

# %%
cwd = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2"
image_path = os.path.join(cwd,r"data/train/image")
mask_path = os.path.join(cwd,r"data/train/label")

val_image_path = os.path.join(cwd,r"data/val/image")
val_mask_path = os.path.join(cwd,r"data/val/label")

# %%
image_list = create_list_id(image_path)

image_list_val = create_list_id(val_image_path)

np.random.shuffle(image_list)
count = len(image_list)    
# cut_idx = int(round(count*split_ratio))    
# train_list = image_list[0:cut_idx]
# val_list = [id_image for id_image in image_list if id_image not in train_list]
train_list = image_list
val_list = image_list_val

visualize_epoch = LambdaCallback(on_epoch_end=lambda epoch, logs: visualize_weight(epoch, unet, image_path, mask_path, train_list))

# %%
num_chanel = INPUT_CHANNEL
batch_size = 2
num_epoch = 300
unet.fit_generator(
    generator= data_gen_not_batch(image_path, mask_path, train_list, augment = True, batch_size = batch_size),
    validation_data = data_gen_not_batch(val_image_path, val_mask_path, val_list, augment = False, batch_size = batch_size, valid = True),
    initial_epoch=0,
    validation_steps = 161,#161
    steps_per_epoch = 300, #len(image_list)//batch_size, ##2
    epochs=num_epoch,
    verbose = 1,
    callbacks=[model_checkpoint, model_earlystop, model_history, model_board, lr_reducer, visualize_epoch],
    max_queue_size=20
)
# Out:
# /tmp/ipykernel_74890/3854121627.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   unet.fit_generator(
# /home/skymap/anaconda3/envs/tf2.7/lib/python3.8/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 1/300
# 2022-10-31 17:06:39.652544: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8500
# 2022-10-31 17:06:40.059703: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2022-10-31 17:06:40.060779: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2022-10-31 17:06:40.060796: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2022-10-31 17:06:40.060860: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-10-31 17:06:42.032180: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.97GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-31 17:06:42.032244: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.97GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 300/300 [==============================] - ETA: 0s - loss: 0.2023 - accuracy: 0.9507 - dice_coef: 0.9199 - dice_coe: 0.9193
# Epoch 00001: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0001_val_weights.h5
# 300/300 [==============================] - 187s 594ms/step - loss: 0.2023 - accuracy: 0.9507 - dice_coef: 0.9199 - dice_coe: 0.9193 - val_loss: 0.1369 - val_accuracy: 0.9624 - val_dice_coef: 0.9544 - val_dice_coe: 0.9543 - lr: 3.0000e-04
# Epoch 2/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0702 - accuracy: 0.9788 - dice_coef: 0.9803 - dice_coe: 0.9799
# Epoch 00002: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0002_val_weights.h5
# 300/300 [==============================] - 186s 619ms/step - loss: 0.0702 - accuracy: 0.9788 - dice_coef: 0.9803 - dice_coe: 0.9799 - val_loss: 0.0598 - val_accuracy: 0.9706 - val_dice_coef: 0.9745 - val_dice_coe: 0.9736 - lr: 3.0000e-04
# Epoch 3/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9859 - dice_coef: 0.9886 - dice_coe: 0.9885
# Epoch 00003: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0003_val_weights.h5
# 300/300 [==============================] - 191s 637ms/step - loss: 0.0397 - accuracy: 0.9859 - dice_coef: 0.9886 - dice_coe: 0.9885 - val_loss: 0.0795 - val_accuracy: 0.9643 - val_dice_coef: 0.9676 - val_dice_coe: 0.9672 - lr: 3.0000e-04
# Epoch 4/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9834 - dice_coef: 0.9862 - dice_coe: 0.9860
# Epoch 00004: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0004_val_weights.h5
# 300/300 [==============================] - 198s 661ms/step - loss: 0.0442 - accuracy: 0.9834 - dice_coef: 0.9862 - dice_coe: 0.9860 - val_loss: 0.0224 - val_accuracy: 0.9941 - val_dice_coef: 0.9945 - val_dice_coe: 0.9944 - lr: 3.0000e-04
# Epoch 5/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0303 - accuracy: 0.9858 - dice_coef: 0.9891 - dice_coe: 0.9889
# Epoch 00005: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0005_val_weights.h5
# 300/300 [==============================] - 197s 656ms/step - loss: 0.0303 - accuracy: 0.9858 - dice_coef: 0.9891 - dice_coe: 0.9889 - val_loss: 0.0320 - val_accuracy: 0.9833 - val_dice_coef: 0.9864 - val_dice_coe: 0.9860 - lr: 3.0000e-04
# Epoch 6/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9866 - dice_coef: 0.9896 - dice_coe: 0.9894
# Epoch 00006: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0006_val_weights.h5
# 300/300 [==============================] - 204s 681ms/step - loss: 0.0271 - accuracy: 0.9866 - dice_coef: 0.9896 - dice_coe: 0.9894 - val_loss: 0.0660 - val_accuracy: 0.9721 - val_dice_coef: 0.9772 - val_dice_coe: 0.9763 - lr: 3.0000e-04
# Epoch 7/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9857 - dice_coef: 0.9890 - dice_coe: 0.9889
# Epoch 00007: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0007_val_weights.h5
# 300/300 [==============================] - 185s 617ms/step - loss: 0.0293 - accuracy: 0.9857 - dice_coef: 0.9890 - dice_coe: 0.9889 - val_loss: 0.0161 - val_accuracy: 0.9904 - val_dice_coef: 0.9931 - val_dice_coe: 0.9929 - lr: 3.0000e-04
# Epoch 8/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9864 - dice_coef: 0.9897 - dice_coe: 0.9895
# Epoch 00008: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0008_val_weights.h5
# 300/300 [==============================] - 180s 601ms/step - loss: 0.0253 - accuracy: 0.9864 - dice_coef: 0.9897 - dice_coe: 0.9895 - val_loss: 0.0210 - val_accuracy: 0.9934 - val_dice_coef: 0.9945 - val_dice_coe: 0.9943 - lr: 3.0000e-04
# Epoch 9/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9851 - dice_coef: 0.9883 - dice_coe: 0.9882
# Epoch 00009: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0009_val_weights.h5
# 300/300 [==============================] - 177s 590ms/step - loss: 0.0299 - accuracy: 0.9851 - dice_coef: 0.9883 - dice_coe: 0.9882 - val_loss: 0.0264 - val_accuracy: 0.9868 - val_dice_coef: 0.9895 - val_dice_coe: 0.9891 - lr: 3.0000e-04
# Epoch 10/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9881 - dice_coef: 0.9911 - dice_coe: 0.9910
# Epoch 00010: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0010_val_weights.h5
# 300/300 [==============================] - 179s 597ms/step - loss: 0.0211 - accuracy: 0.9881 - dice_coef: 0.9911 - dice_coe: 0.9910 - val_loss: 0.0173 - val_accuracy: 0.9907 - val_dice_coef: 0.9929 - val_dice_coe: 0.9927 - lr: 3.0000e-04
# Epoch 11/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9894 - dice_coef: 0.9922 - dice_coe: 0.9921
# Epoch 00011: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0011_val_weights.h5
# 300/300 [==============================] - 180s 599ms/step - loss: 0.0184 - accuracy: 0.9894 - dice_coef: 0.9922 - dice_coe: 0.9921 - val_loss: 0.0096 - val_accuracy: 0.9944 - val_dice_coef: 0.9959 - val_dice_coe: 0.9958 - lr: 3.0000e-04
# Epoch 12/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9860 - dice_coef: 0.9893 - dice_coe: 0.9891
# Epoch 00012: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0012_val_weights.h5
# 300/300 [==============================] - 178s 592ms/step - loss: 0.0259 - accuracy: 0.9860 - dice_coef: 0.9893 - dice_coe: 0.9891 - val_loss: 0.0116 - val_accuracy: 0.9940 - val_dice_coef: 0.9953 - val_dice_coe: 0.9952 - lr: 3.0000e-04
# Epoch 13/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9886 - dice_coef: 0.9917 - dice_coe: 0.9916
# Epoch 00013: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0013_val_weights.h5
# 300/300 [==============================] - 179s 599ms/step - loss: 0.0189 - accuracy: 0.9886 - dice_coef: 0.9917 - dice_coe: 0.9916 - val_loss: 0.0126 - val_accuracy: 0.9928 - val_dice_coef: 0.9946 - val_dice_coe: 0.9945 - lr: 3.0000e-04
# Epoch 14/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9888 - dice_coef: 0.9916 - dice_coe: 0.9915
# Epoch 00014: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0014_val_weights.h5
# 300/300 [==============================] - 180s 600ms/step - loss: 0.0192 - accuracy: 0.9888 - dice_coef: 0.9916 - dice_coe: 0.9915 - val_loss: 0.1341 - val_accuracy: 0.9586 - val_dice_coef: 0.9426 - val_dice_coe: 0.9410 - lr: 3.0000e-04
# Epoch 15/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9849 - dice_coef: 0.9880 - dice_coe: 0.9879
# Epoch 00015: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0015_val_weights.h5
# 300/300 [==============================] - 185s 618ms/step - loss: 0.0352 - accuracy: 0.9849 - dice_coef: 0.9880 - dice_coe: 0.9879 - val_loss: 0.0753 - val_accuracy: 0.9792 - val_dice_coef: 0.9802 - val_dice_coe: 0.9802 - lr: 3.0000e-04
# Epoch 16/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9888 - dice_coef: 0.9917 - dice_coe: 0.9916
# Epoch 00016: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0016_val_weights.h5
# 300/300 [==============================] - 191s 636ms/step - loss: 0.0190 - accuracy: 0.9888 - dice_coef: 0.9917 - dice_coe: 0.9916 - val_loss: 0.0130 - val_accuracy: 0.9948 - val_dice_coef: 0.9957 - val_dice_coe: 0.9957 - lr: 3.0000e-04
# Epoch 17/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9911 - dice_coef: 0.9935 - dice_coe: 0.9935
# Epoch 00017: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0017_val_weights.h5
# 300/300 [==============================] - 181s 603ms/step - loss: 0.0147 - accuracy: 0.9911 - dice_coef: 0.9935 - dice_coe: 0.9935 - val_loss: 0.0102 - val_accuracy: 0.9933 - val_dice_coef: 0.9953 - val_dice_coe: 0.9952 - lr: 3.0000e-04
# Epoch 18/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9910 - dice_coef: 0.9933 - dice_coe: 0.9932
# Epoch 00018: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0018_val_weights.h5
# 300/300 [==============================] - 179s 596ms/step - loss: 0.0153 - accuracy: 0.9910 - dice_coef: 0.9933 - dice_coe: 0.9932 - val_loss: 0.0055 - val_accuracy: 0.9970 - val_dice_coef: 0.9977 - val_dice_coe: 0.9977 - lr: 3.0000e-04
# Epoch 19/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9896 - dice_coef: 0.9923 - dice_coe: 0.9922
# Epoch 00019: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0019_val_weights.h5
# 300/300 [==============================] - 179s 597ms/step - loss: 0.0174 - accuracy: 0.9896 - dice_coef: 0.9923 - dice_coe: 0.9922 - val_loss: 0.0112 - val_accuracy: 0.9959 - val_dice_coef: 0.9965 - val_dice_coe: 0.9965 - lr: 3.0000e-04
# Epoch 20/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9904 - dice_coef: 0.9928 - dice_coe: 0.9928
# Epoch 00020: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0020_val_weights.h5
# 300/300 [==============================] - 189s 629ms/step - loss: 0.0162 - accuracy: 0.9904 - dice_coef: 0.9928 - dice_coe: 0.9928 - val_loss: 0.0151 - val_accuracy: 0.9922 - val_dice_coef: 0.9939 - val_dice_coe: 0.9938 - lr: 3.0000e-04
# Epoch 21/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9888 - dice_coef: 0.9917 - dice_coe: 0.9916
# Epoch 00021: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0021_val_weights.h5
# 300/300 [==============================] - 187s 624ms/step - loss: 0.0188 - accuracy: 0.9888 - dice_coef: 0.9917 - dice_coe: 0.9916 - val_loss: 0.0598 - val_accuracy: 0.9821 - val_dice_coef: 0.9800 - val_dice_coe: 0.9795 - lr: 3.0000e-04
# Epoch 22/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9894 - dice_coef: 0.9921 - dice_coe: 0.9920
# Epoch 00022: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0022_val_weights.h5
# 300/300 [==============================] - 187s 625ms/step - loss: 0.0180 - accuracy: 0.9894 - dice_coef: 0.9921 - dice_coe: 0.9920 - val_loss: 0.0156 - val_accuracy: 0.9906 - val_dice_coef: 0.9928 - val_dice_coe: 0.9925 - lr: 3.0000e-04
# Epoch 23/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9907 - dice_coef: 0.9930 - dice_coe: 0.9930
# Epoch 00023: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0023_val_weights.h5
# 300/300 [==============================] - 181s 602ms/step - loss: 0.0159 - accuracy: 0.9907 - dice_coef: 0.9930 - dice_coe: 0.9930 - val_loss: 0.0156 - val_accuracy: 0.9913 - val_dice_coef: 0.9931 - val_dice_coe: 0.9929 - lr: 3.0000e-04
# Epoch 24/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9880 - dice_coef: 0.9909 - dice_coe: 0.9908
# Epoch 00024: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0024_val_weights.h5
# 300/300 [==============================] - 178s 594ms/step - loss: 0.0204 - accuracy: 0.9880 - dice_coef: 0.9909 - dice_coe: 0.9908 - val_loss: 0.0109 - val_accuracy: 0.9940 - val_dice_coef: 0.9954 - val_dice_coe: 0.9953 - lr: 3.0000e-04
# Epoch 25/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9860 - dice_coef: 0.9893 - dice_coe: 0.9891
# Epoch 00025: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0025_val_weights.h5
# 300/300 [==============================] - 178s 595ms/step - loss: 0.0251 - accuracy: 0.9860 - dice_coef: 0.9893 - dice_coe: 0.9891 - val_loss: 0.0249 - val_accuracy: 0.9929 - val_dice_coef: 0.9924 - val_dice_coe: 0.9923 - lr: 3.0000e-04
# Epoch 26/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9897 - dice_coef: 0.9924 - dice_coe: 0.9923
# Epoch 00026: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0026_val_weights.h5
# 300/300 [==============================] - 177s 591ms/step - loss: 0.0172 - accuracy: 0.9897 - dice_coef: 0.9924 - dice_coe: 0.9923 - val_loss: 0.0137 - val_accuracy: 0.9920 - val_dice_coef: 0.9941 - val_dice_coe: 0.9940 - lr: 3.0000e-04
# Epoch 27/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9883 - dice_coef: 0.9912 - dice_coe: 0.9911
# Epoch 00027: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0027_val_weights.h5
# 300/300 [==============================] - 179s 597ms/step - loss: 0.0201 - accuracy: 0.9883 - dice_coef: 0.9912 - dice_coe: 0.9911 - val_loss: 0.0120 - val_accuracy: 0.9959 - val_dice_coef: 0.9963 - val_dice_coe: 0.9962 - lr: 3.0000e-04
# Epoch 28/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9910 - dice_coef: 0.9934 - dice_coe: 0.9934
# Epoch 00028: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0028_val_weights.h5
# 300/300 [==============================] - 179s 596ms/step - loss: 0.0147 - accuracy: 0.9910 - dice_coef: 0.9934 - dice_coe: 0.9934 - val_loss: 0.0167 - val_accuracy: 0.9901 - val_dice_coef: 0.9924 - val_dice_coe: 0.9923 - lr: 3.0000e-04
# Epoch 29/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9911 - dice_coef: 0.9935 - dice_coe: 0.9934
# Epoch 00029: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0029_val_weights.h5
# 300/300 [==============================] - 176s 587ms/step - loss: 0.0144 - accuracy: 0.9911 - dice_coef: 0.9935 - dice_coe: 0.9934 - val_loss: 0.0199 - val_accuracy: 0.9900 - val_dice_coef: 0.9920 - val_dice_coe: 0.9918 - lr: 3.0000e-04
# Epoch 30/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9903 - dice_coef: 0.9929 - dice_coe: 0.9929
# Epoch 00030: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0030_val_weights.h5
# 300/300 [==============================] - 178s 592ms/step - loss: 0.0156 - accuracy: 0.9903 - dice_coef: 0.9929 - dice_coe: 0.9929 - val_loss: 0.0089 - val_accuracy: 0.9949 - val_dice_coef: 0.9961 - val_dice_coe: 0.9961 - lr: 3.0000e-04
# Epoch 31/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9904 - dice_coef: 0.9930 - dice_coe: 0.9929
# Epoch 00031: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0031_val_weights.h5
# 300/300 [==============================] - 178s 595ms/step - loss: 0.0156 - accuracy: 0.9904 - dice_coef: 0.9930 - dice_coe: 0.9929 - val_loss: 0.0288 - val_accuracy: 0.9883 - val_dice_coef: 0.9897 - val_dice_coe: 0.9895 - lr: 3.0000e-04
# Epoch 32/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9901 - dice_coef: 0.9928 - dice_coe: 0.9927
# Epoch 00032: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0032_val_weights.h5
# 300/300 [==============================] - 179s 598ms/step - loss: 0.0161 - accuracy: 0.9901 - dice_coef: 0.9928 - dice_coe: 0.9927 - val_loss: 0.0072 - val_accuracy: 0.9964 - val_dice_coef: 0.9972 - val_dice_coe: 0.9971 - lr: 3.0000e-04
# Epoch 33/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9922 - dice_coef: 0.9944 - dice_coe: 0.9943
# Epoch 00033: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0033_val_weights.h5
# 300/300 [==============================] - 176s 586ms/step - loss: 0.0123 - accuracy: 0.9922 - dice_coef: 0.9944 - dice_coe: 0.9943 - val_loss: 0.0069 - val_accuracy: 0.9958 - val_dice_coef: 0.9969 - val_dice_coe: 0.9969 - lr: 3.0000e-04
# Epoch 34/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9869 - dice_coef: 0.9898 - dice_coe: 0.9896
# Epoch 00034: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0034_val_weights.h5
# 300/300 [==============================] - 178s 595ms/step - loss: 0.0259 - accuracy: 0.9869 - dice_coef: 0.9898 - dice_coe: 0.9896 - val_loss: 0.0075 - val_accuracy: 0.9959 - val_dice_coef: 0.9969 - val_dice_coe: 0.9969 - lr: 3.0000e-04
# Epoch 35/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9912 - dice_coef: 0.9935 - dice_coe: 0.9934
# Epoch 00035: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0035_val_weights.h5
# 300/300 [==============================] - 190s 636ms/step - loss: 0.0147 - accuracy: 0.9912 - dice_coef: 0.9935 - dice_coe: 0.9934 - val_loss: 0.0203 - val_accuracy: 0.9909 - val_dice_coef: 0.9923 - val_dice_coe: 0.9921 - lr: 3.0000e-04
# Epoch 36/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9908 - dice_coef: 0.9932 - dice_coe: 0.9932
# Epoch 00036: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0036_val_weights.h5
# 300/300 [==============================] - 194s 649ms/step - loss: 0.0156 - accuracy: 0.9908 - dice_coef: 0.9932 - dice_coe: 0.9932 - val_loss: 0.0495 - val_accuracy: 0.9808 - val_dice_coef: 0.9836 - val_dice_coe: 0.9833 - lr: 3.0000e-04
# Epoch 37/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9889 - dice_coef: 0.9918 - dice_coe: 0.9917
# Epoch 00037: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0037_val_weights.h5
# 300/300 [==============================] - 181s 604ms/step - loss: 0.0184 - accuracy: 0.9889 - dice_coef: 0.9918 - dice_coe: 0.9917 - val_loss: 0.0101 - val_accuracy: 0.9943 - val_dice_coef: 0.9961 - val_dice_coe: 0.9960 - lr: 3.0000e-04
# Epoch 38/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9905 - dice_coef: 0.9931 - dice_coe: 0.9931
# Epoch 00038: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0038_val_weights.h5
# 300/300 [==============================] - 182s 606ms/step - loss: 0.0151 - accuracy: 0.9905 - dice_coef: 0.9931 - dice_coe: 0.9931 - val_loss: 0.0391 - val_accuracy: 0.9880 - val_dice_coef: 0.9891 - val_dice_coe: 0.9890 - lr: 3.0000e-04
# Epoch 39/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9910 - dice_coef: 0.9935 - dice_coe: 0.9934
# Epoch 00039: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0039_val_weights.h5
# 300/300 [==============================] - 179s 596ms/step - loss: 0.0144 - accuracy: 0.9910 - dice_coef: 0.9935 - dice_coe: 0.9934 - val_loss: 0.0477 - val_accuracy: 0.9861 - val_dice_coef: 0.9872 - val_dice_coe: 0.9870 - lr: 3.0000e-04
# Epoch 40/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9931 - dice_coef: 0.9949 - dice_coe: 0.9949
# Epoch 00040: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0040_val_weights.h5
# 300/300 [==============================] - 177s 591ms/step - loss: 0.0114 - accuracy: 0.9931 - dice_coef: 0.9949 - dice_coe: 0.9949 - val_loss: 0.0080 - val_accuracy: 0.9961 - val_dice_coef: 0.9969 - val_dice_coe: 0.9968 - lr: 3.0000e-04
# Epoch 41/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9933 - dice_coef: 0.9952 - dice_coe: 0.9951
# Epoch 00041: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0041_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0106 - accuracy: 0.9933 - dice_coef: 0.9952 - dice_coe: 0.9951 - val_loss: 0.0122 - val_accuracy: 0.9919 - val_dice_coef: 0.9942 - val_dice_coe: 0.9941 - lr: 3.0000e-04
# Epoch 42/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9924 - dice_coef: 0.9945 - dice_coe: 0.9944
# Epoch 00042: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0042_val_weights.h5
# 300/300 [==============================] - 183s 609ms/step - loss: 0.0122 - accuracy: 0.9924 - dice_coef: 0.9945 - dice_coe: 0.9944 - val_loss: 0.0062 - val_accuracy: 0.9964 - val_dice_coef: 0.9973 - val_dice_coe: 0.9973 - lr: 3.0000e-04
# Epoch 43/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9904 - dice_coef: 0.9928 - dice_coe: 0.9928
# Epoch 00043: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0043_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0173 - accuracy: 0.9904 - dice_coef: 0.9928 - dice_coe: 0.9928 - val_loss: 0.0088 - val_accuracy: 0.9946 - val_dice_coef: 0.9960 - val_dice_coe: 0.9960 - lr: 3.0000e-04
# Epoch 44/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9897 - dice_coef: 0.9923 - dice_coe: 0.9922
# Epoch 00044: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0044_val_weights.h5
# 300/300 [==============================] - 180s 601ms/step - loss: 0.0184 - accuracy: 0.9897 - dice_coef: 0.9923 - dice_coe: 0.9922 - val_loss: 0.0120 - val_accuracy: 0.9937 - val_dice_coef: 0.9951 - val_dice_coe: 0.9951 - lr: 3.0000e-04
# Epoch 45/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9911 - dice_coef: 0.9934 - dice_coe: 0.9933
# Epoch 00045: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0045_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0147 - accuracy: 0.9911 - dice_coef: 0.9934 - dice_coe: 0.9933 - val_loss: 0.0106 - val_accuracy: 0.9949 - val_dice_coef: 0.9960 - val_dice_coe: 0.9959 - lr: 3.0000e-04
# Epoch 46/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9925 - dice_coef: 0.9945 - dice_coe: 0.9945
# Epoch 00046: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0046_val_weights.h5
# 300/300 [==============================] - 177s 590ms/step - loss: 0.0123 - accuracy: 0.9925 - dice_coef: 0.9945 - dice_coe: 0.9945 - val_loss: 0.0070 - val_accuracy: 0.9959 - val_dice_coef: 0.9969 - val_dice_coe: 0.9969 - lr: 3.0000e-04
# Epoch 47/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9915 - dice_coef: 0.9938 - dice_coe: 0.9938
# Epoch 00047: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0047_val_weights.h5
# 300/300 [==============================] - 177s 590ms/step - loss: 0.0139 - accuracy: 0.9915 - dice_coef: 0.9938 - dice_coe: 0.9938 - val_loss: 0.0069 - val_accuracy: 0.9957 - val_dice_coef: 0.9970 - val_dice_coe: 0.9969 - lr: 3.0000e-04
# Epoch 48/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9902 - dice_coef: 0.9928 - dice_coe: 0.9928
# Epoch 00048: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0048_val_weights.h5
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 9.486833431105525e-05.
# 300/300 [==============================] - 174s 582ms/step - loss: 0.0159 - accuracy: 0.9902 - dice_coef: 0.9928 - dice_coe: 0.9928 - val_loss: 0.0144 - val_accuracy: 0.9922 - val_dice_coef: 0.9938 - val_dice_coe: 0.9936 - lr: 3.0000e-04
# Epoch 49/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9926 - dice_coef: 0.9945 - dice_coe: 0.9945
# Epoch 00049: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0049_val_weights.h5
# 300/300 [==============================] - 179s 597ms/step - loss: 0.0123 - accuracy: 0.9926 - dice_coef: 0.9945 - dice_coe: 0.9945 - val_loss: 0.0060 - val_accuracy: 0.9966 - val_dice_coef: 0.9975 - val_dice_coe: 0.9974 - lr: 9.4868e-05
# Epoch 50/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9919 - dice_coef: 0.9941 - dice_coe: 0.9941
# Epoch 00050: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0050_val_weights.h5
# 300/300 [==============================] - 176s 586ms/step - loss: 0.0128 - accuracy: 0.9919 - dice_coef: 0.9941 - dice_coe: 0.9941 - val_loss: 0.0068 - val_accuracy: 0.9959 - val_dice_coef: 0.9969 - val_dice_coe: 0.9969 - lr: 9.4868e-05
# Epoch 51/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9917 - dice_coef: 0.9941 - dice_coe: 0.9940
# Epoch 00051: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0051_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0129 - accuracy: 0.9917 - dice_coef: 0.9941 - dice_coe: 0.9940 - val_loss: 0.0051 - val_accuracy: 0.9971 - val_dice_coef: 0.9979 - val_dice_coe: 0.9978 - lr: 9.4868e-05
# Epoch 52/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9928 - dice_coef: 0.9948 - dice_coe: 0.9948
# Epoch 00052: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0052_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0113 - accuracy: 0.9928 - dice_coef: 0.9948 - dice_coe: 0.9948 - val_loss: 0.0057 - val_accuracy: 0.9966 - val_dice_coef: 0.9975 - val_dice_coe: 0.9975 - lr: 9.4868e-05
# Epoch 53/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9935 - dice_coef: 0.9953 - dice_coe: 0.9953
# Epoch 00053: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0053_val_weights.h5
# 300/300 [==============================] - 177s 592ms/step - loss: 0.0103 - accuracy: 0.9935 - dice_coef: 0.9953 - dice_coe: 0.9953 - val_loss: 0.0058 - val_accuracy: 0.9966 - val_dice_coef: 0.9975 - val_dice_coe: 0.9975 - lr: 9.4868e-05
# Epoch 54/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9927 - dice_coef: 0.9947 - dice_coe: 0.9947
# Epoch 00054: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0054_val_weights.h5
# 300/300 [==============================] - 176s 589ms/step - loss: 0.0115 - accuracy: 0.9927 - dice_coef: 0.9947 - dice_coe: 0.9947 - val_loss: 0.0049 - val_accuracy: 0.9971 - val_dice_coef: 0.9979 - val_dice_coe: 0.9979 - lr: 9.4868e-05
# Epoch 55/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9936 - dice_coef: 0.9953 - dice_coe: 0.9953
# Epoch 00055: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0055_val_weights.h5
# 300/300 [==============================] - 176s 588ms/step - loss: 0.0103 - accuracy: 0.9936 - dice_coef: 0.9953 - dice_coe: 0.9953 - val_loss: 0.0038 - val_accuracy: 0.9977 - val_dice_coef: 0.9983 - val_dice_coe: 0.9983 - lr: 9.4868e-05
# Epoch 56/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9925 - dice_coef: 0.9945 - dice_coe: 0.9944
# Epoch 00056: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0056_val_weights.h5
# 300/300 [==============================] - 177s 589ms/step - loss: 0.0125 - accuracy: 0.9925 - dice_coef: 0.9945 - dice_coe: 0.9944 - val_loss: 0.0155 - val_accuracy: 0.9947 - val_dice_coef: 0.9946 - val_dice_coe: 0.9946 - lr: 9.4868e-05
# Epoch 57/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9931 - dice_coef: 0.9951 - dice_coe: 0.9950
# Epoch 00057: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0057_val_weights.h5
# 300/300 [==============================] - 177s 591ms/step - loss: 0.0108 - accuracy: 0.9931 - dice_coef: 0.9951 - dice_coe: 0.9950 - val_loss: 0.0076 - val_accuracy: 0.9952 - val_dice_coef: 0.9965 - val_dice_coe: 0.9964 - lr: 9.4868e-05
# Epoch 58/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9906 - dice_coef: 0.9929 - dice_coe: 0.9928
# Epoch 00058: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0058_val_weights.h5
# 300/300 [==============================] - 178s 595ms/step - loss: 0.0179 - accuracy: 0.9906 - dice_coef: 0.9929 - dice_coe: 0.9928 - val_loss: 0.0128 - val_accuracy: 0.9919 - val_dice_coef: 0.9940 - val_dice_coe: 0.9939 - lr: 9.4868e-05
# Epoch 59/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9930 - dice_coef: 0.9950 - dice_coe: 0.9950
# Epoch 00059: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0059_val_weights.h5
# 300/300 [==============================] - 181s 603ms/step - loss: 0.0110 - accuracy: 0.9930 - dice_coef: 0.9950 - dice_coe: 0.9950 - val_loss: 0.0038 - val_accuracy: 0.9977 - val_dice_coef: 0.9984 - val_dice_coe: 0.9984 - lr: 9.4868e-05
# Epoch 60/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9927 - dice_coef: 0.9948 - dice_coe: 0.9947
# Epoch 00060: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0060_val_weights.h5
# 300/300 [==============================] - 177s 589ms/step - loss: 0.0115 - accuracy: 0.9927 - dice_coef: 0.9948 - dice_coe: 0.9947 - val_loss: 0.0060 - val_accuracy: 0.9964 - val_dice_coef: 0.9974 - val_dice_coe: 0.9974 - lr: 9.4868e-05
# Epoch 61/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9911 - dice_coef: 0.9932 - dice_coe: 0.9932
# Epoch 00061: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0061_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0195 - accuracy: 0.9911 - dice_coef: 0.9932 - dice_coe: 0.9932 - val_loss: 0.0105 - val_accuracy: 0.9937 - val_dice_coef: 0.9955 - val_dice_coe: 0.9954 - lr: 9.4868e-05
# Epoch 62/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9927 - dice_coef: 0.9947 - dice_coe: 0.9947
# Epoch 00062: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0062_val_weights.h5
# 300/300 [==============================] - 181s 604ms/step - loss: 0.0116 - accuracy: 0.9927 - dice_coef: 0.9947 - dice_coe: 0.9947 - val_loss: 0.0046 - val_accuracy: 0.9975 - val_dice_coef: 0.9981 - val_dice_coe: 0.9981 - lr: 9.4868e-05
# Epoch 63/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9928 - dice_coef: 0.9948 - dice_coe: 0.9948
# Epoch 00063: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0063_val_weights.h5
# 300/300 [==============================] - 178s 594ms/step - loss: 0.0113 - accuracy: 0.9928 - dice_coef: 0.9948 - dice_coe: 0.9948 - val_loss: 0.0051 - val_accuracy: 0.9969 - val_dice_coef: 0.9978 - val_dice_coe: 0.9977 - lr: 9.4868e-05
# Epoch 64/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9925 - dice_coef: 0.9947 - dice_coe: 0.9946
# Epoch 00064: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0064_val_weights.h5
# 300/300 [==============================] - 177s 592ms/step - loss: 0.0116 - accuracy: 0.9925 - dice_coef: 0.9947 - dice_coe: 0.9946 - val_loss: 0.0041 - val_accuracy: 0.9978 - val_dice_coef: 0.9983 - val_dice_coe: 0.9983 - lr: 9.4868e-05
# Epoch 65/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9924 - dice_coef: 0.9946 - dice_coe: 0.9946
# Epoch 00065: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0065_val_weights.h5
# 300/300 [==============================] - 178s 594ms/step - loss: 0.0118 - accuracy: 0.9924 - dice_coef: 0.9946 - dice_coe: 0.9946 - val_loss: 0.0049 - val_accuracy: 0.9969 - val_dice_coef: 0.9978 - val_dice_coe: 0.9977 - lr: 9.4868e-05
# Epoch 66/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9934 - dice_coef: 0.9953 - dice_coe: 0.9952
# Epoch 00066: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0066_val_weights.h5
# 300/300 [==============================] - 179s 597ms/step - loss: 0.0106 - accuracy: 0.9934 - dice_coef: 0.9953 - dice_coe: 0.9952 - val_loss: 0.0052 - val_accuracy: 0.9970 - val_dice_coef: 0.9978 - val_dice_coe: 0.9977 - lr: 9.4868e-05
# Epoch 67/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9927 - dice_coef: 0.9948 - dice_coe: 0.9947
# Epoch 00067: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0067_val_weights.h5
# 300/300 [==============================] - 184s 615ms/step - loss: 0.0113 - accuracy: 0.9927 - dice_coef: 0.9948 - dice_coe: 0.9947 - val_loss: 0.0052 - val_accuracy: 0.9972 - val_dice_coef: 0.9978 - val_dice_coe: 0.9978 - lr: 9.4868e-05
# Epoch 68/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9932 - dice_coef: 0.9951 - dice_coe: 0.9951
# Epoch 00068: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0068_val_weights.h5
# 300/300 [==============================] - 191s 637ms/step - loss: 0.0107 - accuracy: 0.9932 - dice_coef: 0.9951 - dice_coe: 0.9951 - val_loss: 0.0040 - val_accuracy: 0.9974 - val_dice_coef: 0.9982 - val_dice_coe: 0.9982 - lr: 9.4868e-05
# Epoch 69/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9932 - dice_coef: 0.9952 - dice_coe: 0.9951
# Epoch 00069: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0069_val_weights.h5
# 300/300 [==============================] - 181s 604ms/step - loss: 0.0106 - accuracy: 0.9932 - dice_coef: 0.9952 - dice_coe: 0.9951 - val_loss: 0.0048 - val_accuracy: 0.9969 - val_dice_coef: 0.9978 - val_dice_coe: 0.9978 - lr: 9.4868e-05
# Epoch 70/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9942 - dice_coef: 0.9958 - dice_coe: 0.9958
# Epoch 00070: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0070_val_weights.h5
# 300/300 [==============================] - 178s 595ms/step - loss: 0.0092 - accuracy: 0.9942 - dice_coef: 0.9958 - dice_coe: 0.9958 - val_loss: 0.0031 - val_accuracy: 0.9980 - val_dice_coef: 0.9986 - val_dice_coe: 0.9986 - lr: 9.4868e-05
# Epoch 71/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9932 - dice_coef: 0.9952 - dice_coe: 0.9952
# Epoch 00071: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0071_val_weights.h5
# 300/300 [==============================] - 177s 591ms/step - loss: 0.0104 - accuracy: 0.9932 - dice_coef: 0.9952 - dice_coe: 0.9952 - val_loss: 0.0062 - val_accuracy: 0.9957 - val_dice_coef: 0.9971 - val_dice_coe: 0.9970 - lr: 9.4868e-05
# Epoch 72/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9929 - dice_coef: 0.9948 - dice_coe: 0.9948
# Epoch 00072: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0072_val_weights.h5
# 300/300 [==============================] - 178s 594ms/step - loss: 0.0114 - accuracy: 0.9929 - dice_coef: 0.9948 - dice_coe: 0.9948 - val_loss: 0.0048 - val_accuracy: 0.9973 - val_dice_coef: 0.9979 - val_dice_coe: 0.9979 - lr: 9.4868e-05
# Epoch 73/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9921 - dice_coef: 0.9944 - dice_coe: 0.9943
# Epoch 00073: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0073_val_weights.h5
# 300/300 [==============================] - 177s 591ms/step - loss: 0.0123 - accuracy: 0.9921 - dice_coef: 0.9944 - dice_coe: 0.9943 - val_loss: 0.0090 - val_accuracy: 0.9951 - val_dice_coef: 0.9963 - val_dice_coe: 0.9963 - lr: 9.4868e-05
# Epoch 74/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9938 - dice_coef: 0.9955 - dice_coe: 0.9955
# Epoch 00074: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0074_val_weights.h5
# 300/300 [==============================] - 183s 610ms/step - loss: 0.0098 - accuracy: 0.9938 - dice_coef: 0.9955 - dice_coe: 0.9955 - val_loss: 0.0054 - val_accuracy: 0.9966 - val_dice_coef: 0.9976 - val_dice_coe: 0.9976 - lr: 9.4868e-05
# Epoch 75/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9935 - dice_coef: 0.9954 - dice_coe: 0.9953
# Epoch 00075: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0075_val_weights.h5
# 300/300 [==============================] - 177s 590ms/step - loss: 0.0101 - accuracy: 0.9935 - dice_coef: 0.9954 - dice_coe: 0.9953 - val_loss: 0.0055 - val_accuracy: 0.9963 - val_dice_coef: 0.9975 - val_dice_coe: 0.9974 - lr: 9.4868e-05
# Epoch 76/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9929 - dice_coef: 0.9950 - dice_coe: 0.9949
# Epoch 00076: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0076_val_weights.h5
# 300/300 [==============================] - 179s 598ms/step - loss: 0.0109 - accuracy: 0.9929 - dice_coef: 0.9950 - dice_coe: 0.9949 - val_loss: 0.0066 - val_accuracy: 0.9958 - val_dice_coef: 0.9970 - val_dice_coe: 0.9969 - lr: 9.4868e-05
# Epoch 77/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9932 - dice_coef: 0.9952 - dice_coe: 0.9951
# Epoch 00077: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0077_val_weights.h5
# 300/300 [==============================] - 175s 585ms/step - loss: 0.0104 - accuracy: 0.9932 - dice_coef: 0.9952 - dice_coe: 0.9951 - val_loss: 0.0070 - val_accuracy: 0.9953 - val_dice_coef: 0.9968 - val_dice_coe: 0.9967 - lr: 9.4868e-05
# Epoch 78/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9926 - dice_coef: 0.9948 - dice_coe: 0.9947
# Epoch 00078: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0078_val_weights.h5
# 300/300 [==============================] - 176s 589ms/step - loss: 0.0113 - accuracy: 0.9926 - dice_coef: 0.9948 - dice_coe: 0.9947 - val_loss: 0.0106 - val_accuracy: 0.9940 - val_dice_coef: 0.9954 - val_dice_coe: 0.9953 - lr: 9.4868e-05
# Epoch 79/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9937 - dice_coef: 0.9956 - dice_coe: 0.9956
# Epoch 00079: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0079_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0094 - accuracy: 0.9937 - dice_coef: 0.9956 - dice_coe: 0.9956 - val_loss: 0.0038 - val_accuracy: 0.9978 - val_dice_coef: 0.9984 - val_dice_coe: 0.9984 - lr: 9.4868e-05
# Epoch 80/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9902 - dice_coef: 0.9927 - dice_coe: 0.9926
# Epoch 00080: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0080_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0164 - accuracy: 0.9902 - dice_coef: 0.9927 - dice_coe: 0.9926 - val_loss: 0.0059 - val_accuracy: 0.9962 - val_dice_coef: 0.9974 - val_dice_coe: 0.9973 - lr: 9.4868e-05
# Epoch 81/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9925 - dice_coef: 0.9946 - dice_coe: 0.9945
# Epoch 00081: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0081_val_weights.h5
# 300/300 [==============================] - 178s 595ms/step - loss: 0.0118 - accuracy: 0.9925 - dice_coef: 0.9946 - dice_coe: 0.9945 - val_loss: 0.0058 - val_accuracy: 0.9966 - val_dice_coef: 0.9976 - val_dice_coe: 0.9976 - lr: 9.4868e-05
# Epoch 82/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9932 - dice_coef: 0.9952 - dice_coe: 0.9952
# Epoch 00082: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0082_val_weights.h5
# 300/300 [==============================] - 176s 586ms/step - loss: 0.0104 - accuracy: 0.9932 - dice_coef: 0.9952 - dice_coe: 0.9952 - val_loss: 0.0059 - val_accuracy: 0.9964 - val_dice_coef: 0.9974 - val_dice_coe: 0.9974 - lr: 9.4868e-05
# Epoch 83/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9924 - dice_coef: 0.9945 - dice_coe: 0.9944
# Epoch 00083: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0083_val_weights.h5
# 300/300 [==============================] - 179s 598ms/step - loss: 0.0125 - accuracy: 0.9924 - dice_coef: 0.9945 - dice_coe: 0.9944 - val_loss: 0.0058 - val_accuracy: 0.9965 - val_dice_coef: 0.9974 - val_dice_coe: 0.9974 - lr: 9.4868e-05
# Epoch 84/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9906 - dice_coef: 0.9932 - dice_coe: 0.9932
# Epoch 00084: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0084_val_weights.h5
# 300/300 [==============================] - 177s 590ms/step - loss: 0.0154 - accuracy: 0.9906 - dice_coef: 0.9932 - dice_coe: 0.9932 - val_loss: 0.0050 - val_accuracy: 0.9969 - val_dice_coef: 0.9978 - val_dice_coe: 0.9978 - lr: 9.4868e-05
# Epoch 85/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9927 - dice_coef: 0.9948 - dice_coe: 0.9948
# Epoch 00085: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0085_val_weights.h5
# 300/300 [==============================] - 176s 586ms/step - loss: 0.0113 - accuracy: 0.9927 - dice_coef: 0.9948 - dice_coe: 0.9948 - val_loss: 0.0051 - val_accuracy: 0.9965 - val_dice_coef: 0.9976 - val_dice_coe: 0.9976 - lr: 9.4868e-05
# Epoch 86/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9904 - dice_coef: 0.9927 - dice_coe: 0.9926
# Epoch 00086: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0086_val_weights.h5
# 300/300 [==============================] - 179s 597ms/step - loss: 0.0192 - accuracy: 0.9904 - dice_coef: 0.9927 - dice_coe: 0.9926 - val_loss: 0.0068 - val_accuracy: 0.9960 - val_dice_coef: 0.9970 - val_dice_coe: 0.9970 - lr: 9.4868e-05
# Epoch 87/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9928 - dice_coef: 0.9949 - dice_coe: 0.9948
# Epoch 00087: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0087_val_weights.h5
# 300/300 [==============================] - 176s 588ms/step - loss: 0.0110 - accuracy: 0.9928 - dice_coef: 0.9949 - dice_coe: 0.9948 - val_loss: 0.0049 - val_accuracy: 0.9971 - val_dice_coef: 0.9979 - val_dice_coe: 0.9978 - lr: 9.4868e-05
# Epoch 88/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9938 - dice_coef: 0.9956 - dice_coe: 0.9955
# Epoch 00088: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0088_val_weights.h5
# 300/300 [==============================] - 177s 591ms/step - loss: 0.0097 - accuracy: 0.9938 - dice_coef: 0.9956 - dice_coe: 0.9955 - val_loss: 0.0051 - val_accuracy: 0.9968 - val_dice_coef: 0.9977 - val_dice_coe: 0.9977 - lr: 9.4868e-05
# Epoch 89/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9938 - dice_coef: 0.9955 - dice_coe: 0.9955
# Epoch 00089: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0089_val_weights.h5
# 300/300 [==============================] - 181s 603ms/step - loss: 0.0097 - accuracy: 0.9938 - dice_coef: 0.9955 - dice_coe: 0.9955 - val_loss: 0.0053 - val_accuracy: 0.9968 - val_dice_coef: 0.9977 - val_dice_coe: 0.9976 - lr: 9.4868e-05
# Epoch 90/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9938 - dice_coef: 0.9956 - dice_coe: 0.9956
# Epoch 00090: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0090_val_weights.h5
# 300/300 [==============================] - 177s 590ms/step - loss: 0.0096 - accuracy: 0.9938 - dice_coef: 0.9956 - dice_coe: 0.9956 - val_loss: 0.0037 - val_accuracy: 0.9978 - val_dice_coef: 0.9984 - val_dice_coe: 0.9984 - lr: 9.4868e-05
# Epoch 91/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9931 - dice_coef: 0.9951 - dice_coe: 0.9950
# Epoch 00091: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0091_val_weights.h5
# 300/300 [==============================] - 176s 587ms/step - loss: 0.0108 - accuracy: 0.9931 - dice_coef: 0.9951 - dice_coe: 0.9950 - val_loss: 0.0083 - val_accuracy: 0.9952 - val_dice_coef: 0.9964 - val_dice_coe: 0.9963 - lr: 9.4868e-05
# Epoch 92/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9940 - dice_coef: 0.9957 - dice_coe: 0.9957
# Epoch 00092: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0092_val_weights.h5
# 300/300 [==============================] - 179s 598ms/step - loss: 0.0093 - accuracy: 0.9940 - dice_coef: 0.9957 - dice_coe: 0.9957 - val_loss: 0.0064 - val_accuracy: 0.9959 - val_dice_coef: 0.9970 - val_dice_coe: 0.9970 - lr: 9.4868e-05
# Epoch 93/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9929 - dice_coef: 0.9949 - dice_coe: 0.9949
# Epoch 00093: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0093_val_weights.h5
# 300/300 [==============================] - 177s 589ms/step - loss: 0.0112 - accuracy: 0.9929 - dice_coef: 0.9949 - dice_coe: 0.9949 - val_loss: 0.0049 - val_accuracy: 0.9971 - val_dice_coef: 0.9979 - val_dice_coe: 0.9979 - lr: 9.4868e-05
# Epoch 94/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9921 - dice_coef: 0.9941 - dice_coe: 0.9940
# Epoch 00094: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0094_val_weights.h5
# 300/300 [==============================] - 179s 596ms/step - loss: 0.0140 - accuracy: 0.9921 - dice_coef: 0.9941 - dice_coe: 0.9940 - val_loss: 0.0122 - val_accuracy: 0.9935 - val_dice_coef: 0.9949 - val_dice_coe: 0.9948 - lr: 9.4868e-05
# Epoch 95/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9942 - dice_coef: 0.9958 - dice_coe: 0.9957
# Epoch 00095: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0095_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0102 - accuracy: 0.9942 - dice_coef: 0.9958 - dice_coe: 0.9957 - val_loss: 0.0048 - val_accuracy: 0.9968 - val_dice_coef: 0.9978 - val_dice_coe: 0.9978 - lr: 9.4868e-05
# Epoch 96/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9927 - dice_coef: 0.9947 - dice_coe: 0.9946
# Epoch 00096: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0096_val_weights.h5
# 300/300 [==============================] - 180s 601ms/step - loss: 0.0117 - accuracy: 0.9927 - dice_coef: 0.9947 - dice_coe: 0.9946 - val_loss: 0.0110 - val_accuracy: 0.9942 - val_dice_coef: 0.9955 - val_dice_coe: 0.9955 - lr: 9.4868e-05
# Epoch 97/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9933 - dice_coef: 0.9952 - dice_coe: 0.9952
# Epoch 00097: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0097_val_weights.h5
# 300/300 [==============================] - 175s 583ms/step - loss: 0.0105 - accuracy: 0.9933 - dice_coef: 0.9952 - dice_coe: 0.9952 - val_loss: 0.0040 - val_accuracy: 0.9976 - val_dice_coef: 0.9983 - val_dice_coe: 0.9983 - lr: 9.4868e-05
# Epoch 98/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9943 - dice_coef: 0.9960 - dice_coe: 0.9959
# Epoch 00098: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0098_val_weights.h5
# 300/300 [==============================] - 175s 582ms/step - loss: 0.0087 - accuracy: 0.9943 - dice_coef: 0.9960 - dice_coe: 0.9959 - val_loss: 0.0045 - val_accuracy: 0.9975 - val_dice_coef: 0.9981 - val_dice_coe: 0.9981 - lr: 9.4868e-05
# Epoch 99/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9925 - dice_coef: 0.9946 - dice_coe: 0.9945
# Epoch 00099: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0099_val_weights.h5
# 300/300 [==============================] - 175s 585ms/step - loss: 0.0118 - accuracy: 0.9925 - dice_coef: 0.9946 - dice_coe: 0.9945 - val_loss: 0.0049 - val_accuracy: 0.9969 - val_dice_coef: 0.9978 - val_dice_coe: 0.9978 - lr: 9.4868e-05
# Epoch 100/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9936 - dice_coef: 0.9954 - dice_coe: 0.9953
# Epoch 00100: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0100_val_weights.h5
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 3.0000002378990563e-05.
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0101 - accuracy: 0.9936 - dice_coef: 0.9954 - dice_coe: 0.9953 - val_loss: 0.0049 - val_accuracy: 0.9969 - val_dice_coef: 0.9979 - val_dice_coe: 0.9978 - lr: 9.4868e-05
# Epoch 101/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9934 - dice_coef: 0.9954 - dice_coe: 0.9953
# Epoch 00101: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0101_val_weights.h5
# 300/300 [==============================] - 176s 586ms/step - loss: 0.0100 - accuracy: 0.9934 - dice_coef: 0.9954 - dice_coe: 0.9953 - val_loss: 0.0054 - val_accuracy: 0.9967 - val_dice_coef: 0.9976 - val_dice_coe: 0.9976 - lr: 3.0000e-05
# Epoch 102/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9941 - dice_coef: 0.9958 - dice_coe: 0.9958
# Epoch 00102: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0102_val_weights.h5
# 300/300 [==============================] - 177s 589ms/step - loss: 0.0090 - accuracy: 0.9941 - dice_coef: 0.9958 - dice_coe: 0.9958 - val_loss: 0.0042 - val_accuracy: 0.9974 - val_dice_coef: 0.9982 - val_dice_coe: 0.9982 - lr: 3.0000e-05
# Epoch 103/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9948 - dice_coef: 0.9963 - dice_coe: 0.9963
# Epoch 00103: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0103_val_weights.h5
# 300/300 [==============================] - 178s 595ms/step - loss: 0.0081 - accuracy: 0.9948 - dice_coef: 0.9963 - dice_coe: 0.9963 - val_loss: 0.0037 - val_accuracy: 0.9977 - val_dice_coef: 0.9984 - val_dice_coe: 0.9983 - lr: 3.0000e-05
# Epoch 104/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9938 - dice_coef: 0.9956 - dice_coe: 0.9955
# Epoch 00104: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0104_val_weights.h5
# 300/300 [==============================] - 179s 596ms/step - loss: 0.0096 - accuracy: 0.9938 - dice_coef: 0.9956 - dice_coe: 0.9955 - val_loss: 0.0055 - val_accuracy: 0.9964 - val_dice_coef: 0.9975 - val_dice_coe: 0.9974 - lr: 3.0000e-05
# Epoch 105/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9937 - dice_coef: 0.9955 - dice_coe: 0.9955
# Epoch 00105: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0105_val_weights.h5
# 300/300 [==============================] - 176s 588ms/step - loss: 0.0096 - accuracy: 0.9937 - dice_coef: 0.9955 - dice_coe: 0.9955 - val_loss: 0.0042 - val_accuracy: 0.9973 - val_dice_coef: 0.9981 - val_dice_coe: 0.9981 - lr: 3.0000e-05
# Epoch 106/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9945 - dice_coef: 0.9961 - dice_coe: 0.9960
# Epoch 00106: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0106_val_weights.h5
# 300/300 [==============================] - 176s 586ms/step - loss: 0.0086 - accuracy: 0.9945 - dice_coef: 0.9961 - dice_coe: 0.9960 - val_loss: 0.0032 - val_accuracy: 0.9980 - val_dice_coef: 0.9986 - val_dice_coe: 0.9986 - lr: 3.0000e-05
# Epoch 107/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9934 - dice_coef: 0.9953 - dice_coe: 0.9953
# Epoch 00107: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0107_val_weights.h5
# 300/300 [==============================] - 176s 587ms/step - loss: 0.0102 - accuracy: 0.9934 - dice_coef: 0.9953 - dice_coe: 0.9953 - val_loss: 0.0049 - val_accuracy: 0.9967 - val_dice_coef: 0.9978 - val_dice_coe: 0.9977 - lr: 3.0000e-05
# Epoch 108/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9935 - dice_coef: 0.9953 - dice_coe: 0.9953
# Epoch 00108: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0108_val_weights.h5
# 300/300 [==============================] - 178s 594ms/step - loss: 0.0103 - accuracy: 0.9935 - dice_coef: 0.9953 - dice_coe: 0.9953 - val_loss: 0.0042 - val_accuracy: 0.9975 - val_dice_coef: 0.9982 - val_dice_coe: 0.9982 - lr: 3.0000e-05
# Epoch 109/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9938 - dice_coef: 0.9956 - dice_coe: 0.9956
# Epoch 00109: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0109_val_weights.h5
# 300/300 [==============================] - 176s 587ms/step - loss: 0.0094 - accuracy: 0.9938 - dice_coef: 0.9956 - dice_coe: 0.9956 - val_loss: 0.0053 - val_accuracy: 0.9967 - val_dice_coef: 0.9976 - val_dice_coe: 0.9976 - lr: 3.0000e-05
# Epoch 110/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9941 - dice_coef: 0.9959 - dice_coe: 0.9958
# Epoch 00110: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0110_val_weights.h5
# 300/300 [==============================] - 177s 590ms/step - loss: 0.0090 - accuracy: 0.9941 - dice_coef: 0.9959 - dice_coe: 0.9958 - val_loss: 0.0052 - val_accuracy: 0.9964 - val_dice_coef: 0.9975 - val_dice_coe: 0.9975 - lr: 3.0000e-05
# Epoch 111/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9943 - dice_coef: 0.9960 - dice_coe: 0.9960
# Epoch 00111: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0111_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0086 - accuracy: 0.9943 - dice_coef: 0.9960 - dice_coe: 0.9960 - val_loss: 0.0044 - val_accuracy: 0.9971 - val_dice_coef: 0.9980 - val_dice_coe: 0.9980 - lr: 3.0000e-05
# Epoch 112/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9939 - dice_coef: 0.9956 - dice_coe: 0.9956
# Epoch 00112: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0112_val_weights.h5
# 300/300 [==============================] - 178s 594ms/step - loss: 0.0095 - accuracy: 0.9939 - dice_coef: 0.9956 - dice_coe: 0.9956 - val_loss: 0.0041 - val_accuracy: 0.9973 - val_dice_coef: 0.9981 - val_dice_coe: 0.9981 - lr: 3.0000e-05
# Epoch 113/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9935 - dice_coef: 0.9954 - dice_coe: 0.9954
# Epoch 00113: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0113_val_weights.h5
# 300/300 [==============================] - 179s 599ms/step - loss: 0.0099 - accuracy: 0.9935 - dice_coef: 0.9954 - dice_coe: 0.9954 - val_loss: 0.0046 - val_accuracy: 0.9974 - val_dice_coef: 0.9980 - val_dice_coe: 0.9980 - lr: 3.0000e-05
# Epoch 114/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9935 - dice_coef: 0.9954 - dice_coe: 0.9953
# Epoch 00114: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0114_val_weights.h5
# 300/300 [==============================] - 178s 592ms/step - loss: 0.0100 - accuracy: 0.9935 - dice_coef: 0.9954 - dice_coe: 0.9953 - val_loss: 0.0044 - val_accuracy: 0.9972 - val_dice_coef: 0.9980 - val_dice_coe: 0.9980 - lr: 3.0000e-05
# Epoch 115/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9935 - dice_coef: 0.9954 - dice_coe: 0.9953
# Epoch 00115: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0115_val_weights.h5
# 300/300 [==============================] - 178s 592ms/step - loss: 0.0100 - accuracy: 0.9935 - dice_coef: 0.9954 - dice_coe: 0.9953 - val_loss: 0.0036 - val_accuracy: 0.9978 - val_dice_coef: 0.9984 - val_dice_coe: 0.9984 - lr: 3.0000e-05
# Epoch 116/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9930 - dice_coef: 0.9950 - dice_coe: 0.9949
# Epoch 00116: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0116_val_weights.h5
# 300/300 [==============================] - 178s 593ms/step - loss: 0.0110 - accuracy: 0.9930 - dice_coef: 0.9950 - dice_coe: 0.9949 - val_loss: 0.0046 - val_accuracy: 0.9970 - val_dice_coef: 0.9980 - val_dice_coe: 0.9979 - lr: 3.0000e-05
# Epoch 117/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9939 - dice_coef: 0.9957 - dice_coe: 0.9957
# Epoch 00117: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0117_val_weights.h5
# 300/300 [==============================] - 177s 591ms/step - loss: 0.0092 - accuracy: 0.9939 - dice_coef: 0.9957 - dice_coe: 0.9957 - val_loss: 0.0044 - val_accuracy: 0.9970 - val_dice_coef: 0.9979 - val_dice_coe: 0.9979 - lr: 3.0000e-05
# Epoch 118/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9936 - dice_coef: 0.9953 - dice_coe: 0.9953
# Epoch 00118: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0118_val_weights.h5
# 300/300 [==============================] - 178s 594ms/step - loss: 0.0105 - accuracy: 0.9936 - dice_coef: 0.9953 - dice_coe: 0.9953 - val_loss: 0.0048 - val_accuracy: 0.9970 - val_dice_coef: 0.9979 - val_dice_coe: 0.9978 - lr: 3.0000e-05
# Epoch 119/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9931 - dice_coef: 0.9950 - dice_coe: 0.9950
# Epoch 00119: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0119_val_weights.h5
# 300/300 [==============================] - 177s 590ms/step - loss: 0.0109 - accuracy: 0.9931 - dice_coef: 0.9950 - dice_coe: 0.9950 - val_loss: 0.0043 - val_accuracy: 0.9971 - val_dice_coef: 0.9981 - val_dice_coe: 0.9980 - lr: 3.0000e-05
# Epoch 120/300
# 300/300 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9938 - dice_coef: 0.9956 - dice_coe: 0.9956
# Epoch 00120: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow_v2/logs/weights/checkpoints_0120_val_weights.h5
# 300/300 [==============================] - 178s 594ms/step - loss: 0.0095 - accuracy: 0.9938 - dice_coef: 0.9956 - dice_coe: 0.9956 - val_loss: 0.0044 - val_accuracy: 0.9973 - val_dice_coef: 0.9980 - val_dice_coe: 0.9980 - lr: 3.0000e-05

# %%
unet.save(os.path.join(log_dir, FMT_VALMODEL_LAST_PATH.format(PREFIX)))
