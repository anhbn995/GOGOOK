# %%
import os
# import model as modellib
# import unet_new as modellib2
# import vgg16unet
import argparse
import numpy as np
import tensorflow as tf
import pandas as pd
import os
import h5py
from data_defores_generator import data_gen, create_list_id,data_gen_not_batch
from datetime import datetime
from tensorflow.keras.callbacks import (ModelCheckpoint, TensorBoard, CSVLogger, History, EarlyStopping, LambdaCallback,ReduceLROnPlateau)

from tensorflow.keras import layers, backend, Model, utils
from matplotlib import pyplot as plt
import rasterio
import cv2
from tensorflow.compat.v1.keras.backend import set_session
# import wanrings
# warnings.filterwarnings("ignore")
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth=True
set_session(tf.compat.v1.Session(config=config))
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
# os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async"
# Out:
# 2022-10-21 16:37:29.769994: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-21 16:37:29.784760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:29.821271: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:29.821443: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.172421: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.172637: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.172762: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.172859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9730 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
FMT_VALMODEL_PATH ="{}_val_weights.h5"
FMT_VALMODEL_LAST_PATH = "{}_val_weights_last.h5"
FMT_VALMODEL_HIST = "{}_val_hist.csv"
PREFIX = "checkpoints"
INPUT_CHANNEL =  300
INPUT_SIZE = 512
early_stop = 50
num_class = 1
weight_path = r""
# log_dir = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_only/"
log_dir = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/"
num_epoch = 200
batch_size= 16
scale_neg = 0.1

# %%
from model import build_model
unet = build_model((None,None,4), 36)
# unet = modellib2.build_model((None,None,3), 32)
# Out:
# 2022-10-21 16:37:30.307221: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.307409: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.307514: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.307741: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.307850: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.307950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.308084: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.308189: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 16:37:30.308254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9730 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
from sklearn.preprocessing import OneHotEncoder

# mask_fn = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/data/train/label/box_0001.tif"
# with rasterio.open(mask_fn, 'r') as f:
#     mask = f.read().astype(np.uint8)
#     onehot_encode = OneHotEncoder(sparse=False)
#     new_mask = onehot_encode.fit_transform(mask.squeeze(0).reshape(-1,1)).reshape(512, 512, -1)[...,1:3].astype(np.uint8)
    # mask = np.array((mask[0]==2).astype(np.uint8)) #==255
    # result_mask = np.full((new_image_height,new_image_width), 0, dtype=np.uint8)
    # result_mask[y_center:y_center+height, x_center:x_center+width] = mask
    # result_mask = cv2.resize(result_mask,(INPUT_SIZE, INPUT_SIZE), interpolation = cv2.INTER_CUBIC).astype(np.uint8)
    # mask = np.expand_dims(result_mask,axis = -1)

# %%
# weight_path = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/cp.h5"
weight_path = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0032_val_weights.h5"
if weight_path != "":
    unet.load_weights(weight_path)

# %%
if not os.path.exists(log_dir):
    os.mkdir(log_dir)

# %%
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  4)]
#
#  conv2d (Conv2D)                (None, None, None,   1332        ['input_1[0][0]']
#                                 36)
#
#  batch_normalization (BatchNorm  (None, None, None,   144        ['conv2d[0][0]']
#  alization)                     36)
#
#  activation (Activation)        (None, None, None,   0           ['batch_normalization[0][0]']
#                                 36)
#
#  conv2d_1 (Conv2D)              (None, None, None,   11700       ['activation[0][0]']
#                                 36)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   144        ['conv2d_1[0][0]']
#  rmalization)                   36)
#
#  activation_1 (Activation)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 36)
#
#  conv2d_2 (Conv2D)              (None, None, None,   11700       ['activation_1[0][0]']
#                                 36)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   144        ['conv2d_2[0][0]']
#  rmalization)                   36)
#
#  activation_2 (Activation)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 36)
#
#  add (Add)                      (None, None, None,   0           ['activation_2[0][0]',
#                                 36)                               'conv2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, None, None,   144        ['add[0][0]']
#  rmalization)                   36)
#
#  activation_3 (Activation)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 36)
#
#  conv2d_3 (Conv2D)              (None, None, None,   11700       ['activation_3[0][0]']
#                                 36)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   144        ['conv2d_3[0][0]']
#  rmalization)                   36)
#
#  activation_4 (Activation)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 36)
#
#  conv2d_4 (Conv2D)              (None, None, None,   11700       ['activation_4[0][0]']
#                                 36)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   144        ['conv2d_4[0][0]']
#  rmalization)                   36)
#
#  activation_5 (Activation)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 36)
#
#  add_1 (Add)                    (None, None, None,   0           ['activation_5[0][0]',
#                                 36)                               'add[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, None, None,   144        ['add_1[0][0]']
#  rmalization)                   36)
#
#  activation_6 (Activation)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 36)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['activation_6[0][0]']
#                                 36)
#
#  dropout (Dropout)              (None, None, None,   0           ['max_pooling2d[0][0]']
#                                 36)
#
#  conv2d_5 (Conv2D)              (None, None, None,   23400       ['dropout[0][0]']
#                                 72)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   288        ['conv2d_5[0][0]']
#  rmalization)                   72)
#
#  activation_7 (Activation)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 72)
#
#  conv2d_6 (Conv2D)              (None, None, None,   46728       ['activation_7[0][0]']
#                                 72)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   288        ['conv2d_6[0][0]']
#  rmalization)                   72)
#
#  activation_8 (Activation)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 72)
#
#  conv2d_7 (Conv2D)              (None, None, None,   46728       ['activation_8[0][0]']
#                                 72)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   288        ['conv2d_7[0][0]']
#  rmalization)                   72)
#
#  activation_9 (Activation)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 72)
#
#  add_2 (Add)                    (None, None, None,   0           ['activation_9[0][0]',
#                                 72)                               'conv2d_5[0][0]']
#
#  batch_normalization_10 (BatchN  (None, None, None,   288        ['add_2[0][0]']
#  ormalization)                  72)
#
#  activation_10 (Activation)     (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 72)
#
#  conv2d_8 (Conv2D)              (None, None, None,   46728       ['activation_10[0][0]']
#                                 72)
#
#  batch_normalization_11 (BatchN  (None, None, None,   288        ['conv2d_8[0][0]']
#  ormalization)                  72)
#
#  activation_11 (Activation)     (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 72)
#
#  conv2d_9 (Conv2D)              (None, None, None,   46728       ['activation_11[0][0]']
#                                 72)
#
#  batch_normalization_12 (BatchN  (None, None, None,   288        ['conv2d_9[0][0]']
#  ormalization)                  72)
#
#  activation_12 (Activation)     (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 72)
#
#  add_3 (Add)                    (None, None, None,   0           ['activation_12[0][0]',
#                                 72)                               'add_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, None, None,   288        ['add_3[0][0]']
#  ormalization)                  72)
#
#  activation_13 (Activation)     (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 72)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['activation_13[0][0]']
#                                 72)
#
#  dropout_1 (Dropout)            (None, None, None,   0           ['max_pooling2d_1[0][0]']
#                                 72)
#
#  conv2d_10 (Conv2D)             (None, None, None,   93456       ['dropout_1[0][0]']
#                                 144)
#
#  batch_normalization_14 (BatchN  (None, None, None,   576        ['conv2d_10[0][0]']
#  ormalization)                  144)
#
#  activation_14 (Activation)     (None, None, None,   0           ['batch_normalization_14[0][0]']
#                                 144)
#
#  conv2d_11 (Conv2D)             (None, None, None,   186768      ['activation_14[0][0]']
#                                 144)
#
#  batch_normalization_15 (BatchN  (None, None, None,   576        ['conv2d_11[0][0]']
#  ormalization)                  144)
#
#  activation_15 (Activation)     (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 144)
#
#  conv2d_12 (Conv2D)             (None, None, None,   186768      ['activation_15[0][0]']
#                                 144)
#
#  batch_normalization_16 (BatchN  (None, None, None,   576        ['conv2d_12[0][0]']
#  ormalization)                  144)
#
#  activation_16 (Activation)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 144)
#
#  add_4 (Add)                    (None, None, None,   0           ['activation_16[0][0]',
#                                 144)                              'conv2d_10[0][0]']
#
#  batch_normalization_17 (BatchN  (None, None, None,   576        ['add_4[0][0]']
#  ormalization)                  144)
#
#  activation_17 (Activation)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 144)
#
#  conv2d_13 (Conv2D)             (None, None, None,   186768      ['activation_17[0][0]']
#                                 144)
#
#  batch_normalization_18 (BatchN  (None, None, None,   576        ['conv2d_13[0][0]']
#  ormalization)                  144)
#
#  activation_18 (Activation)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 144)
#
#  conv2d_14 (Conv2D)             (None, None, None,   186768      ['activation_18[0][0]']
#                                 144)
#
#  batch_normalization_19 (BatchN  (None, None, None,   576        ['conv2d_14[0][0]']
#  ormalization)                  144)
#
#  activation_19 (Activation)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 144)
#
#  add_5 (Add)                    (None, None, None,   0           ['activation_19[0][0]',
#                                 144)                              'add_4[0][0]']
#
#  batch_normalization_20 (BatchN  (None, None, None,   576        ['add_5[0][0]']
#  ormalization)                  144)
#
#  activation_20 (Activation)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 144)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['activation_20[0][0]']
#                                 144)
#
#  dropout_2 (Dropout)            (None, None, None,   0           ['max_pooling2d_2[0][0]']
#                                 144)
#
#  conv2d_15 (Conv2D)             (None, None, None,   373536      ['dropout_2[0][0]']
#                                 288)
#
#  batch_normalization_21 (BatchN  (None, None, None,   1152       ['conv2d_15[0][0]']
#  ormalization)                  288)
#
#  activation_21 (Activation)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 288)
#
#  conv2d_16 (Conv2D)             (None, None, None,   746784      ['activation_21[0][0]']
#                                 288)
#
#  batch_normalization_22 (BatchN  (None, None, None,   1152       ['conv2d_16[0][0]']
#  ormalization)                  288)
#
#  activation_22 (Activation)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 288)
#
#  conv2d_17 (Conv2D)             (None, None, None,   746784      ['activation_22[0][0]']
#                                 288)
#
#  batch_normalization_23 (BatchN  (None, None, None,   1152       ['conv2d_17[0][0]']
#  ormalization)                  288)
#
#  activation_23 (Activation)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 288)
#
#  add_6 (Add)                    (None, None, None,   0           ['activation_23[0][0]',
#                                 288)                              'conv2d_15[0][0]']
#
#  batch_normalization_24 (BatchN  (None, None, None,   1152       ['add_6[0][0]']
#  ormalization)                  288)
#
#  activation_24 (Activation)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 288)
#
#  conv2d_18 (Conv2D)             (None, None, None,   746784      ['activation_24[0][0]']
#                                 288)
#
#  batch_normalization_25 (BatchN  (None, None, None,   1152       ['conv2d_18[0][0]']
#  ormalization)                  288)
#
#  activation_25 (Activation)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 288)
#
#  conv2d_19 (Conv2D)             (None, None, None,   746784      ['activation_25[0][0]']
#                                 288)
#
#  batch_normalization_26 (BatchN  (None, None, None,   1152       ['conv2d_19[0][0]']
#  ormalization)                  288)
#
#  activation_26 (Activation)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 288)
#
#  add_7 (Add)                    (None, None, None,   0           ['activation_26[0][0]',
#                                 288)                              'add_6[0][0]']
#
#  batch_normalization_27 (BatchN  (None, None, None,   1152       ['add_7[0][0]']
#  ormalization)                  288)
#
#  activation_27 (Activation)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 288)
#
#  conv2d_transpose (Conv2DTransp  (None, None, None,   373392     ['activation_27[0][0]']
#  ose)                           144)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['conv2d_transpose[0][0]',
#                                 288)                              'activation_20[0][0]']
#
#  dropout_3 (Dropout)            (None, None, None,   0           ['concatenate[0][0]']
#                                 288)
#
#  conv2d_20 (Conv2D)             (None, None, None,   373392      ['dropout_3[0][0]']
#                                 144)
#
#  batch_normalization_28 (BatchN  (None, None, None,   576        ['conv2d_20[0][0]']
#  ormalization)                  144)
#
#  activation_28 (Activation)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 144)
#
#  conv2d_21 (Conv2D)             (None, None, None,   186768      ['activation_28[0][0]']
#                                 144)
#
#  batch_normalization_29 (BatchN  (None, None, None,   576        ['conv2d_21[0][0]']
#  ormalization)                  144)
#
#  activation_29 (Activation)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 144)
#
#  conv2d_22 (Conv2D)             (None, None, None,   186768      ['activation_29[0][0]']
#                                 144)
#
#  batch_normalization_30 (BatchN  (None, None, None,   576        ['conv2d_22[0][0]']
#  ormalization)                  144)
#
#  activation_30 (Activation)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 144)
#
#  add_8 (Add)                    (None, None, None,   0           ['activation_30[0][0]',
#                                 144)                              'conv2d_20[0][0]']
#
#  batch_normalization_31 (BatchN  (None, None, None,   576        ['add_8[0][0]']
#  ormalization)                  144)
#
#  activation_31 (Activation)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 144)
#
#  conv2d_23 (Conv2D)             (None, None, None,   186768      ['activation_31[0][0]']
#                                 144)
#
#  batch_normalization_32 (BatchN  (None, None, None,   576        ['conv2d_23[0][0]']
#  ormalization)                  144)
#
#  activation_32 (Activation)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 144)
#
#  conv2d_24 (Conv2D)             (None, None, None,   186768      ['activation_32[0][0]']
#                                 144)
#
#  batch_normalization_33 (BatchN  (None, None, None,   576        ['conv2d_24[0][0]']
#  ormalization)                  144)
#
#  activation_33 (Activation)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 144)
#
#  add_9 (Add)                    (None, None, None,   0           ['activation_33[0][0]',
#                                 144)                              'add_8[0][0]']
#
#  batch_normalization_34 (BatchN  (None, None, None,   576        ['add_9[0][0]']
#  ormalization)                  144)
#
#  activation_34 (Activation)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 144)
#
#  conv2d_transpose_1 (Conv2DTran  (None, None, None,   93384      ['activation_34[0][0]']
#  spose)                         72)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['conv2d_transpose_1[0][0]',
#                                 144)                              'activation_13[0][0]']
#
#  dropout_4 (Dropout)            (None, None, None,   0           ['concatenate_1[0][0]']
#                                 144)
#
#  conv2d_25 (Conv2D)             (None, None, None,   93384       ['dropout_4[0][0]']
#                                 72)
#
#  batch_normalization_35 (BatchN  (None, None, None,   288        ['conv2d_25[0][0]']
#  ormalization)                  72)
#
#  activation_35 (Activation)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 72)
#
#  conv2d_26 (Conv2D)             (None, None, None,   46728       ['activation_35[0][0]']
#                                 72)
#
#  batch_normalization_36 (BatchN  (None, None, None,   288        ['conv2d_26[0][0]']
#  ormalization)                  72)
#
#  activation_36 (Activation)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 72)
#
#  conv2d_27 (Conv2D)             (None, None, None,   46728       ['activation_36[0][0]']
#                                 72)
#
#  batch_normalization_37 (BatchN  (None, None, None,   288        ['conv2d_27[0][0]']
#  ormalization)                  72)
#
#  activation_37 (Activation)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 72)
#
#  add_10 (Add)                   (None, None, None,   0           ['activation_37[0][0]',
#                                 72)                               'conv2d_25[0][0]']
#
#  batch_normalization_38 (BatchN  (None, None, None,   288        ['add_10[0][0]']
#  ormalization)                  72)
#
#  activation_38 (Activation)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 72)
#
#  conv2d_28 (Conv2D)             (None, None, None,   46728       ['activation_38[0][0]']
#                                 72)
#
#  batch_normalization_39 (BatchN  (None, None, None,   288        ['conv2d_28[0][0]']
#  ormalization)                  72)
#
#  activation_39 (Activation)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 72)
#
#  conv2d_29 (Conv2D)             (None, None, None,   46728       ['activation_39[0][0]']
#                                 72)
#
#  batch_normalization_40 (BatchN  (None, None, None,   288        ['conv2d_29[0][0]']
#  ormalization)                  72)
#
#  activation_40 (Activation)     (None, None, None,   0           ['batch_normalization_40[0][0]']
#                                 72)
#
#  add_11 (Add)                   (None, None, None,   0           ['activation_40[0][0]',
#                                 72)                               'add_10[0][0]']
#
#  batch_normalization_41 (BatchN  (None, None, None,   288        ['add_11[0][0]']
#  ormalization)                  72)
#
#  activation_41 (Activation)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 72)
#
#  conv2d_transpose_2 (Conv2DTran  (None, None, None,   23364      ['activation_41[0][0]']
#  spose)                         36)
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['conv2d_transpose_2[0][0]',
#                                 72)                               'activation_6[0][0]']
#
#  dropout_5 (Dropout)            (None, None, None,   0           ['concatenate_2[0][0]']
#                                 72)
#
#  conv2d_30 (Conv2D)             (None, None, None,   23364       ['dropout_5[0][0]']
#                                 36)
#
#  batch_normalization_42 (BatchN  (None, None, None,   144        ['conv2d_30[0][0]']
#  ormalization)                  36)
#
#  activation_42 (Activation)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 36)
#
#  conv2d_31 (Conv2D)             (None, None, None,   11700       ['activation_42[0][0]']
#                                 36)
#
#  batch_normalization_43 (BatchN  (None, None, None,   144        ['conv2d_31[0][0]']
#  ormalization)                  36)
#
#  activation_43 (Activation)     (None, None, None,   0           ['batch_normalization_43[0][0]']
#                                 36)
#
#  conv2d_32 (Conv2D)             (None, None, None,   11700       ['activation_43[0][0]']
#                                 36)
#
#  batch_normalization_44 (BatchN  (None, None, None,   144        ['conv2d_32[0][0]']
#  ormalization)                  36)
#
#  activation_44 (Activation)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 36)
#
#  add_12 (Add)                   (None, None, None,   0           ['activation_44[0][0]',
#                                 36)                               'conv2d_30[0][0]']
#
#  batch_normalization_45 (BatchN  (None, None, None,   144        ['add_12[0][0]']
#  ormalization)                  36)
#
#  activation_45 (Activation)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 36)
#
#  conv2d_33 (Conv2D)             (None, None, None,   11700       ['activation_45[0][0]']
#                                 36)
#
#  batch_normalization_46 (BatchN  (None, None, None,   144        ['conv2d_33[0][0]']
#  ormalization)                  36)
#
#  activation_46 (Activation)     (None, None, None,   0           ['batch_normalization_46[0][0]']
#                                 36)
#
#  conv2d_34 (Conv2D)             (None, None, None,   11700       ['activation_46[0][0]']
#                                 36)
#
#  batch_normalization_47 (BatchN  (None, None, None,   144        ['conv2d_34[0][0]']
#  ormalization)                  36)
#
#  activation_47 (Activation)     (None, None, None,   0           ['batch_normalization_47[0][0]']
#                                 36)
#
#  add_13 (Add)                   (None, None, None,   0           ['activation_47[0][0]',
#                                 36)                               'add_12[0][0]']
#
#  batch_normalization_48 (BatchN  (None, None, None,   144        ['add_13[0][0]']
#  ormalization)                  36)
#
#  activation_48 (Activation)     (None, None, None,   0           ['batch_normalization_48[0][0]']
#                                 36)
#
#  conv2d_35 (Conv2D)             (None, None, None,   111         ['activation_48[0][0]']
#                                 3)
#
#  softmax (Softmax)              (None, None, None,   0           ['conv2d_35[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 6,442,995
# Trainable params: 6,431,907
# Non-trainable params: 11,088
# __________________________________________________________________________________________________

# %%
checkpoint_dir = os.path.join(log_dir, 'logs')
model_checkpoint = ModelCheckpoint(
    os.path.join(checkpoint_dir, FMT_VALMODEL_PATH.format(PREFIX + "_{epoch:04d}")),
    verbose=1,
    save_best_only=False,
    save_weights_only=False)

# %%
model_earlystop = EarlyStopping(
    # monitor='val_jaccard_coef_int',
    patience=early_stop,
    verbose=0,
    # mode='max'
    )

# %%
model_history = History()

model_board = TensorBoard(
    log_dir=os.path.join(log_dir, 'logs'),
    histogram_freq=0,
    write_graph=True,
    embeddings_freq=0)

# %%
lr_reducer = ReduceLROnPlateau(
factor=np.sqrt(0.1),
verbose=1,
patience=30,
min_lr=0.5e-7)

# %%
fig_dir = os.path.join(log_dir, 'logs/fig')
def visualize_weight(epoch, model, image_path,mask_path,pos_val):
    INPUT_SIZE = 512
    color = (0,0,0,0)
    list_id = pos_val
    indx= np.random.choice(len(list_id),4)
    x=[]
    y=[]
    for idx in indx: 
        im_name = list_id[idx]
        image_fn = os.path.join(image_path, im_name)
        mask_fn = os.path.join(mask_path, im_name)
        with rasterio.open(image_fn, 'r') as f1:
            width,height = f1.width,f1.height
            new_image_width = new_image_height = max(width,height)
            # if width < 512 and height < 512:
            values = f1.read().transpose(1,2,0)
            x_center = (new_image_width - width) // 2
            y_center = (new_image_height - height) // 2
            result = np.full((new_image_height,new_image_width, 4), color, dtype=np.float16)
            result[y_center:y_center+height, x_center:x_center+width] = values ## REMOVE indices if input 3 channels
            
            if result.dtype == np.float16: pass
            else: result = cv2.resize(result,(INPUT_SIZE, INPUT_SIZE), interpolation = cv2.INTER_CUBIC)
            image = result
            
            with rasterio.open(mask_fn, 'r') as f:
                mask = f.read().astype(np.uint8)
                # onehot_encode = OneHotEncoder(sparse=False)
                # mask = onehot_encode.fit_transform(mask.squeeze(0).reshape(-1,1)).reshape(512, 512, -1)[...,1:3].astype(np.uint8)
                mask_full = np.zeros((INPUT_SIZE, INPUT_SIZE, 3),dtype=np.uint8)
                mask2 = np.array((mask[0]==2).astype(np.uint8)) #255
                mask3 = np.array((mask[0]==3).astype(np.uint8)) #255
                mask1 = ((mask2+mask3)==0).astype(np.uint8)
                mask_full[...,0] = mask1   # 1st band red = backgroud
                mask_full[...,1] = mask2   # 2nd band red = cloud
                mask_full[...,2] = mask3   # 3rd band blue = shadow
                mask = mask_full
                # result_mask = np.full((new_image_height,new_image_width), 0, dtype=np.uint8)
                # result_mask[y_center:y_center+height, x_center:x_center+width] = mask
                # result_mask = cv2.resize(result_mask,(INPUT_SIZE, INPUT_SIZE), interpolation = cv2.INTER_CUBIC).astype(np.uint8)
#                 mask = np.expand_dims(result_mask,axis = -1)
                # mask = result_mask
            x.append(image)
            y.append(mask)
    y_predict = model.predict(np.array(x)/np.finfo(np.float16).max)
    
    import sys

    ressult_predict = []
    for i in range(len(x)):
        predict_mask = y_predict[i].reshape((INPUT_SIZE,INPUT_SIZE, 3))
        predict_mask = np.array(predict_mask).argmax(axis=2)
        new_mask = np.zeros((INPUT_SIZE,INPUT_SIZE, 3), dtype=np.uint8)
        new_mask[...,0] = (predict_mask==0)
        new_mask[...,1] = (predict_mask==1)
        new_mask[...,2] = (predict_mask==2)
        predict_mask = new_mask
        ressult_predict.append(predict_mask)
    fig = plt.figure(figsize=(7, 7))
    rows = 4
    columns = 3
    count = 0
    # if np.random.randint(0, 1000) < 100:
    for i in range(len(x)):
        count = count+1
        image = x[i]
        fig.add_subplot(4, 3, count)
        im_converted = np.array((image/np.finfo(np.float16).max)*255, dtype=np.uint8)
        plt.imshow(im_converted) ## Holy MOLY
#         plt.axis('off')
        plt.title("image_{}".format(str(i)))
        mask = y[i]
        count = count+1
        fig.add_subplot(4, 3, count)
        plt.imshow(np.array(mask)*255)
#         plt.axis('off')
        plt.title("mask_{}".format(str(i)))
        predict = ressult_predict[i]
        count = count+1
        fig.add_subplot(4, 3, count)
        plt.imshow(np.array(predict)*255)
#         plt.axis('off')
        plt.title("result{}".format(str(i)))
    plt.savefig(os.path.join(fig_dir,'line plot{}_epoch{}.jpg'.format(PREFIX,epoch+1)), dpi=200)
    plt.close(fig)
#     plt.shows()

# %%
image_path = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/data/train/image"
mask_path = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/data/train/label"

val_image_path = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/data/val/image"
val_mask_path = r"/home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/data/val/label"

# %%
image_list = create_list_id(image_path)

image_list_val = create_list_id(val_image_path)

np.random.shuffle(image_list)
count = len(image_list)    
# cut_idx = int(round(count*split_ratio))    
# train_list = image_list[0:cut_idx]
# val_list = [id_image for id_image in image_list if id_image not in train_list]
train_list = image_list
val_list = image_list_val

visualize_epoch = LambdaCallback(on_epoch_end=lambda epoch, logs: visualize_weight(epoch, unet, image_path, mask_path, train_list))

# %%
# Training stage
# Epoch 8 occurred exploding gradient
# Solution: use gradient clipping, weight regularization

# %%
num_chanel = INPUT_CHANNEL
batch_size = 1
num_epoch = 300
unet.fit_generator(
    generator= data_gen_not_batch(image_path, mask_path, train_list,augment = True),
    validation_data = data_gen_not_batch(val_image_path, val_mask_path, val_list, augment = False),
    initial_epoch=0,
    validation_steps = 100, #200
    steps_per_epoch = 200, ##500
    epochs=num_epoch,
    verbose=1,
    callbacks=[model_checkpoint,model_earlystop, model_history, model_board,lr_reducer,visualize_epoch],
    max_queue_size=20
)
# Out:
# /tmp/ipykernel_78151/3132583913.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   unet.fit_generator(
# /home/skymap/anaconda3/envs/tf2.7/lib/python3.8/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 1/300
# 2022-10-21 16:37:39.597129: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8500
# 2022-10-21 16:37:40.038190: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2022-10-21 16:37:40.039448: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2022-10-21 16:37:40.039461: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2022-10-21 16:37:40.039509: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-10-21 16:37:41.866972: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-21 16:37:41.867042: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-21 16:37:41.954363: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.81GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-21 16:37:41.954423: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.81GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-21 16:37:42.276183: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-21 16:37:42.276242: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-21 16:37:42.501858: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.81GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-21 16:37:42.501919: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.81GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 200/200 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9970 - dice_coef: 0.9978 - dice_coe: 0.9978
# Epoch 00001: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0001_val_weights.h5
# 200/200 [==============================] - 213s 1s/step - loss: 0.0049 - accuracy: 0.9970 - dice_coef: 0.9978 - dice_coe: 0.9978 - val_loss: 0.3527 - val_accuracy: 0.8712 - val_dice_coef: 0.8866 - val_dice_coe: 0.8850 - lr: 1.0000e-05
# Epoch 2/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9980
# Epoch 00002: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0002_val_weights.h5
# 200/200 [==============================] - 198s 992ms/step - loss: 0.0044 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9980 - val_loss: 0.3888 - val_accuracy: 0.8556 - val_dice_coef: 0.8728 - val_dice_coe: 0.8707 - lr: 1.0000e-05
# Epoch 3/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9970 - dice_coef: 0.9978 - dice_coe: 0.9978
# Epoch 00003: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0003_val_weights.h5
# 200/200 [==============================] - 199s 997ms/step - loss: 0.0047 - accuracy: 0.9970 - dice_coef: 0.9978 - dice_coe: 0.9978 - val_loss: 0.3603 - val_accuracy: 0.8650 - val_dice_coef: 0.8821 - val_dice_coe: 0.8803 - lr: 1.0000e-05
# Epoch 4/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9970 - dice_coef: 0.9979 - dice_coe: 0.9978
# Epoch 00004: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0004_val_weights.h5
# 200/200 [==============================] - 197s 985ms/step - loss: 0.0047 - accuracy: 0.9970 - dice_coef: 0.9979 - dice_coe: 0.9978 - val_loss: 0.3526 - val_accuracy: 0.8712 - val_dice_coef: 0.8870 - val_dice_coe: 0.8851 - lr: 1.0000e-05
# Epoch 5/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9974 - dice_coef: 0.9982 - dice_coe: 0.9982
# Epoch 00005: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0005_val_weights.h5
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0040 - accuracy: 0.9974 - dice_coef: 0.9982 - dice_coe: 0.9982 - val_loss: 0.3887 - val_accuracy: 0.8539 - val_dice_coef: 0.8718 - val_dice_coe: 0.8696 - lr: 1.0000e-05
# Epoch 6/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9975 - dice_coef: 0.9982 - dice_coe: 0.9982
# Epoch 00006: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0006_val_weights.h5
# 200/200 [==============================] - 196s 980ms/step - loss: 0.0039 - accuracy: 0.9975 - dice_coef: 0.9982 - dice_coe: 0.9982 - val_loss: 0.3521 - val_accuracy: 0.8685 - val_dice_coef: 0.8849 - val_dice_coe: 0.8831 - lr: 1.0000e-05
# Epoch 7/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9965 - dice_coef: 0.9975 - dice_coe: 0.9975
# Epoch 00007: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0007_val_weights.h5
# 200/200 [==============================] - 196s 979ms/step - loss: 0.0054 - accuracy: 0.9965 - dice_coef: 0.9975 - dice_coe: 0.9975 - val_loss: 0.3471 - val_accuracy: 0.8683 - val_dice_coef: 0.8849 - val_dice_coe: 0.8828 - lr: 1.0000e-05
# Epoch 8/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9977 - dice_coef: 0.9983 - dice_coe: 0.9983
# Epoch 00008: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0008_val_weights.h5
# 200/200 [==============================] - 196s 980ms/step - loss: 0.0037 - accuracy: 0.9977 - dice_coef: 0.9983 - dice_coe: 0.9983 - val_loss: 0.3729 - val_accuracy: 0.8605 - val_dice_coef: 0.8777 - val_dice_coe: 0.8757 - lr: 1.0000e-05
# Epoch 9/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9966 - dice_coef: 0.9976 - dice_coe: 0.9976
# Epoch 00009: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0009_val_weights.h5
# 200/200 [==============================] - 196s 979ms/step - loss: 0.0053 - accuracy: 0.9966 - dice_coef: 0.9976 - dice_coe: 0.9976 - val_loss: 0.3934 - val_accuracy: 0.8517 - val_dice_coef: 0.8701 - val_dice_coe: 0.8679 - lr: 1.0000e-05
# Epoch 10/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9976 - dice_coef: 0.9983 - dice_coe: 0.9983
# Epoch 00010: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0010_val_weights.h5
# 200/200 [==============================] - 196s 981ms/step - loss: 0.0037 - accuracy: 0.9976 - dice_coef: 0.9983 - dice_coe: 0.9983 - val_loss: 0.3496 - val_accuracy: 0.8685 - val_dice_coef: 0.8849 - val_dice_coe: 0.8829 - lr: 1.0000e-05
# Epoch 11/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979
# Epoch 00011: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0011_val_weights.h5
# 200/200 [==============================] - 195s 976ms/step - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979 - val_loss: 0.3796 - val_accuracy: 0.8583 - val_dice_coef: 0.8754 - val_dice_coe: 0.8733 - lr: 1.0000e-05
# Epoch 12/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9973 - dice_coef: 0.9981 - dice_coe: 0.9981
# Epoch 00012: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0012_val_weights.h5
# 200/200 [==============================] - 195s 979ms/step - loss: 0.0040 - accuracy: 0.9973 - dice_coef: 0.9981 - dice_coe: 0.9981 - val_loss: 0.3848 - val_accuracy: 0.8566 - val_dice_coef: 0.8739 - val_dice_coe: 0.8718 - lr: 1.0000e-05
# Epoch 13/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9968 - dice_coef: 0.9977 - dice_coe: 0.9977
# Epoch 00013: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0013_val_weights.h5
# 200/200 [==============================] - 196s 982ms/step - loss: 0.0049 - accuracy: 0.9968 - dice_coef: 0.9977 - dice_coe: 0.9977 - val_loss: 0.3180 - val_accuracy: 0.8805 - val_dice_coef: 0.8955 - val_dice_coe: 0.8936 - lr: 1.0000e-05
# Epoch 14/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9970 - dice_coef: 0.9979 - dice_coe: 0.9978
# Epoch 00014: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0014_val_weights.h5
# 200/200 [==============================] - 196s 982ms/step - loss: 0.0046 - accuracy: 0.9970 - dice_coef: 0.9979 - dice_coe: 0.9978 - val_loss: 0.3743 - val_accuracy: 0.8593 - val_dice_coef: 0.8767 - val_dice_coe: 0.8747 - lr: 1.0000e-05
# Epoch 15/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9980
# Epoch 00015: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0015_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0044 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9980 - val_loss: 0.3487 - val_accuracy: 0.8704 - val_dice_coef: 0.8864 - val_dice_coe: 0.8845 - lr: 1.0000e-05
# Epoch 16/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9967 - dice_coef: 0.9976 - dice_coe: 0.9976
# Epoch 00016: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0016_val_weights.h5
# 200/200 [==============================] - 197s 984ms/step - loss: 0.0052 - accuracy: 0.9967 - dice_coef: 0.9976 - dice_coe: 0.9976 - val_loss: 0.3266 - val_accuracy: 0.8744 - val_dice_coef: 0.8909 - val_dice_coe: 0.8889 - lr: 1.0000e-05
# Epoch 17/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9980
# Epoch 00017: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0017_val_weights.h5
# 200/200 [==============================] - 197s 985ms/step - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9980 - val_loss: 0.3585 - val_accuracy: 0.8703 - val_dice_coef: 0.8856 - val_dice_coe: 0.8839 - lr: 1.0000e-05
# Epoch 18/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9973 - dice_coef: 0.9981 - dice_coe: 0.9981
# Epoch 00018: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0018_val_weights.h5
# 200/200 [==============================] - 197s 984ms/step - loss: 0.0041 - accuracy: 0.9973 - dice_coef: 0.9981 - dice_coe: 0.9981 - val_loss: 0.3753 - val_accuracy: 0.8593 - val_dice_coef: 0.8768 - val_dice_coe: 0.8749 - lr: 1.0000e-05
# Epoch 19/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9967 - dice_coef: 0.9976 - dice_coe: 0.9976
# Epoch 00019: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0019_val_weights.h5
# 200/200 [==============================] - 199s 999ms/step - loss: 0.0051 - accuracy: 0.9967 - dice_coef: 0.9976 - dice_coe: 0.9976 - val_loss: 0.3291 - val_accuracy: 0.8751 - val_dice_coef: 0.8916 - val_dice_coe: 0.8897 - lr: 1.0000e-05
# Epoch 20/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979
# Epoch 00020: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0020_val_weights.h5
# 200/200 [==============================] - 200s 999ms/step - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979 - val_loss: 0.3740 - val_accuracy: 0.8601 - val_dice_coef: 0.8772 - val_dice_coe: 0.8753 - lr: 1.0000e-05
# Epoch 21/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9966 - dice_coef: 0.9975 - dice_coe: 0.9975
# Epoch 00021: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0021_val_weights.h5
# 200/200 [==============================] - 197s 988ms/step - loss: 0.0054 - accuracy: 0.9966 - dice_coef: 0.9975 - dice_coe: 0.9975 - val_loss: 0.3513 - val_accuracy: 0.8722 - val_dice_coef: 0.8874 - val_dice_coe: 0.8856 - lr: 1.0000e-05
# Epoch 22/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979
# Epoch 00022: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0022_val_weights.h5
# 200/200 [==============================] - 196s 979ms/step - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979 - val_loss: 0.3931 - val_accuracy: 0.8533 - val_dice_coef: 0.8712 - val_dice_coe: 0.8692 - lr: 1.0000e-05
# Epoch 23/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9975 - dice_coef: 0.9982 - dice_coe: 0.9982
# Epoch 00023: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0023_val_weights.h5
# 200/200 [==============================] - 197s 986ms/step - loss: 0.0039 - accuracy: 0.9975 - dice_coef: 0.9982 - dice_coe: 0.9982 - val_loss: 0.3753 - val_accuracy: 0.8586 - val_dice_coef: 0.8761 - val_dice_coe: 0.8741 - lr: 1.0000e-05
# Epoch 24/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9975 - dice_coef: 0.9982 - dice_coe: 0.9982
# Epoch 00024: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0024_val_weights.h5
# 200/200 [==============================] - 196s 981ms/step - loss: 0.0040 - accuracy: 0.9975 - dice_coef: 0.9982 - dice_coe: 0.9982 - val_loss: 0.3861 - val_accuracy: 0.8542 - val_dice_coef: 0.8720 - val_dice_coe: 0.8703 - lr: 1.0000e-05
# Epoch 25/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9969 - dice_coef: 0.9978 - dice_coe: 0.9977
# Epoch 00025: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0025_val_weights.h5
# 200/200 [==============================] - 196s 980ms/step - loss: 0.0050 - accuracy: 0.9969 - dice_coef: 0.9978 - dice_coe: 0.9977 - val_loss: 0.3781 - val_accuracy: 0.8616 - val_dice_coef: 0.8783 - val_dice_coe: 0.8763 - lr: 1.0000e-05
# Epoch 26/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9979 - dice_coef: 0.9985 - dice_coe: 0.9985
# Epoch 00026: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0026_val_weights.h5
# 200/200 [==============================] - 196s 981ms/step - loss: 0.0033 - accuracy: 0.9979 - dice_coef: 0.9985 - dice_coe: 0.9985 - val_loss: 0.4070 - val_accuracy: 0.8488 - val_dice_coef: 0.8671 - val_dice_coe: 0.8648 - lr: 1.0000e-05
# Epoch 27/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9979
# Epoch 00027: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0027_val_weights.h5
# 200/200 [==============================] - 196s 979ms/step - loss: 0.0046 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9979 - val_loss: 0.3028 - val_accuracy: 0.8879 - val_dice_coef: 0.9017 - val_dice_coe: 0.9002 - lr: 1.0000e-05
# Epoch 28/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979
# Epoch 00028: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0028_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979 - val_loss: 0.3724 - val_accuracy: 0.8610 - val_dice_coef: 0.8782 - val_dice_coe: 0.8762 - lr: 1.0000e-05
# Epoch 29/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9970 - dice_coef: 0.9978 - dice_coe: 0.9978
# Epoch 00029: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0029_val_weights.h5
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0049 - accuracy: 0.9970 - dice_coef: 0.9978 - dice_coe: 0.9978 - val_loss: 0.3533 - val_accuracy: 0.8714 - val_dice_coef: 0.8872 - val_dice_coe: 0.8853 - lr: 1.0000e-05
# Epoch 30/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9980
# Epoch 00030: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0030_val_weights.h5
# 200/200 [==============================] - 196s 981ms/step - loss: 0.0043 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9980 - val_loss: 0.3770 - val_accuracy: 0.8580 - val_dice_coef: 0.8756 - val_dice_coe: 0.8734 - lr: 1.0000e-05
# Epoch 31/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979
# Epoch 00031: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0031_val_weights.h5
# 200/200 [==============================] - 196s 980ms/step - loss: 0.0047 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979 - val_loss: 0.3681 - val_accuracy: 0.8630 - val_dice_coef: 0.8798 - val_dice_coe: 0.8779 - lr: 1.0000e-05
# Epoch 32/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9980
# Epoch 00032: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0032_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0044 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9980 - val_loss: 0.3907 - val_accuracy: 0.8545 - val_dice_coef: 0.8721 - val_dice_coe: 0.8700 - lr: 1.0000e-05
# Epoch 33/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9973 - dice_coef: 0.9980 - dice_coe: 0.9980
# Epoch 00033: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0033_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0043 - accuracy: 0.9973 - dice_coef: 0.9980 - dice_coe: 0.9980 - val_loss: 0.3709 - val_accuracy: 0.8650 - val_dice_coef: 0.8816 - val_dice_coe: 0.8798 - lr: 1.0000e-05
# Epoch 34/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9970 - dice_coef: 0.9978 - dice_coe: 0.9978
# Epoch 00034: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0034_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0048 - accuracy: 0.9970 - dice_coef: 0.9978 - dice_coe: 0.9978 - val_loss: 0.3822 - val_accuracy: 0.8574 - val_dice_coef: 0.8748 - val_dice_coe: 0.8727 - lr: 1.0000e-05
# Epoch 35/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9969 - dice_coef: 0.9978 - dice_coe: 0.9978
# Epoch 00035: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0035_val_weights.h5
# 200/200 [==============================] - 196s 981ms/step - loss: 0.0049 - accuracy: 0.9969 - dice_coef: 0.9978 - dice_coe: 0.9978 - val_loss: 0.3196 - val_accuracy: 0.8768 - val_dice_coef: 0.8928 - val_dice_coe: 0.8909 - lr: 1.0000e-05
# Epoch 36/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9975 - dice_coef: 0.9982 - dice_coe: 0.9982
# Epoch 00036: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0036_val_weights.h5
# 200/200 [==============================] - 196s 980ms/step - loss: 0.0039 - accuracy: 0.9975 - dice_coef: 0.9982 - dice_coe: 0.9982 - val_loss: 0.3846 - val_accuracy: 0.8533 - val_dice_coef: 0.8716 - val_dice_coe: 0.8696 - lr: 1.0000e-05
# Epoch 37/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9967 - dice_coef: 0.9976 - dice_coe: 0.9976
# Epoch 00037: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0037_val_weights.h5
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0051 - accuracy: 0.9967 - dice_coef: 0.9976 - dice_coe: 0.9976 - val_loss: 0.3561 - val_accuracy: 0.8667 - val_dice_coef: 0.8834 - val_dice_coe: 0.8816 - lr: 1.0000e-05
# Epoch 38/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979
# Epoch 00038: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0038_val_weights.h5
# 200/200 [==============================] - 196s 981ms/step - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979 - val_loss: 0.3245 - val_accuracy: 0.8788 - val_dice_coef: 0.8940 - val_dice_coe: 0.8924 - lr: 1.0000e-05
# Epoch 39/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9970 - dice_coef: 0.9979 - dice_coe: 0.9978
# Epoch 00039: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0039_val_weights.h5
# 200/200 [==============================] - 195s 976ms/step - loss: 0.0047 - accuracy: 0.9970 - dice_coef: 0.9979 - dice_coe: 0.9978 - val_loss: 0.3975 - val_accuracy: 0.8544 - val_dice_coef: 0.8719 - val_dice_coe: 0.8696 - lr: 1.0000e-05
# Epoch 40/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9965 - dice_coef: 0.9975 - dice_coe: 0.9975
# Epoch 00040: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0040_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0056 - accuracy: 0.9965 - dice_coef: 0.9975 - dice_coe: 0.9975 - val_loss: 0.3900 - val_accuracy: 0.8535 - val_dice_coef: 0.8714 - val_dice_coe: 0.8695 - lr: 1.0000e-05
# Epoch 41/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9965 - dice_coef: 0.9975 - dice_coe: 0.9975
# Epoch 00041: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0041_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0054 - accuracy: 0.9965 - dice_coef: 0.9975 - dice_coe: 0.9975 - val_loss: 0.3624 - val_accuracy: 0.8620 - val_dice_coef: 0.8798 - val_dice_coe: 0.8779 - lr: 1.0000e-05
# Epoch 42/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9970 - dice_coef: 0.9978 - dice_coe: 0.9978
# Epoch 00042: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0042_val_weights.h5
# 200/200 [==============================] - 195s 976ms/step - loss: 0.0048 - accuracy: 0.9970 - dice_coef: 0.9978 - dice_coe: 0.9978 - val_loss: 0.3295 - val_accuracy: 0.8777 - val_dice_coef: 0.8931 - val_dice_coe: 0.8914 - lr: 1.0000e-05
# Epoch 43/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979
# Epoch 00043: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0043_val_weights.h5
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0046 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979 - val_loss: 0.3425 - val_accuracy: 0.8740 - val_dice_coef: 0.8896 - val_dice_coe: 0.8878 - lr: 1.0000e-05
# Epoch 44/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979
# Epoch 00044: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0044_val_weights.h5
# 200/200 [==============================] - 196s 979ms/step - loss: 0.0046 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979 - val_loss: 0.3194 - val_accuracy: 0.8755 - val_dice_coef: 0.8923 - val_dice_coe: 0.8904 - lr: 1.0000e-05
# Epoch 45/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979
# Epoch 00045: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0045_val_weights.h5
# 200/200 [==============================] - 196s 979ms/step - loss: 0.0046 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979 - val_loss: 0.3552 - val_accuracy: 0.8693 - val_dice_coef: 0.8850 - val_dice_coe: 0.8831 - lr: 1.0000e-05
# Epoch 46/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9974 - dice_coef: 0.9982 - dice_coe: 0.9981
# Epoch 00046: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0046_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0041 - accuracy: 0.9974 - dice_coef: 0.9982 - dice_coe: 0.9981 - val_loss: 0.3474 - val_accuracy: 0.8742 - val_dice_coef: 0.8895 - val_dice_coe: 0.8878 - lr: 1.0000e-05
# Epoch 47/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9976 - dice_coef: 0.9983 - dice_coe: 0.9983
# Epoch 00047: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0047_val_weights.h5
# 200/200 [==============================] - 196s 980ms/step - loss: 0.0037 - accuracy: 0.9976 - dice_coef: 0.9983 - dice_coe: 0.9983 - val_loss: 0.3390 - val_accuracy: 0.8745 - val_dice_coef: 0.8900 - val_dice_coe: 0.8884 - lr: 1.0000e-05
# Epoch 48/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9968 - dice_coef: 0.9977 - dice_coe: 0.9977
# Epoch 00048: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0048_val_weights.h5
# 200/200 [==============================] - 196s 980ms/step - loss: 0.0050 - accuracy: 0.9968 - dice_coef: 0.9977 - dice_coe: 0.9977 - val_loss: 0.3733 - val_accuracy: 0.8600 - val_dice_coef: 0.8776 - val_dice_coe: 0.8756 - lr: 1.0000e-05
# Epoch 49/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9970 - dice_coef: 0.9979 - dice_coe: 0.9979
# Epoch 00049: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0049_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0046 - accuracy: 0.9970 - dice_coef: 0.9979 - dice_coe: 0.9979 - val_loss: 0.3791 - val_accuracy: 0.8603 - val_dice_coef: 0.8772 - val_dice_coe: 0.8751 - lr: 1.0000e-05
# Epoch 50/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9980
# Epoch 00050: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0050_val_weights.h5
# 200/200 [==============================] - 196s 980ms/step - loss: 0.0043 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9980 - val_loss: 0.4198 - val_accuracy: 0.8474 - val_dice_coef: 0.8645 - val_dice_coe: 0.8624 - lr: 1.0000e-05
# Epoch 51/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9974 - dice_coef: 0.9981 - dice_coe: 0.9981
# Epoch 00051: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0051_val_weights.h5
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0041 - accuracy: 0.9974 - dice_coef: 0.9981 - dice_coe: 0.9981 - val_loss: 0.4072 - val_accuracy: 0.8509 - val_dice_coef: 0.8690 - val_dice_coe: 0.8672 - lr: 1.0000e-05
# Epoch 52/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979
# Epoch 00052: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0052_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979 - val_loss: 0.3723 - val_accuracy: 0.8653 - val_dice_coef: 0.8815 - val_dice_coe: 0.8796 - lr: 1.0000e-05
# Epoch 53/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979
# Epoch 00053: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0053_val_weights.h5
# 200/200 [==============================] - 196s 980ms/step - loss: 0.0046 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979 - val_loss: 0.3884 - val_accuracy: 0.8568 - val_dice_coef: 0.8740 - val_dice_coe: 0.8722 - lr: 1.0000e-05
# Epoch 54/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979
# Epoch 00054: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0054_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979 - val_loss: 0.3656 - val_accuracy: 0.8669 - val_dice_coef: 0.8831 - val_dice_coe: 0.8810 - lr: 1.0000e-05
# Epoch 55/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9967 - dice_coef: 0.9977 - dice_coe: 0.9977
# Epoch 00055: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0055_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0050 - accuracy: 0.9967 - dice_coef: 0.9977 - dice_coe: 0.9977 - val_loss: 0.3443 - val_accuracy: 0.8713 - val_dice_coef: 0.8872 - val_dice_coe: 0.8855 - lr: 1.0000e-05
# Epoch 56/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9976 - dice_coef: 0.9983 - dice_coe: 0.9982
# Epoch 00056: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0056_val_weights.h5
# 200/200 [==============================] - 195s 979ms/step - loss: 0.0038 - accuracy: 0.9976 - dice_coef: 0.9983 - dice_coe: 0.9982 - val_loss: 0.3775 - val_accuracy: 0.8630 - val_dice_coef: 0.8796 - val_dice_coe: 0.8773 - lr: 1.0000e-05
# Epoch 57/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9966 - dice_coef: 0.9975 - dice_coe: 0.9975
# Epoch 00057: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0057_val_weights.h5
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 3.1622775802825263e-06.
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0056 - accuracy: 0.9966 - dice_coef: 0.9975 - dice_coe: 0.9975 - val_loss: 0.3620 - val_accuracy: 0.8654 - val_dice_coef: 0.8820 - val_dice_coe: 0.8800 - lr: 1.0000e-05
# Epoch 58/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979
# Epoch 00058: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0058_val_weights.h5
# 200/200 [==============================] - 196s 980ms/step - loss: 0.0045 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979 - val_loss: 0.3870 - val_accuracy: 0.8581 - val_dice_coef: 0.8750 - val_dice_coe: 0.8731 - lr: 3.1623e-06
# Epoch 59/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9975 - dice_coef: 0.9982 - dice_coe: 0.9982
# Epoch 00059: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0059_val_weights.h5
# 200/200 [==============================] - 195s 979ms/step - loss: 0.0040 - accuracy: 0.9975 - dice_coef: 0.9982 - dice_coe: 0.9982 - val_loss: 0.3874 - val_accuracy: 0.8583 - val_dice_coef: 0.8756 - val_dice_coe: 0.8736 - lr: 3.1623e-06
# Epoch 60/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9966 - dice_coef: 0.9976 - dice_coe: 0.9975
# Epoch 00060: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0060_val_weights.h5
# 200/200 [==============================] - 196s 983ms/step - loss: 0.0053 - accuracy: 0.9966 - dice_coef: 0.9976 - dice_coe: 0.9975 - val_loss: 0.3970 - val_accuracy: 0.8553 - val_dice_coef: 0.8727 - val_dice_coe: 0.8707 - lr: 3.1623e-06
# Epoch 61/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9963 - dice_coef: 0.9974 - dice_coe: 0.9973
# Epoch 00061: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0061_val_weights.h5
# 200/200 [==============================] - 195s 975ms/step - loss: 0.0059 - accuracy: 0.9963 - dice_coef: 0.9974 - dice_coe: 0.9973 - val_loss: 0.3689 - val_accuracy: 0.8613 - val_dice_coef: 0.8786 - val_dice_coe: 0.8768 - lr: 3.1623e-06
# Epoch 62/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979
# Epoch 00062: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0062_val_weights.h5
# 200/200 [==============================] - 196s 979ms/step - loss: 0.0044 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9979 - val_loss: 0.3727 - val_accuracy: 0.8638 - val_dice_coef: 0.8802 - val_dice_coe: 0.8782 - lr: 3.1623e-06
# Epoch 63/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9976 - dice_coef: 0.9983 - dice_coe: 0.9983
# Epoch 00063: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0063_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0038 - accuracy: 0.9976 - dice_coef: 0.9983 - dice_coe: 0.9983 - val_loss: 0.3848 - val_accuracy: 0.8600 - val_dice_coef: 0.8763 - val_dice_coe: 0.8745 - lr: 3.1623e-06
# Epoch 64/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979
# Epoch 00064: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0064_val_weights.h5
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0050 - accuracy: 0.9971 - dice_coef: 0.9979 - dice_coe: 0.9979 - val_loss: 0.3461 - val_accuracy: 0.8713 - val_dice_coef: 0.8872 - val_dice_coe: 0.8853 - lr: 3.1623e-06
# Epoch 65/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9967 - dice_coef: 0.9976 - dice_coe: 0.9976
# Epoch 00065: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0065_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0052 - accuracy: 0.9967 - dice_coef: 0.9976 - dice_coe: 0.9976 - val_loss: 0.3778 - val_accuracy: 0.8559 - val_dice_coef: 0.8741 - val_dice_coe: 0.8721 - lr: 3.1623e-06
# Epoch 66/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9965 - dice_coef: 0.9975 - dice_coe: 0.9975
# Epoch 00066: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0066_val_weights.h5
# 200/200 [==============================] - 195s 975ms/step - loss: 0.0055 - accuracy: 0.9965 - dice_coef: 0.9975 - dice_coe: 0.9975 - val_loss: 0.3882 - val_accuracy: 0.8599 - val_dice_coef: 0.8766 - val_dice_coe: 0.8748 - lr: 3.1623e-06
# Epoch 67/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9969 - dice_coef: 0.9978 - dice_coe: 0.9978
# Epoch 00067: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0067_val_weights.h5
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0048 - accuracy: 0.9969 - dice_coef: 0.9978 - dice_coe: 0.9978 - val_loss: 0.4010 - val_accuracy: 0.8571 - val_dice_coef: 0.8735 - val_dice_coe: 0.8717 - lr: 3.1623e-06
# Epoch 68/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9974 - dice_coef: 0.9981 - dice_coe: 0.9981
# Epoch 00068: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0068_val_weights.h5
# 200/200 [==============================] - 195s 978ms/step - loss: 0.0044 - accuracy: 0.9974 - dice_coef: 0.9981 - dice_coe: 0.9981 - val_loss: 0.3532 - val_accuracy: 0.8625 - val_dice_coef: 0.8804 - val_dice_coe: 0.8785 - lr: 3.1623e-06
# Epoch 69/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9969 - dice_coef: 0.9978 - dice_coe: 0.9978
# Epoch 00069: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0069_val_weights.h5
# 200/200 [==============================] - 194s 971ms/step - loss: 0.0048 - accuracy: 0.9969 - dice_coef: 0.9978 - dice_coe: 0.9978 - val_loss: 0.3512 - val_accuracy: 0.8668 - val_dice_coef: 0.8836 - val_dice_coe: 0.8816 - lr: 3.1623e-06
# Epoch 70/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9980
# Epoch 00070: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0070_val_weights.h5
# 200/200 [==============================] - 195s 979ms/step - loss: 0.0044 - accuracy: 0.9972 - dice_coef: 0.9980 - dice_coe: 0.9980 - val_loss: 0.3947 - val_accuracy: 0.8533 - val_dice_coef: 0.8712 - val_dice_coe: 0.8692 - lr: 3.1623e-06
# Epoch 71/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9968 - dice_coef: 0.9977 - dice_coe: 0.9977
# Epoch 00071: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0071_val_weights.h5
# 200/200 [==============================] - 196s 982ms/step - loss: 0.0049 - accuracy: 0.9968 - dice_coef: 0.9977 - dice_coe: 0.9977 - val_loss: 0.3605 - val_accuracy: 0.8645 - val_dice_coef: 0.8813 - val_dice_coe: 0.8793 - lr: 3.1623e-06
# Epoch 72/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9973 - dice_coef: 0.9981 - dice_coe: 0.9981
# Epoch 00072: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0072_val_weights.h5
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0043 - accuracy: 0.9973 - dice_coef: 0.9981 - dice_coe: 0.9981 - val_loss: 0.3613 - val_accuracy: 0.8688 - val_dice_coef: 0.8846 - val_dice_coe: 0.8829 - lr: 3.1623e-06
# Epoch 73/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9966 - dice_coef: 0.9976 - dice_coe: 0.9976
# Epoch 00073: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0073_val_weights.h5
# 200/200 [==============================] - 196s 979ms/step - loss: 0.0054 - accuracy: 0.9966 - dice_coef: 0.9976 - dice_coe: 0.9976 - val_loss: 0.3651 - val_accuracy: 0.8641 - val_dice_coef: 0.8810 - val_dice_coe: 0.8793 - lr: 3.1623e-06
# Epoch 74/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9967 - dice_coef: 0.9977 - dice_coe: 0.9977
# Epoch 00074: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0074_val_weights.h5
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0050 - accuracy: 0.9967 - dice_coef: 0.9977 - dice_coe: 0.9977 - val_loss: 0.3786 - val_accuracy: 0.8606 - val_dice_coef: 0.8778 - val_dice_coe: 0.8759 - lr: 3.1623e-06
# Epoch 75/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9974 - dice_coef: 0.9981 - dice_coe: 0.9981
# Epoch 00075: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0075_val_weights.h5
# 200/200 [==============================] - 195s 977ms/step - loss: 0.0042 - accuracy: 0.9974 - dice_coef: 0.9981 - dice_coe: 0.9981 - val_loss: 0.3537 - val_accuracy: 0.8647 - val_dice_coef: 0.8819 - val_dice_coe: 0.8801 - lr: 3.1623e-06
# Epoch 76/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9980
# Epoch 00076: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0076_val_weights.h5
# 200/200 [==============================] - 195s 976ms/step - loss: 0.0044 - accuracy: 0.9971 - dice_coef: 0.9980 - dice_coe: 0.9980 - val_loss: 0.3752 - val_accuracy: 0.8634 - val_dice_coef: 0.8796 - val_dice_coe: 0.8777 - lr: 3.1623e-06
# Epoch 77/300
# 200/200 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9967 - dice_coef: 0.9976 - dice_coe: 0.9976
# Epoch 00077: saving model to /home/geoai/eodata/cloud_detect_tensorflow/cloud_and_shadow/logs/checkpoints_0077_val_weights.h5
# 200/200 [==============================] - 195s 974ms/step - loss: 0.0052 - accuracy: 0.9967 - dice_coef: 0.9976 - dice_coe: 0.9976 - val_loss: 0.3767 - val_accuracy: 0.8623 - val_dice_coef: 0.8786 - val_dice_coe: 0.8770 - lr: 3.1623e-06

# %%
unet.save_weights(os.path.join(log_dir, FMT_VALMODEL_LAST_PATH.format(PREFIX)))
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
