# %%
import os
# import model as modellib
# import unet_new as modellib2
# import vgg16unet
import argparse
import numpy as np
import tensorflow as tf
import pandas as pd
import os
import h5py
from data_defores_generator import data_gen, create_list_id,data_gen_not_batch
from datetime import datetime
from tensorflow.keras.callbacks import (ModelCheckpoint, TensorBoard, CSVLogger, History, EarlyStopping, LambdaCallback,ReduceLROnPlateau)

from tensorflow.keras import layers, backend, Model, utils
from matplotlib import pyplot as plt
import rasterio
import cv2
from tensorflow.compat.v1.keras.backend import set_session
# import wanrings
# warnings.filterwarnings("ignore")
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth=True
set_session(tf.compat.v1.Session(config=config))
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
# Out:
# 2022-11-17 11:16:02.153575: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-17 11:16:02.180695: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:02.383355: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:02.383500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:03.978307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:03.978485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:03.978596: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:03.978683: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9483 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
FMT_VALMODEL_PATH ="{}_val_weights.h5"
FMT_VALMODEL_LAST_PATH = "{}_val_weights_last.h5"
FMT_VALMODEL_HIST = "{}_val_hist.csv"
PREFIX = "checkpoints"
INPUT_CHANNEL =  300
INPUT_SIZE = 128#512
early_stop = 50
num_class = 1
log_dir = r"/home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs"
num_epoch = 200
batch_size= 16
scale_neg = 0.1
weight_path = ""

# %%
from model import build_model
unet = build_model((None,None,4),46) #46??
# unet = modellib2.build_model((None,None,3), 32)

# lowest size (None, 64, 64, 512)
# Out:
# 2022-11-17 11:16:04.129795: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:04.129974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:04.130076: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:04.130296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:04.130401: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:04.130498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:04.130628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:04.130730: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 11:16:04.130794: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9483 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# weight_path = r"/home/geoai/eodata/cloud_detect_tensorflow/shadow_only/cp_stretch.h5"
weight_path = r"/home/geoai/eodata/cloud_detect_tensorflow/shadow_only/shadow_only.h5"

if weight_path != "":
    unet.load_weights(weight_path)

# %%
if not os.path.exists(log_dir):
    os.mkdir(log_dir)

# %%
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  4)]
#
#  conv2d (Conv2D)                (None, None, None,   1702        ['input_1[0][0]']
#                                 46)
#
#  batch_normalization (BatchNorm  (None, None, None,   184        ['conv2d[0][0]']
#  alization)                     46)
#
#  leaky_re_lu (LeakyReLU)        (None, None, None,   0           ['batch_normalization[0][0]']
#                                 46)
#
#  conv2d_1 (Conv2D)              (None, None, None,   19090       ['leaky_re_lu[0][0]']
#                                 46)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   184        ['conv2d_1[0][0]']
#  rmalization)                   46)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 46)
#
#  conv2d_2 (Conv2D)              (None, None, None,   19090       ['leaky_re_lu_1[0][0]']
#                                 46)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   184        ['conv2d_2[0][0]']
#  rmalization)                   46)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 46)
#
#  add (Add)                      (None, None, None,   0           ['leaky_re_lu_2[0][0]',
#                                 46)                               'conv2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, None, None,   184        ['add[0][0]']
#  rmalization)                   46)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 46)
#
#  conv2d_3 (Conv2D)              (None, None, None,   19090       ['leaky_re_lu_3[0][0]']
#                                 46)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   184        ['conv2d_3[0][0]']
#  rmalization)                   46)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 46)
#
#  conv2d_4 (Conv2D)              (None, None, None,   19090       ['leaky_re_lu_4[0][0]']
#                                 46)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   184        ['conv2d_4[0][0]']
#  rmalization)                   46)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 46)
#
#  add_1 (Add)                    (None, None, None,   0           ['leaky_re_lu_5[0][0]',
#                                 46)                               'add[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, None, None,   184        ['add_1[0][0]']
#  rmalization)                   46)
#
#  leaky_re_lu_6 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 46)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['leaky_re_lu_6[0][0]']
#                                 46)
#
#  dropout (Dropout)              (None, None, None,   0           ['max_pooling2d[0][0]']
#                                 46)
#
#  conv2d_5 (Conv2D)              (None, None, None,   38180       ['dropout[0][0]']
#                                 92)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   368        ['conv2d_5[0][0]']
#  rmalization)                   92)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 92)
#
#  conv2d_6 (Conv2D)              (None, None, None,   76268       ['leaky_re_lu_7[0][0]']
#                                 92)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   368        ['conv2d_6[0][0]']
#  rmalization)                   92)
#
#  leaky_re_lu_8 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 92)
#
#  conv2d_7 (Conv2D)              (None, None, None,   76268       ['leaky_re_lu_8[0][0]']
#                                 92)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   368        ['conv2d_7[0][0]']
#  rmalization)                   92)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 92)
#
#  add_2 (Add)                    (None, None, None,   0           ['leaky_re_lu_9[0][0]',
#                                 92)                               'conv2d_5[0][0]']
#
#  batch_normalization_10 (BatchN  (None, None, None,   368        ['add_2[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_10 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 92)
#
#  conv2d_8 (Conv2D)              (None, None, None,   76268       ['leaky_re_lu_10[0][0]']
#                                 92)
#
#  batch_normalization_11 (BatchN  (None, None, None,   368        ['conv2d_8[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_11 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 92)
#
#  conv2d_9 (Conv2D)              (None, None, None,   76268       ['leaky_re_lu_11[0][0]']
#                                 92)
#
#  batch_normalization_12 (BatchN  (None, None, None,   368        ['conv2d_9[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_12 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 92)
#
#  add_3 (Add)                    (None, None, None,   0           ['leaky_re_lu_12[0][0]',
#                                 92)                               'add_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, None, None,   368        ['add_3[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 92)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['leaky_re_lu_13[0][0]']
#                                 92)
#
#  dropout_1 (Dropout)            (None, None, None,   0           ['max_pooling2d_1[0][0]']
#                                 92)
#
#  conv2d_10 (Conv2D)             (None, None, None,   152536      ['dropout_1[0][0]']
#                                 184)
#
#  batch_normalization_14 (BatchN  (None, None, None,   736        ['conv2d_10[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_14 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_14[0][0]']
#                                 184)
#
#  conv2d_11 (Conv2D)             (None, None, None,   304888      ['leaky_re_lu_14[0][0]']
#                                 184)
#
#  batch_normalization_15 (BatchN  (None, None, None,   736        ['conv2d_11[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 184)
#
#  conv2d_12 (Conv2D)             (None, None, None,   304888      ['leaky_re_lu_15[0][0]']
#                                 184)
#
#  batch_normalization_16 (BatchN  (None, None, None,   736        ['conv2d_12[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 184)
#
#  add_4 (Add)                    (None, None, None,   0           ['leaky_re_lu_16[0][0]',
#                                 184)                              'conv2d_10[0][0]']
#
#  batch_normalization_17 (BatchN  (None, None, None,   736        ['add_4[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_17 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 184)
#
#  conv2d_13 (Conv2D)             (None, None, None,   304888      ['leaky_re_lu_17[0][0]']
#                                 184)
#
#  batch_normalization_18 (BatchN  (None, None, None,   736        ['conv2d_13[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_18 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 184)
#
#  conv2d_14 (Conv2D)             (None, None, None,   304888      ['leaky_re_lu_18[0][0]']
#                                 184)
#
#  batch_normalization_19 (BatchN  (None, None, None,   736        ['conv2d_14[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 184)
#
#  add_5 (Add)                    (None, None, None,   0           ['leaky_re_lu_19[0][0]',
#                                 184)                              'add_4[0][0]']
#
#  batch_normalization_20 (BatchN  (None, None, None,   736        ['add_5[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_20 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 184)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['leaky_re_lu_20[0][0]']
#                                 184)
#
#  dropout_2 (Dropout)            (None, None, None,   0           ['max_pooling2d_2[0][0]']
#                                 184)
#
#  conv2d_15 (Conv2D)             (None, None, None,   609776      ['dropout_2[0][0]']
#                                 368)
#
#  batch_normalization_21 (BatchN  (None, None, None,   1472       ['conv2d_15[0][0]']
#  ormalization)                  368)
#
#  leaky_re_lu_21 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 368)
#
#  conv2d_16 (Conv2D)             (None, None, None,   1219184     ['leaky_re_lu_21[0][0]']
#                                 368)
#
#  batch_normalization_22 (BatchN  (None, None, None,   1472       ['conv2d_16[0][0]']
#  ormalization)                  368)
#
#  leaky_re_lu_22 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 368)
#
#  conv2d_17 (Conv2D)             (None, None, None,   1219184     ['leaky_re_lu_22[0][0]']
#                                 368)
#
#  batch_normalization_23 (BatchN  (None, None, None,   1472       ['conv2d_17[0][0]']
#  ormalization)                  368)
#
#  leaky_re_lu_23 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 368)
#
#  add_6 (Add)                    (None, None, None,   0           ['leaky_re_lu_23[0][0]',
#                                 368)                              'conv2d_15[0][0]']
#
#  batch_normalization_24 (BatchN  (None, None, None,   1472       ['add_6[0][0]']
#  ormalization)                  368)
#
#  leaky_re_lu_24 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 368)
#
#  conv2d_18 (Conv2D)             (None, None, None,   1219184     ['leaky_re_lu_24[0][0]']
#                                 368)
#
#  batch_normalization_25 (BatchN  (None, None, None,   1472       ['conv2d_18[0][0]']
#  ormalization)                  368)
#
#  leaky_re_lu_25 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 368)
#
#  conv2d_19 (Conv2D)             (None, None, None,   1219184     ['leaky_re_lu_25[0][0]']
#                                 368)
#
#  batch_normalization_26 (BatchN  (None, None, None,   1472       ['conv2d_19[0][0]']
#  ormalization)                  368)
#
#  leaky_re_lu_26 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 368)
#
#  add_7 (Add)                    (None, None, None,   0           ['leaky_re_lu_26[0][0]',
#                                 368)                              'add_6[0][0]']
#
#  batch_normalization_27 (BatchN  (None, None, None,   1472       ['add_7[0][0]']
#  ormalization)                  368)
#
#  leaky_re_lu_27 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 368)
#
#  conv2d_transpose (Conv2DTransp  (None, None, None,   609592     ['leaky_re_lu_27[0][0]']
#  ose)                           184)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['conv2d_transpose[0][0]',
#                                 368)                              'leaky_re_lu_20[0][0]']
#
#  dropout_3 (Dropout)            (None, None, None,   0           ['concatenate[0][0]']
#                                 368)
#
#  conv2d_20 (Conv2D)             (None, None, None,   609592      ['dropout_3[0][0]']
#                                 184)
#
#  batch_normalization_28 (BatchN  (None, None, None,   736        ['conv2d_20[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_28 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 184)
#
#  conv2d_21 (Conv2D)             (None, None, None,   304888      ['leaky_re_lu_28[0][0]']
#                                 184)
#
#  batch_normalization_29 (BatchN  (None, None, None,   736        ['conv2d_21[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_29 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 184)
#
#  conv2d_22 (Conv2D)             (None, None, None,   304888      ['leaky_re_lu_29[0][0]']
#                                 184)
#
#  batch_normalization_30 (BatchN  (None, None, None,   736        ['conv2d_22[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_30 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 184)
#
#  add_8 (Add)                    (None, None, None,   0           ['leaky_re_lu_30[0][0]',
#                                 184)                              'conv2d_20[0][0]']
#
#  batch_normalization_31 (BatchN  (None, None, None,   736        ['add_8[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_31 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 184)
#
#  conv2d_23 (Conv2D)             (None, None, None,   304888      ['leaky_re_lu_31[0][0]']
#                                 184)
#
#  batch_normalization_32 (BatchN  (None, None, None,   736        ['conv2d_23[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_32 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 184)
#
#  conv2d_24 (Conv2D)             (None, None, None,   304888      ['leaky_re_lu_32[0][0]']
#                                 184)
#
#  batch_normalization_33 (BatchN  (None, None, None,   736        ['conv2d_24[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_33 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 184)
#
#  add_9 (Add)                    (None, None, None,   0           ['leaky_re_lu_33[0][0]',
#                                 184)                              'add_8[0][0]']
#
#  batch_normalization_34 (BatchN  (None, None, None,   736        ['add_9[0][0]']
#  ormalization)                  184)
#
#  leaky_re_lu_34 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 184)
#
#  conv2d_transpose_1 (Conv2DTran  (None, None, None,   152444     ['leaky_re_lu_34[0][0]']
#  spose)                         92)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['conv2d_transpose_1[0][0]',
#                                 184)                              'leaky_re_lu_13[0][0]']
#
#  dropout_4 (Dropout)            (None, None, None,   0           ['concatenate_1[0][0]']
#                                 184)
#
#  conv2d_25 (Conv2D)             (None, None, None,   152444      ['dropout_4[0][0]']
#                                 92)
#
#  batch_normalization_35 (BatchN  (None, None, None,   368        ['conv2d_25[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_35 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 92)
#
#  conv2d_26 (Conv2D)             (None, None, None,   76268       ['leaky_re_lu_35[0][0]']
#                                 92)
#
#  batch_normalization_36 (BatchN  (None, None, None,   368        ['conv2d_26[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_36 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 92)
#
#  conv2d_27 (Conv2D)             (None, None, None,   76268       ['leaky_re_lu_36[0][0]']
#                                 92)
#
#  batch_normalization_37 (BatchN  (None, None, None,   368        ['conv2d_27[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_37 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 92)
#
#  add_10 (Add)                   (None, None, None,   0           ['leaky_re_lu_37[0][0]',
#                                 92)                               'conv2d_25[0][0]']
#
#  batch_normalization_38 (BatchN  (None, None, None,   368        ['add_10[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_38 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 92)
#
#  conv2d_28 (Conv2D)             (None, None, None,   76268       ['leaky_re_lu_38[0][0]']
#                                 92)
#
#  batch_normalization_39 (BatchN  (None, None, None,   368        ['conv2d_28[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_39 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 92)
#
#  conv2d_29 (Conv2D)             (None, None, None,   76268       ['leaky_re_lu_39[0][0]']
#                                 92)
#
#  batch_normalization_40 (BatchN  (None, None, None,   368        ['conv2d_29[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_40 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_40[0][0]']
#                                 92)
#
#  add_11 (Add)                   (None, None, None,   0           ['leaky_re_lu_40[0][0]',
#                                 92)                               'add_10[0][0]']
#
#  batch_normalization_41 (BatchN  (None, None, None,   368        ['add_11[0][0]']
#  ormalization)                  92)
#
#  leaky_re_lu_41 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 92)
#
#  conv2d_transpose_2 (Conv2DTran  (None, None, None,   38134      ['leaky_re_lu_41[0][0]']
#  spose)                         46)
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['conv2d_transpose_2[0][0]',
#                                 92)                               'leaky_re_lu_6[0][0]']
#
#  dropout_5 (Dropout)            (None, None, None,   0           ['concatenate_2[0][0]']
#                                 92)
#
#  conv2d_30 (Conv2D)             (None, None, None,   38134       ['dropout_5[0][0]']
#                                 46)
#
#  batch_normalization_42 (BatchN  (None, None, None,   184        ['conv2d_30[0][0]']
#  ormalization)                  46)
#
#  leaky_re_lu_42 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 46)
#
#  conv2d_31 (Conv2D)             (None, None, None,   19090       ['leaky_re_lu_42[0][0]']
#                                 46)
#
#  batch_normalization_43 (BatchN  (None, None, None,   184        ['conv2d_31[0][0]']
#  ormalization)                  46)
#
#  leaky_re_lu_43 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_43[0][0]']
#                                 46)
#
#  conv2d_32 (Conv2D)             (None, None, None,   19090       ['leaky_re_lu_43[0][0]']
#                                 46)
#
#  batch_normalization_44 (BatchN  (None, None, None,   184        ['conv2d_32[0][0]']
#  ormalization)                  46)
#
#  leaky_re_lu_44 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 46)
#
#  add_12 (Add)                   (None, None, None,   0           ['leaky_re_lu_44[0][0]',
#                                 46)                               'conv2d_30[0][0]']
#
#  batch_normalization_45 (BatchN  (None, None, None,   184        ['add_12[0][0]']
#  ormalization)                  46)
#
#  leaky_re_lu_45 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 46)
#
#  conv2d_33 (Conv2D)             (None, None, None,   19090       ['leaky_re_lu_45[0][0]']
#                                 46)
#
#  batch_normalization_46 (BatchN  (None, None, None,   184        ['conv2d_33[0][0]']
#  ormalization)                  46)
#
#  leaky_re_lu_46 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_46[0][0]']
#                                 46)
#
#  conv2d_34 (Conv2D)             (None, None, None,   19090       ['leaky_re_lu_46[0][0]']
#                                 46)
#
#  batch_normalization_47 (BatchN  (None, None, None,   184        ['conv2d_34[0][0]']
#  ormalization)                  46)
#
#  leaky_re_lu_47 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_47[0][0]']
#                                 46)
#
#  add_13 (Add)                   (None, None, None,   0           ['leaky_re_lu_47[0][0]',
#                                 46)                               'add_12[0][0]']
#
#  batch_normalization_48 (BatchN  (None, None, None,   184        ['add_13[0][0]']
#  ormalization)                  46)
#
#  leaky_re_lu_48 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_48[0][0]']
#                                 46)
#
#  conv2d_35 (Conv2D)             (None, None, None,   47          ['leaky_re_lu_48[0][0]']
#                                 1)
#
#  activation (Activation)        (None, None, None,   0           ['conv2d_35[0][0]']
#                                 1)
#
# ==================================================================================================
# Total params: 10,509,621
# Trainable params: 10,495,453
# Non-trainable params: 14,168
# __________________________________________________________________________________________________

# %%
checkpoint_dir = os.path.join(log_dir, 'weights')
os.makedirs(checkpoint_dir, exist_ok=True)
model_checkpoint = ModelCheckpoint(
    os.path.join(checkpoint_dir, FMT_VALMODEL_PATH.format(PREFIX + "_{epoch:04d}")),
    verbose=1,
    save_best_only=False,
    save_weights_only=False)

# %%
model_earlystop = EarlyStopping(
    monitor='val_loss',   #val_jaccard_coef_int
    patience=early_stop,
    verbose=0,
    mode='auto'
)

# %%
model_history = History()

model_board = TensorBoard(
    log_dir=os.path.join(log_dir, 'logs'),
    histogram_freq=0,
    write_graph=True,
    embeddings_freq=0)

# %%
lr_reducer = ReduceLROnPlateau(
factor=np.sqrt(0.1),
verbose=1,
patience=30,
min_lr=0.5e-7)

# %%
fig_dir1 = os.path.join(log_dir, 'figs/train')
os.makedirs(fig_dir1, exist_ok=True)

fig_dir2 = os.path.join(log_dir, 'figs/val')
os.makedirs(fig_dir2, exist_ok=True)

def visualize_weight(epoch, model, image_path, mask_path, pos_val, save_locate = None):
    INPUT_SIZE = 512
    color = (0,0,0,0)
    list_id = pos_val
    indx= np.random.choice(len(list_id),4)
    x=[]
    y=[]
    for idx in indx: 
        im_name = list_id[idx]
        image_fn = os.path.join(image_path, im_name)
        mask_fn = os.path.join(mask_path, im_name)
        with rasterio.open(image_fn, 'r') as f1:
            width,height = f1.width,f1.height
            new_image_width = new_image_height = max(width,height)
            # if width < 512 and height < 512:
            values = f1.read().transpose(1,2,0)
            x_center = (new_image_width - width) // 2
            y_center = (new_image_height - height) // 2
            result = np.full((new_image_height,new_image_width, 4), color, dtype=np.float16)
            result[y_center:y_center+height, x_center:x_center+width] = values ## REMOVE indices if input 3 channels
            
            if result.dtype == np.float16: pass
            else: result = cv2.resize(result,(INPUT_SIZE, INPUT_SIZE), interpolation = cv2.INTER_CUBIC)
            
            image = result
            #fill nodata
            list_rand = list(np.random.normal(loc = 2000,scale=200, size=(500000)))
            idx_nodata = np.where(image==0)
            image[idx_nodata] = list_rand.pop(0)

            image = image/15000
            idx_over = np.where(image>1)
            image[idx_over] = 1
            
            with rasterio.open(mask_fn, 'r') as f:
                mask = f.read().astype(np.uint8)
                mask = np.array((mask[0]==2).astype(np.uint8)) #255
                result_mask = np.full((new_image_height,new_image_width), 0, dtype=np.uint8)
                result_mask[y_center:y_center+height, x_center:x_center+width] = mask
                result_mask = cv2.resize(result_mask,(INPUT_SIZE, INPUT_SIZE), interpolation = cv2.INTER_CUBIC).astype(np.uint8)
#                 mask = np.expand_dims(result_mask,axis = -1)
                mask = result_mask
            x.append(image)
            y.append(mask)
    y_predict = model.predict(np.array(x, dtype=np.float16))
    ressult_predict = []
    for i in range(len(x)):        
        predict_mask = y_predict[i].reshape((INPUT_SIZE,INPUT_SIZE))
        predict_mask = (predict_mask>0.5).astype(np.uint8)
        ressult_predict.append(predict_mask)
    fig = plt.figure(figsize=(7, 7))
    rows = 4
    columns = 3
    count = 0
    # if np.random.randint(0, 1000) < 100:
    for i in range(len(x)):
        count = count+1
        image = x[i]
        fig.add_subplot(4, 3, count)
        im_converted = image
        im_converted = np.array(im_converted*255, dtype=np.uint8)
        plt.imshow(im_converted) ##
#         plt.axis('off')
        plt.title("image_{}".format(str(i)))
        mask = y[i]
        count = count+1
        fig.add_subplot(4, 3, count)
        plt.imshow(np.array(mask,dtype = np.uint8), cmap='gray')
#         plt.axis('off')
        plt.title("mask_{}".format(str(i)))
        predict = ressult_predict[i]
        count = count+1
        fig.add_subplot(4, 3, count)
        plt.imshow(np.array(predict,dtype = np.uint8), cmap='gray')
#         plt.axis('off')
        plt.title("result{}".format(str(i)))
    plt.savefig(os.path.join(save_locate,'line plot{}_epoch{}.jpg'.format(PREFIX,epoch+1)), dpi=200)
    plt.close(fig)

# %%
cwd = r"/home/geoai/eodata/cloud_detect_tensorflow/shadow_only/"
image_path = os.path.join(cwd,r"data/train/image")
mask_path = os.path.join(cwd,r"data/train/label")

val_image_path = os.path.join(cwd,r"data/val/image")
val_mask_path = os.path.join(cwd,r"data/val/label")

# %%
image_list = create_list_id(image_path)

image_list_val = create_list_id(val_image_path)

# np.random.shuffle(image_list)
# count = len(image_list)    
# cut_idx = int(round(count*split_ratio))    
# train_list = image_list[0:cut_idx]
# val_list = [id_image for id_image in image_list if id_image not in train_list]
train_list = image_list
val_list = image_list_val

visualize_epoch_train = LambdaCallback(on_epoch_end=lambda epoch, logs: visualize_weight(epoch, unet, image_path, mask_path, train_list, save_locate=fig_dir1))
visualize_epoch_val = LambdaCallback(on_epoch_end=lambda epoch, logs: visualize_weight(epoch, unet, val_image_path, val_mask_path, val_list, save_locate= fig_dir2))

# %%
# Stretched
num_chanel = INPUT_CHANNEL
batch_size = 2
num_epoch = 900
unet.fit_generator(
    generator= data_gen_not_batch(image_path, mask_path, train_list, augment = True, batch_size = batch_size),
    validation_data = data_gen_not_batch(val_image_path, val_mask_path, val_list, augment = False, batch_size = batch_size),
    initial_epoch = 600,
    validation_steps = 50,  # 161
    steps_per_epoch = 385,  # len(image_list)//batch_size, ##2
    epochs=num_epoch,
    verbose = 1,
    callbacks=[model_checkpoint, model_history, model_board, lr_reducer, visualize_epoch_train, visualize_epoch_val],  # model_earlystop
    max_queue_size = 20
)
# Out:
# /tmp/ipykernel_204289/539780162.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   unet.fit_generator(
# /home/skymap/anaconda3/envs/tf2.7/lib/python3.8/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 601/900
# 2022-11-17 11:16:12.255367: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8500
# 2022-11-17 11:16:13.466628: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2022-11-17 11:16:13.467822: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2022-11-17 11:16:13.467836: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2022-11-17 11:16:13.467888: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-11-17 11:16:15.829902: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-11-17 11:16:15.829959: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 385/385 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9911 - f1_m: 0.8402 - precision_m: 0.8408 - recall_m: 0.8442 - dice_coef: 0.8816
# Epoch 00601: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0601_val_weights.h5
# 385/385 [==============================] - 214s 526ms/step - loss: 0.0312 - accuracy: 0.9911 - f1_m: 0.8402 - precision_m: 0.8408 - recall_m: 0.8442 - dice_coef: 0.8816 - val_loss: 0.0397 - val_accuracy: 0.9900 - val_f1_m: 0.8770 - val_precision_m: 0.8910 - val_recall_m: 0.8836 - val_dice_coef: 0.9165 - lr: 1.0000e-05
# Epoch 602/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9904 - f1_m: 0.8506 - precision_m: 0.8493 - recall_m: 0.8559 - dice_coef: 0.8937
# Epoch 00602: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0602_val_weights.h5
# 385/385 [==============================] - 199s 517ms/step - loss: 0.0337 - accuracy: 0.9904 - f1_m: 0.8506 - precision_m: 0.8493 - recall_m: 0.8559 - dice_coef: 0.8937 - val_loss: 0.0397 - val_accuracy: 0.9896 - val_f1_m: 0.8191 - val_precision_m: 0.8235 - val_recall_m: 0.8181 - val_dice_coef: 0.9168 - lr: 1.0000e-05
# Epoch 603/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9915 - f1_m: 0.8565 - precision_m: 0.8598 - recall_m: 0.8581 - dice_coef: 0.9041
# Epoch 00603: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0603_val_weights.h5
# 385/385 [==============================] - 200s 520ms/step - loss: 0.0298 - accuracy: 0.9915 - f1_m: 0.8565 - precision_m: 0.8598 - recall_m: 0.8581 - dice_coef: 0.9041 - val_loss: 0.0328 - val_accuracy: 0.9915 - val_f1_m: 0.9138 - val_precision_m: 0.9138 - val_recall_m: 0.9152 - val_dice_coef: 0.9445 - lr: 1.0000e-05
# Epoch 604/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9919 - f1_m: 0.8475 - precision_m: 0.8528 - recall_m: 0.8476 - dice_coef: 0.8949
# Epoch 00604: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0604_val_weights.h5
# 385/385 [==============================] - 203s 527ms/step - loss: 0.0276 - accuracy: 0.9919 - f1_m: 0.8475 - precision_m: 0.8528 - recall_m: 0.8476 - dice_coef: 0.8949 - val_loss: 0.0381 - val_accuracy: 0.9906 - val_f1_m: 0.8750 - val_precision_m: 0.8823 - val_recall_m: 0.8722 - val_dice_coef: 0.9272 - lr: 1.0000e-05
# Epoch 605/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9908 - f1_m: 0.8463 - precision_m: 0.8457 - recall_m: 0.8529 - dice_coef: 0.8905
# Epoch 00605: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0605_val_weights.h5
# 385/385 [==============================] - 199s 518ms/step - loss: 0.0322 - accuracy: 0.9908 - f1_m: 0.8463 - precision_m: 0.8457 - recall_m: 0.8529 - dice_coef: 0.8905 - val_loss: 0.0428 - val_accuracy: 0.9894 - val_f1_m: 0.8608 - val_precision_m: 0.8657 - val_recall_m: 0.8584 - val_dice_coef: 0.9326 - lr: 1.0000e-05
# Epoch 606/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9923 - f1_m: 0.8242 - precision_m: 0.8285 - recall_m: 0.8278 - dice_coef: 0.8873
# Epoch 00606: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0606_val_weights.h5
# 385/385 [==============================] - 201s 523ms/step - loss: 0.0257 - accuracy: 0.9923 - f1_m: 0.8242 - precision_m: 0.8285 - recall_m: 0.8278 - dice_coef: 0.8873 - val_loss: 0.0335 - val_accuracy: 0.9917 - val_f1_m: 0.8812 - val_precision_m: 0.8890 - val_recall_m: 0.8766 - val_dice_coef: 0.9332 - lr: 1.0000e-05
# Epoch 607/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9909 - f1_m: 0.8737 - precision_m: 0.8791 - recall_m: 0.8736 - dice_coef: 0.9071
# Epoch 00607: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0607_val_weights.h5
# 385/385 [==============================] - 199s 518ms/step - loss: 0.0315 - accuracy: 0.9909 - f1_m: 0.8737 - precision_m: 0.8791 - recall_m: 0.8736 - dice_coef: 0.9071 - val_loss: 0.0221 - val_accuracy: 0.9943 - val_f1_m: 0.8869 - val_precision_m: 0.9052 - val_recall_m: 0.8732 - val_dice_coef: 0.9375 - lr: 1.0000e-05
# Epoch 608/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9914 - f1_m: 0.8605 - precision_m: 0.8616 - recall_m: 0.8639 - dice_coef: 0.8950
# Epoch 00608: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0608_val_weights.h5
# 385/385 [==============================] - 200s 519ms/step - loss: 0.0296 - accuracy: 0.9914 - f1_m: 0.8605 - precision_m: 0.8616 - recall_m: 0.8639 - dice_coef: 0.8950 - val_loss: 0.0430 - val_accuracy: 0.9891 - val_f1_m: 0.8394 - val_precision_m: 0.8592 - val_recall_m: 0.8404 - val_dice_coef: 0.9187 - lr: 1.0000e-05
# Epoch 609/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9913 - f1_m: 0.8677 - precision_m: 0.8764 - recall_m: 0.8660 - dice_coef: 0.9076
# Epoch 00609: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0609_val_weights.h5
# 385/385 [==============================] - 199s 517ms/step - loss: 0.0290 - accuracy: 0.9913 - f1_m: 0.8677 - precision_m: 0.8764 - recall_m: 0.8660 - dice_coef: 0.9076 - val_loss: 0.0381 - val_accuracy: 0.9908 - val_f1_m: 0.8817 - val_precision_m: 0.9005 - val_recall_m: 0.8692 - val_dice_coef: 0.9026 - lr: 1.0000e-05
# Epoch 610/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9910 - f1_m: 0.8596 - precision_m: 0.8618 - recall_m: 0.8622 - dice_coef: 0.8992
# Epoch 00610: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0610_val_weights.h5
# 385/385 [==============================] - 200s 520ms/step - loss: 0.0305 - accuracy: 0.9910 - f1_m: 0.8596 - precision_m: 0.8618 - recall_m: 0.8622 - dice_coef: 0.8992 - val_loss: 0.0421 - val_accuracy: 0.9898 - val_f1_m: 0.8589 - val_precision_m: 0.8814 - val_recall_m: 0.8416 - val_dice_coef: 0.9130 - lr: 1.0000e-05
# Epoch 611/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9916 - f1_m: 0.8636 - precision_m: 0.8657 - recall_m: 0.8663 - dice_coef: 0.9014
# Epoch 00611: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0611_val_weights.h5
# 385/385 [==============================] - 206s 534ms/step - loss: 0.0285 - accuracy: 0.9916 - f1_m: 0.8636 - precision_m: 0.8657 - recall_m: 0.8663 - dice_coef: 0.9014 - val_loss: 0.0300 - val_accuracy: 0.9928 - val_f1_m: 0.9213 - val_precision_m: 0.9366 - val_recall_m: 0.9090 - val_dice_coef: 0.9331 - lr: 1.0000e-05
# Epoch 612/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9913 - f1_m: 0.8455 - precision_m: 0.8479 - recall_m: 0.8484 - dice_coef: 0.8958
# Epoch 00612: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0612_val_weights.h5
# 385/385 [==============================] - 204s 531ms/step - loss: 0.0306 - accuracy: 0.9913 - f1_m: 0.8455 - precision_m: 0.8479 - recall_m: 0.8484 - dice_coef: 0.8958 - val_loss: 0.0310 - val_accuracy: 0.9923 - val_f1_m: 0.9057 - val_precision_m: 0.9233 - val_recall_m: 0.8917 - val_dice_coef: 0.9190 - lr: 1.0000e-05
# Epoch 613/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9913 - f1_m: 0.8751 - precision_m: 0.8801 - recall_m: 0.8750 - dice_coef: 0.9151
# Epoch 00613: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0613_val_weights.h5
# 385/385 [==============================] - 199s 518ms/step - loss: 0.0300 - accuracy: 0.9913 - f1_m: 0.8751 - precision_m: 0.8801 - recall_m: 0.8750 - dice_coef: 0.9151 - val_loss: 0.0400 - val_accuracy: 0.9900 - val_f1_m: 0.8800 - val_precision_m: 0.8924 - val_recall_m: 0.8731 - val_dice_coef: 0.9137 - lr: 1.0000e-05
# Epoch 614/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9922 - f1_m: 0.8439 - precision_m: 0.8465 - recall_m: 0.8451 - dice_coef: 0.9092
# Epoch 00614: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0614_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0265 - accuracy: 0.9922 - f1_m: 0.8439 - precision_m: 0.8465 - recall_m: 0.8451 - dice_coef: 0.9092 - val_loss: 0.0361 - val_accuracy: 0.9907 - val_f1_m: 0.8574 - val_precision_m: 0.8655 - val_recall_m: 0.8541 - val_dice_coef: 0.9005 - lr: 1.0000e-05
# Epoch 615/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9913 - f1_m: 0.8661 - precision_m: 0.8716 - recall_m: 0.8660 - dice_coef: 0.9004
# Epoch 00615: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0615_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0298 - accuracy: 0.9913 - f1_m: 0.8661 - precision_m: 0.8716 - recall_m: 0.8660 - dice_coef: 0.9004 - val_loss: 0.0374 - val_accuracy: 0.9911 - val_f1_m: 0.8398 - val_precision_m: 0.8587 - val_recall_m: 0.8258 - val_dice_coef: 0.8807 - lr: 1.0000e-05
# Epoch 616/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9917 - f1_m: 0.8454 - precision_m: 0.8475 - recall_m: 0.8476 - dice_coef: 0.8968
# Epoch 00616: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0616_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0285 - accuracy: 0.9917 - f1_m: 0.8454 - precision_m: 0.8475 - recall_m: 0.8476 - dice_coef: 0.8968 - val_loss: 0.0374 - val_accuracy: 0.9907 - val_f1_m: 0.9143 - val_precision_m: 0.9241 - val_recall_m: 0.9073 - val_dice_coef: 0.9267 - lr: 1.0000e-05
# Epoch 617/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9914 - f1_m: 0.8594 - precision_m: 0.8630 - recall_m: 0.8589 - dice_coef: 0.9023
# Epoch 00617: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0617_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0289 - accuracy: 0.9914 - f1_m: 0.8594 - precision_m: 0.8630 - recall_m: 0.8589 - dice_coef: 0.9023 - val_loss: 0.0403 - val_accuracy: 0.9903 - val_f1_m: 0.8188 - val_precision_m: 0.8464 - val_recall_m: 0.8119 - val_dice_coef: 0.8989 - lr: 1.0000e-05
# Epoch 618/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9910 - f1_m: 0.8520 - precision_m: 0.8564 - recall_m: 0.8532 - dice_coef: 0.8939
# Epoch 00618: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0618_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0314 - accuracy: 0.9910 - f1_m: 0.8520 - precision_m: 0.8564 - recall_m: 0.8532 - dice_coef: 0.8939 - val_loss: 0.0251 - val_accuracy: 0.9938 - val_f1_m: 0.8705 - val_precision_m: 0.8860 - val_recall_m: 0.8588 - val_dice_coef: 0.9406 - lr: 1.0000e-05
# Epoch 619/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9909 - f1_m: 0.8571 - precision_m: 0.8625 - recall_m: 0.8571 - dice_coef: 0.9066
# Epoch 00619: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0619_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0312 - accuracy: 0.9909 - f1_m: 0.8571 - precision_m: 0.8625 - recall_m: 0.8571 - dice_coef: 0.9066 - val_loss: 0.0398 - val_accuracy: 0.9902 - val_f1_m: 0.8473 - val_precision_m: 0.8668 - val_recall_m: 0.8348 - val_dice_coef: 0.9070 - lr: 1.0000e-05
# Epoch 620/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.9905 - f1_m: 0.8516 - precision_m: 0.8558 - recall_m: 0.8529 - dice_coef: 0.9011
# Epoch 00620: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0620_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0327 - accuracy: 0.9905 - f1_m: 0.8516 - precision_m: 0.8558 - recall_m: 0.8529 - dice_coef: 0.9011 - val_loss: 0.0368 - val_accuracy: 0.9909 - val_f1_m: 0.8813 - val_precision_m: 0.9006 - val_recall_m: 0.8725 - val_dice_coef: 0.9145 - lr: 1.0000e-05
# Epoch 621/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9909 - f1_m: 0.8727 - precision_m: 0.8772 - recall_m: 0.8719 - dice_coef: 0.9099
# Epoch 00621: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0621_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0309 - accuracy: 0.9909 - f1_m: 0.8727 - precision_m: 0.8772 - recall_m: 0.8719 - dice_coef: 0.9099 - val_loss: 0.0339 - val_accuracy: 0.9916 - val_f1_m: 0.9088 - val_precision_m: 0.9391 - val_recall_m: 0.8971 - val_dice_coef: 0.9272 - lr: 1.0000e-05
# Epoch 622/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9914 - f1_m: 0.8802 - precision_m: 0.8892 - recall_m: 0.8768 - dice_coef: 0.9138
# Epoch 00622: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0622_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0288 - accuracy: 0.9914 - f1_m: 0.8802 - precision_m: 0.8892 - recall_m: 0.8768 - dice_coef: 0.9138 - val_loss: 0.0266 - val_accuracy: 0.9928 - val_f1_m: 0.9173 - val_precision_m: 0.9319 - val_recall_m: 0.9051 - val_dice_coef: 0.9482 - lr: 1.0000e-05
# Epoch 623/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9919 - f1_m: 0.8445 - precision_m: 0.8569 - recall_m: 0.8393 - dice_coef: 0.8847
# Epoch 00623: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0623_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0271 - accuracy: 0.9919 - f1_m: 0.8445 - precision_m: 0.8569 - recall_m: 0.8393 - dice_coef: 0.8847 - val_loss: 0.0283 - val_accuracy: 0.9928 - val_f1_m: 0.8679 - val_precision_m: 0.9137 - val_recall_m: 0.8485 - val_dice_coef: 0.9073 - lr: 1.0000e-05
# Epoch 624/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9907 - f1_m: 0.8620 - precision_m: 0.8661 - recall_m: 0.8618 - dice_coef: 0.9055
# Epoch 00624: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0624_val_weights.h5
# 385/385 [==============================] - 198s 513ms/step - loss: 0.0312 - accuracy: 0.9907 - f1_m: 0.8620 - precision_m: 0.8661 - recall_m: 0.8618 - dice_coef: 0.9055 - val_loss: 0.0367 - val_accuracy: 0.9911 - val_f1_m: 0.8585 - val_precision_m: 0.8669 - val_recall_m: 0.8531 - val_dice_coef: 0.9306 - lr: 1.0000e-05
# Epoch 625/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9912 - f1_m: 0.8500 - precision_m: 0.8560 - recall_m: 0.8485 - dice_coef: 0.9043
# Epoch 00625: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0625_val_weights.h5
# 385/385 [==============================] - 198s 513ms/step - loss: 0.0300 - accuracy: 0.9912 - f1_m: 0.8500 - precision_m: 0.8560 - recall_m: 0.8485 - dice_coef: 0.9043 - val_loss: 0.0352 - val_accuracy: 0.9915 - val_f1_m: 0.8867 - val_precision_m: 0.9078 - val_recall_m: 0.8747 - val_dice_coef: 0.9183 - lr: 1.0000e-05
# Epoch 626/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9917 - f1_m: 0.8406 - precision_m: 0.8451 - recall_m: 0.8412 - dice_coef: 0.8926
# Epoch 00626: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0626_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0281 - accuracy: 0.9917 - f1_m: 0.8406 - precision_m: 0.8451 - recall_m: 0.8412 - dice_coef: 0.8926 - val_loss: 0.0336 - val_accuracy: 0.9912 - val_f1_m: 0.9011 - val_precision_m: 0.9293 - val_recall_m: 0.8940 - val_dice_coef: 0.9216 - lr: 1.0000e-05
# Epoch 627/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9918 - f1_m: 0.8479 - precision_m: 0.8586 - recall_m: 0.8430 - dice_coef: 0.8941
# Epoch 00627: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0627_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0276 - accuracy: 0.9918 - f1_m: 0.8479 - precision_m: 0.8586 - recall_m: 0.8430 - dice_coef: 0.8941 - val_loss: 0.0318 - val_accuracy: 0.9919 - val_f1_m: 0.9048 - val_precision_m: 0.9178 - val_recall_m: 0.8942 - val_dice_coef: 0.9365 - lr: 1.0000e-05
# Epoch 628/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9915 - f1_m: 0.8379 - precision_m: 0.8443 - recall_m: 0.8358 - dice_coef: 0.8928
# Epoch 00628: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0628_val_weights.h5
# 385/385 [==============================] - 199s 516ms/step - loss: 0.0284 - accuracy: 0.9915 - f1_m: 0.8379 - precision_m: 0.8443 - recall_m: 0.8358 - dice_coef: 0.8928 - val_loss: 0.0400 - val_accuracy: 0.9902 - val_f1_m: 0.8426 - val_precision_m: 0.8794 - val_recall_m: 0.8291 - val_dice_coef: 0.9027 - lr: 1.0000e-05
# Epoch 629/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9910 - f1_m: 0.8524 - precision_m: 0.8600 - recall_m: 0.8528 - dice_coef: 0.8978
# Epoch 00629: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0629_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0306 - accuracy: 0.9910 - f1_m: 0.8524 - precision_m: 0.8600 - recall_m: 0.8528 - dice_coef: 0.8978 - val_loss: 0.0352 - val_accuracy: 0.9910 - val_f1_m: 0.8920 - val_precision_m: 0.9095 - val_recall_m: 0.8810 - val_dice_coef: 0.9266 - lr: 1.0000e-05
# Epoch 630/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9919 - f1_m: 0.8754 - precision_m: 0.8822 - recall_m: 0.8728 - dice_coef: 0.9170
# Epoch 00630: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0630_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0264 - accuracy: 0.9919 - f1_m: 0.8754 - precision_m: 0.8822 - recall_m: 0.8728 - dice_coef: 0.9170 - val_loss: 0.0366 - val_accuracy: 0.9906 - val_f1_m: 0.8350 - val_precision_m: 0.8444 - val_recall_m: 0.8290 - val_dice_coef: 0.9127 - lr: 1.0000e-05
# Epoch 631/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9916 - f1_m: 0.8533 - precision_m: 0.8648 - recall_m: 0.8497 - dice_coef: 0.8972
# Epoch 00631: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0631_val_weights.h5
# 385/385 [==============================] - 201s 521ms/step - loss: 0.0283 - accuracy: 0.9916 - f1_m: 0.8533 - precision_m: 0.8648 - recall_m: 0.8497 - dice_coef: 0.8972 - val_loss: 0.0319 - val_accuracy: 0.9918 - val_f1_m: 0.8560 - val_precision_m: 0.8899 - val_recall_m: 0.8382 - val_dice_coef: 0.9138 - lr: 1.0000e-05
# Epoch 632/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9916 - f1_m: 0.8557 - precision_m: 0.8611 - recall_m: 0.8555 - dice_coef: 0.9053
# Epoch 00632: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0632_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0285 - accuracy: 0.9916 - f1_m: 0.8557 - precision_m: 0.8611 - recall_m: 0.8555 - dice_coef: 0.9053 - val_loss: 0.0359 - val_accuracy: 0.9912 - val_f1_m: 0.8936 - val_precision_m: 0.9017 - val_recall_m: 0.8891 - val_dice_coef: 0.9263 - lr: 1.0000e-05
# Epoch 633/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9916 - f1_m: 0.8714 - precision_m: 0.8799 - recall_m: 0.8675 - dice_coef: 0.9071
# Epoch 00633: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0633_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0272 - accuracy: 0.9916 - f1_m: 0.8714 - precision_m: 0.8799 - recall_m: 0.8675 - dice_coef: 0.9071 - val_loss: 0.0374 - val_accuracy: 0.9902 - val_f1_m: 0.8560 - val_precision_m: 0.8650 - val_recall_m: 0.8499 - val_dice_coef: 0.9106 - lr: 1.0000e-05
# Epoch 634/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9917 - f1_m: 0.8587 - precision_m: 0.8745 - recall_m: 0.8525 - dice_coef: 0.8973
# Epoch 00634: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0634_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0285 - accuracy: 0.9917 - f1_m: 0.8587 - precision_m: 0.8745 - recall_m: 0.8525 - dice_coef: 0.8973 - val_loss: 0.0367 - val_accuracy: 0.9909 - val_f1_m: 0.8886 - val_precision_m: 0.9015 - val_recall_m: 0.8783 - val_dice_coef: 0.9220 - lr: 1.0000e-05
# Epoch 635/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9914 - f1_m: 0.8411 - precision_m: 0.8482 - recall_m: 0.8409 - dice_coef: 0.8971
# Epoch 00635: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0635_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0293 - accuracy: 0.9914 - f1_m: 0.8411 - precision_m: 0.8482 - recall_m: 0.8409 - dice_coef: 0.8971 - val_loss: 0.0286 - val_accuracy: 0.9924 - val_f1_m: 0.8060 - val_precision_m: 0.8229 - val_recall_m: 0.7932 - val_dice_coef: 0.9239 - lr: 1.0000e-05
# Epoch 636/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9918 - f1_m: 0.8652 - precision_m: 0.8792 - recall_m: 0.8579 - dice_coef: 0.9020
# Epoch 00636: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0636_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0275 - accuracy: 0.9918 - f1_m: 0.8652 - precision_m: 0.8792 - recall_m: 0.8579 - dice_coef: 0.9020 - val_loss: 0.0343 - val_accuracy: 0.9910 - val_f1_m: 0.8853 - val_precision_m: 0.8972 - val_recall_m: 0.8758 - val_dice_coef: 0.9072 - lr: 1.0000e-05
# Epoch 637/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9918 - f1_m: 0.8583 - precision_m: 0.8675 - recall_m: 0.8547 - dice_coef: 0.9072
# Epoch 00637: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0637_val_weights.h5
#
# Epoch 00637: ReduceLROnPlateau reducing learning rate to 3.1622775802825263e-06.
# 385/385 [==============================] - 199s 517ms/step - loss: 0.0271 - accuracy: 0.9918 - f1_m: 0.8583 - precision_m: 0.8675 - recall_m: 0.8547 - dice_coef: 0.9072 - val_loss: 0.0291 - val_accuracy: 0.9923 - val_f1_m: 0.9129 - val_precision_m: 0.9349 - val_recall_m: 0.8978 - val_dice_coef: 0.9259 - lr: 1.0000e-05
# Epoch 638/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9913 - f1_m: 0.8572 - precision_m: 0.8665 - recall_m: 0.8529 - dice_coef: 0.8956
# Epoch 00638: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0638_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0293 - accuracy: 0.9913 - f1_m: 0.8572 - precision_m: 0.8665 - recall_m: 0.8529 - dice_coef: 0.8956 - val_loss: 0.0360 - val_accuracy: 0.9912 - val_f1_m: 0.8681 - val_precision_m: 0.8910 - val_recall_m: 0.8517 - val_dice_coef: 0.9213 - lr: 3.1623e-06
# Epoch 639/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9917 - f1_m: 0.8460 - precision_m: 0.8544 - recall_m: 0.8421 - dice_coef: 0.8929
# Epoch 00639: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0639_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0275 - accuracy: 0.9917 - f1_m: 0.8460 - precision_m: 0.8544 - recall_m: 0.8421 - dice_coef: 0.8929 - val_loss: 0.0313 - val_accuracy: 0.9917 - val_f1_m: 0.8702 - val_precision_m: 0.8729 - val_recall_m: 0.8695 - val_dice_coef: 0.9140 - lr: 3.1623e-06
# Epoch 640/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9918 - f1_m: 0.8610 - precision_m: 0.8675 - recall_m: 0.8583 - dice_coef: 0.9099
# Epoch 00640: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0640_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0274 - accuracy: 0.9918 - f1_m: 0.8610 - precision_m: 0.8675 - recall_m: 0.8583 - dice_coef: 0.9099 - val_loss: 0.0368 - val_accuracy: 0.9904 - val_f1_m: 0.9054 - val_precision_m: 0.9111 - val_recall_m: 0.9033 - val_dice_coef: 0.9370 - lr: 3.1623e-06
# Epoch 641/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9914 - f1_m: 0.8478 - precision_m: 0.8597 - recall_m: 0.8431 - dice_coef: 0.8852
# Epoch 00641: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0641_val_weights.h5
# 385/385 [==============================] - 198s 514ms/step - loss: 0.0285 - accuracy: 0.9914 - f1_m: 0.8478 - precision_m: 0.8597 - recall_m: 0.8431 - dice_coef: 0.8852 - val_loss: 0.0317 - val_accuracy: 0.9917 - val_f1_m: 0.9204 - val_precision_m: 0.9306 - val_recall_m: 0.9125 - val_dice_coef: 0.9330 - lr: 3.1623e-06
# Epoch 642/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9915 - f1_m: 0.8495 - precision_m: 0.8577 - recall_m: 0.8457 - dice_coef: 0.8989
# Epoch 00642: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0642_val_weights.h5
# 385/385 [==============================] - 197s 513ms/step - loss: 0.0285 - accuracy: 0.9915 - f1_m: 0.8495 - precision_m: 0.8577 - recall_m: 0.8457 - dice_coef: 0.8989 - val_loss: 0.0402 - val_accuracy: 0.9896 - val_f1_m: 0.8741 - val_precision_m: 0.8870 - val_recall_m: 0.8640 - val_dice_coef: 0.9273 - lr: 3.1623e-06
# Epoch 643/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9914 - f1_m: 0.8335 - precision_m: 0.8512 - recall_m: 0.8296 - dice_coef: 0.8910
# Epoch 00643: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0643_val_weights.h5
# 385/385 [==============================] - 198s 513ms/step - loss: 0.0290 - accuracy: 0.9914 - f1_m: 0.8335 - precision_m: 0.8512 - recall_m: 0.8296 - dice_coef: 0.8910 - val_loss: 0.0406 - val_accuracy: 0.9902 - val_f1_m: 0.8115 - val_precision_m: 0.8343 - val_recall_m: 0.7964 - val_dice_coef: 0.9058 - lr: 3.1623e-06
# Epoch 644/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9913 - f1_m: 0.8581 - precision_m: 0.8650 - recall_m: 0.8572 - dice_coef: 0.9008
# Epoch 00644: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0644_val_weights.h5
# 385/385 [==============================] - 198s 513ms/step - loss: 0.0288 - accuracy: 0.9913 - f1_m: 0.8581 - precision_m: 0.8650 - recall_m: 0.8572 - dice_coef: 0.9008 - val_loss: 0.0354 - val_accuracy: 0.9911 - val_f1_m: 0.9116 - val_precision_m: 0.9279 - val_recall_m: 0.8985 - val_dice_coef: 0.9251 - lr: 3.1623e-06
# Epoch 645/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9911 - f1_m: 0.8546 - precision_m: 0.8598 - recall_m: 0.8541 - dice_coef: 0.8993
# Epoch 00645: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0645_val_weights.h5
# 385/385 [==============================] - 200s 518ms/step - loss: 0.0292 - accuracy: 0.9911 - f1_m: 0.8546 - precision_m: 0.8598 - recall_m: 0.8541 - dice_coef: 0.8993 - val_loss: 0.0275 - val_accuracy: 0.9927 - val_f1_m: 0.9087 - val_precision_m: 0.9200 - val_recall_m: 0.8999 - val_dice_coef: 0.9406 - lr: 3.1623e-06
# Epoch 646/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9920 - f1_m: 0.8694 - precision_m: 0.8832 - recall_m: 0.8613 - dice_coef: 0.9071
# Epoch 00646: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0646_val_weights.h5
# 385/385 [==============================] - 198s 515ms/step - loss: 0.0266 - accuracy: 0.9920 - f1_m: 0.8694 - precision_m: 0.8832 - recall_m: 0.8613 - dice_coef: 0.9071 - val_loss: 0.0358 - val_accuracy: 0.9912 - val_f1_m: 0.8116 - val_precision_m: 0.8229 - val_recall_m: 0.8020 - val_dice_coef: 0.9282 - lr: 3.1623e-06
# Epoch 647/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9911 - f1_m: 0.8493 - precision_m: 0.8559 - recall_m: 0.8468 - dice_coef: 0.9051
# Epoch 00647: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0647_val_weights.h5
# 385/385 [==============================] - 200s 519ms/step - loss: 0.0298 - accuracy: 0.9911 - f1_m: 0.8493 - precision_m: 0.8559 - recall_m: 0.8468 - dice_coef: 0.9051 - val_loss: 0.0263 - val_accuracy: 0.9931 - val_f1_m: 0.8706 - val_precision_m: 0.8917 - val_recall_m: 0.8597 - val_dice_coef: 0.9227 - lr: 3.1623e-06
# Epoch 648/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9924 - f1_m: 0.8640 - precision_m: 0.8733 - recall_m: 0.8588 - dice_coef: 0.9074
# Epoch 00648: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0648_val_weights.h5
# 385/385 [==============================] - 201s 522ms/step - loss: 0.0253 - accuracy: 0.9924 - f1_m: 0.8640 - precision_m: 0.8733 - recall_m: 0.8588 - dice_coef: 0.9074 - val_loss: 0.0373 - val_accuracy: 0.9899 - val_f1_m: 0.8523 - val_precision_m: 0.8654 - val_recall_m: 0.8456 - val_dice_coef: 0.9233 - lr: 3.1623e-06
# Epoch 649/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9920 - f1_m: 0.8549 - precision_m: 0.8698 - recall_m: 0.8490 - dice_coef: 0.9022
# Epoch 00649: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0649_val_weights.h5
# 385/385 [==============================] - 204s 529ms/step - loss: 0.0265 - accuracy: 0.9920 - f1_m: 0.8549 - precision_m: 0.8698 - recall_m: 0.8490 - dice_coef: 0.9022 - val_loss: 0.0336 - val_accuracy: 0.9915 - val_f1_m: 0.8689 - val_precision_m: 0.8933 - val_recall_m: 0.8503 - val_dice_coef: 0.9226 - lr: 3.1623e-06
# Epoch 650/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9911 - f1_m: 0.8563 - precision_m: 0.8639 - recall_m: 0.8527 - dice_coef: 0.8999
# Epoch 00650: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0650_val_weights.h5
# 385/385 [==============================] - 200s 519ms/step - loss: 0.0297 - accuracy: 0.9911 - f1_m: 0.8563 - precision_m: 0.8639 - recall_m: 0.8527 - dice_coef: 0.8999 - val_loss: 0.0325 - val_accuracy: 0.9917 - val_f1_m: 0.8586 - val_precision_m: 0.8820 - val_recall_m: 0.8415 - val_dice_coef: 0.9303 - lr: 3.1623e-06
# Epoch 651/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9919 - f1_m: 0.8624 - precision_m: 0.8708 - recall_m: 0.8580 - dice_coef: 0.9040
# Epoch 00651: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0651_val_weights.h5
# 385/385 [==============================] - 200s 518ms/step - loss: 0.0263 - accuracy: 0.9919 - f1_m: 0.8624 - precision_m: 0.8708 - recall_m: 0.8580 - dice_coef: 0.9040 - val_loss: 0.0422 - val_accuracy: 0.9898 - val_f1_m: 0.8793 - val_precision_m: 0.9023 - val_recall_m: 0.8618 - val_dice_coef: 0.9133 - lr: 3.1623e-06
# Epoch 652/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9919 - f1_m: 0.8655 - precision_m: 0.8741 - recall_m: 0.8625 - dice_coef: 0.9099
# Epoch 00652: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0652_val_weights.h5
# 385/385 [==============================] - 202s 525ms/step - loss: 0.0265 - accuracy: 0.9919 - f1_m: 0.8655 - precision_m: 0.8741 - recall_m: 0.8625 - dice_coef: 0.9099 - val_loss: 0.0437 - val_accuracy: 0.9891 - val_f1_m: 0.8513 - val_precision_m: 0.8624 - val_recall_m: 0.8431 - val_dice_coef: 0.9245 - lr: 3.1623e-06
# Epoch 653/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9917 - f1_m: 0.8536 - precision_m: 0.8648 - recall_m: 0.8502 - dice_coef: 0.8952
# Epoch 00653: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0653_val_weights.h5
# 385/385 [==============================] - 202s 525ms/step - loss: 0.0273 - accuracy: 0.9917 - f1_m: 0.8536 - precision_m: 0.8648 - recall_m: 0.8502 - dice_coef: 0.8952 - val_loss: 0.0348 - val_accuracy: 0.9911 - val_f1_m: 0.8557 - val_precision_m: 0.8750 - val_recall_m: 0.8438 - val_dice_coef: 0.9268 - lr: 3.1623e-06
# Epoch 654/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9911 - f1_m: 0.8698 - precision_m: 0.8778 - recall_m: 0.8661 - dice_coef: 0.9004
# Epoch 00654: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0654_val_weights.h5
# 385/385 [==============================] - 201s 523ms/step - loss: 0.0291 - accuracy: 0.9911 - f1_m: 0.8698 - precision_m: 0.8778 - recall_m: 0.8661 - dice_coef: 0.9004 - val_loss: 0.0353 - val_accuracy: 0.9909 - val_f1_m: 0.8672 - val_precision_m: 0.8989 - val_recall_m: 0.8522 - val_dice_coef: 0.9260 - lr: 3.1623e-06
# Epoch 655/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9912 - f1_m: 0.8559 - precision_m: 0.8649 - recall_m: 0.8531 - dice_coef: 0.8958
# Epoch 00655: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0655_val_weights.h5
# 385/385 [==============================] - 201s 523ms/step - loss: 0.0297 - accuracy: 0.9912 - f1_m: 0.8559 - precision_m: 0.8649 - recall_m: 0.8531 - dice_coef: 0.8958 - val_loss: 0.0329 - val_accuracy: 0.9915 - val_f1_m: 0.8060 - val_precision_m: 0.8334 - val_recall_m: 0.7862 - val_dice_coef: 0.9193 - lr: 3.1623e-06
# Epoch 656/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9912 - f1_m: 0.8563 - precision_m: 0.8686 - recall_m: 0.8491 - dice_coef: 0.8972
# Epoch 00656: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0656_val_weights.h5
# 385/385 [==============================] - 207s 537ms/step - loss: 0.0298 - accuracy: 0.9912 - f1_m: 0.8563 - precision_m: 0.8686 - recall_m: 0.8491 - dice_coef: 0.8972 - val_loss: 0.0326 - val_accuracy: 0.9916 - val_f1_m: 0.8658 - val_precision_m: 0.8775 - val_recall_m: 0.8561 - val_dice_coef: 0.9376 - lr: 3.1623e-06
# Epoch 657/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9917 - f1_m: 0.8318 - precision_m: 0.8414 - recall_m: 0.8270 - dice_coef: 0.8853
# Epoch 00657: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0657_val_weights.h5
# 385/385 [==============================] - 204s 530ms/step - loss: 0.0291 - accuracy: 0.9917 - f1_m: 0.8318 - precision_m: 0.8414 - recall_m: 0.8270 - dice_coef: 0.8853 - val_loss: 0.0378 - val_accuracy: 0.9901 - val_f1_m: 0.9197 - val_precision_m: 0.9353 - val_recall_m: 0.9079 - val_dice_coef: 0.9319 - lr: 3.1623e-06
# Epoch 658/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9911 - f1_m: 0.8631 - precision_m: 0.8695 - recall_m: 0.8612 - dice_coef: 0.9127
# Epoch 00658: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0658_val_weights.h5
# 385/385 [==============================] - 205s 533ms/step - loss: 0.0297 - accuracy: 0.9911 - f1_m: 0.8631 - precision_m: 0.8695 - recall_m: 0.8612 - dice_coef: 0.9127 - val_loss: 0.0437 - val_accuracy: 0.9890 - val_f1_m: 0.9071 - val_precision_m: 0.9243 - val_recall_m: 0.8949 - val_dice_coef: 0.9211 - lr: 3.1623e-06
# Epoch 659/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9913 - f1_m: 0.8480 - precision_m: 0.8553 - recall_m: 0.8437 - dice_coef: 0.8974
# Epoch 00659: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0659_val_weights.h5
# 385/385 [==============================] - 202s 526ms/step - loss: 0.0295 - accuracy: 0.9913 - f1_m: 0.8480 - precision_m: 0.8553 - recall_m: 0.8437 - dice_coef: 0.8974 - val_loss: 0.0300 - val_accuracy: 0.9920 - val_f1_m: 0.9110 - val_precision_m: 0.9245 - val_recall_m: 0.9001 - val_dice_coef: 0.9424 - lr: 3.1623e-06
# Epoch 660/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9915 - f1_m: 0.8742 - precision_m: 0.8858 - recall_m: 0.8675 - dice_coef: 0.9050
# Epoch 00660: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0660_val_weights.h5
# 385/385 [==============================] - 204s 531ms/step - loss: 0.0286 - accuracy: 0.9915 - f1_m: 0.8742 - precision_m: 0.8858 - recall_m: 0.8675 - dice_coef: 0.9050 - val_loss: 0.0295 - val_accuracy: 0.9925 - val_f1_m: 0.8887 - val_precision_m: 0.9173 - val_recall_m: 0.8724 - val_dice_coef: 0.9012 - lr: 3.1623e-06
# Epoch 661/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9917 - f1_m: 0.8603 - precision_m: 0.8701 - recall_m: 0.8553 - dice_coef: 0.9030
# Epoch 00661: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0661_val_weights.h5
# 385/385 [==============================] - 202s 525ms/step - loss: 0.0270 - accuracy: 0.9917 - f1_m: 0.8603 - precision_m: 0.8701 - recall_m: 0.8553 - dice_coef: 0.9030 - val_loss: 0.0388 - val_accuracy: 0.9902 - val_f1_m: 0.8786 - val_precision_m: 0.8904 - val_recall_m: 0.8692 - val_dice_coef: 0.9169 - lr: 3.1623e-06
# Epoch 662/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9912 - f1_m: 0.8636 - precision_m: 0.8727 - recall_m: 0.8615 - dice_coef: 0.9002
# Epoch 00662: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0662_val_weights.h5
# 385/385 [==============================] - 204s 531ms/step - loss: 0.0291 - accuracy: 0.9912 - f1_m: 0.8636 - precision_m: 0.8727 - recall_m: 0.8615 - dice_coef: 0.9002 - val_loss: 0.0350 - val_accuracy: 0.9909 - val_f1_m: 0.8590 - val_precision_m: 0.8730 - val_recall_m: 0.8473 - val_dice_coef: 0.9311 - lr: 3.1623e-06
# Epoch 663/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9916 - f1_m: 0.8595 - precision_m: 0.8754 - recall_m: 0.8501 - dice_coef: 0.8922
# Epoch 00663: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0663_val_weights.h5
# 385/385 [==============================] - 205s 533ms/step - loss: 0.0279 - accuracy: 0.9916 - f1_m: 0.8595 - precision_m: 0.8754 - recall_m: 0.8501 - dice_coef: 0.8922 - val_loss: 0.0402 - val_accuracy: 0.9897 - val_f1_m: 0.8893 - val_precision_m: 0.9037 - val_recall_m: 0.8797 - val_dice_coef: 0.9224 - lr: 3.1623e-06
# Epoch 664/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9910 - f1_m: 0.8574 - precision_m: 0.8663 - recall_m: 0.8547 - dice_coef: 0.9054
# Epoch 00664: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0664_val_weights.h5
# 385/385 [==============================] - 203s 527ms/step - loss: 0.0306 - accuracy: 0.9910 - f1_m: 0.8574 - precision_m: 0.8663 - recall_m: 0.8547 - dice_coef: 0.9054 - val_loss: 0.0267 - val_accuracy: 0.9929 - val_f1_m: 0.8587 - val_precision_m: 0.8776 - val_recall_m: 0.8448 - val_dice_coef: 0.9167 - lr: 3.1623e-06
# Epoch 665/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9914 - f1_m: 0.8622 - precision_m: 0.8702 - recall_m: 0.8579 - dice_coef: 0.9060
# Epoch 00665: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0665_val_weights.h5
# 385/385 [==============================] - 201s 523ms/step - loss: 0.0285 - accuracy: 0.9914 - f1_m: 0.8622 - precision_m: 0.8702 - recall_m: 0.8579 - dice_coef: 0.9060 - val_loss: 0.0397 - val_accuracy: 0.9895 - val_f1_m: 0.8854 - val_precision_m: 0.8973 - val_recall_m: 0.8801 - val_dice_coef: 0.9190 - lr: 3.1623e-06
# Epoch 666/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9918 - f1_m: 0.8525 - precision_m: 0.8628 - recall_m: 0.8474 - dice_coef: 0.8912
# Epoch 00666: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0666_val_weights.h5
# 385/385 [==============================] - 204s 530ms/step - loss: 0.0275 - accuracy: 0.9918 - f1_m: 0.8525 - precision_m: 0.8628 - recall_m: 0.8474 - dice_coef: 0.8912 - val_loss: 0.0375 - val_accuracy: 0.9906 - val_f1_m: 0.8682 - val_precision_m: 0.8899 - val_recall_m: 0.8508 - val_dice_coef: 0.9209 - lr: 3.1623e-06
# Epoch 667/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9913 - f1_m: 0.8495 - precision_m: 0.8642 - recall_m: 0.8432 - dice_coef: 0.8944
# Epoch 00667: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0667_val_weights.h5
#
# Epoch 00667: ReduceLROnPlateau reducing learning rate to 9.99999983430526e-07.
# 385/385 [==============================] - 202s 524ms/step - loss: 0.0287 - accuracy: 0.9913 - f1_m: 0.8495 - precision_m: 0.8642 - recall_m: 0.8432 - dice_coef: 0.8944 - val_loss: 0.0271 - val_accuracy: 0.9926 - val_f1_m: 0.8981 - val_precision_m: 0.9156 - val_recall_m: 0.8852 - val_dice_coef: 0.9305 - lr: 3.1623e-06
# Epoch 668/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9914 - f1_m: 0.8688 - precision_m: 0.8760 - recall_m: 0.8658 - dice_coef: 0.9054
# Epoch 00668: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0668_val_weights.h5
# 385/385 [==============================] - 206s 535ms/step - loss: 0.0282 - accuracy: 0.9914 - f1_m: 0.8688 - precision_m: 0.8760 - recall_m: 0.8658 - dice_coef: 0.9054 - val_loss: 0.0264 - val_accuracy: 0.9934 - val_f1_m: 0.8230 - val_precision_m: 0.8423 - val_recall_m: 0.8098 - val_dice_coef: 0.9330 - lr: 1.0000e-06
# Epoch 669/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9916 - f1_m: 0.8607 - precision_m: 0.8685 - recall_m: 0.8562 - dice_coef: 0.9023
# Epoch 00669: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0669_val_weights.h5
# 385/385 [==============================] - 207s 539ms/step - loss: 0.0280 - accuracy: 0.9916 - f1_m: 0.8607 - precision_m: 0.8685 - recall_m: 0.8562 - dice_coef: 0.9023 - val_loss: 0.0313 - val_accuracy: 0.9918 - val_f1_m: 0.8625 - val_precision_m: 0.8930 - val_recall_m: 0.8535 - val_dice_coef: 0.9062 - lr: 1.0000e-06
# Epoch 670/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9917 - f1_m: 0.8561 - precision_m: 0.8664 - recall_m: 0.8500 - dice_coef: 0.9050
# Epoch 00670: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0670_val_weights.h5
# 385/385 [==============================] - 204s 529ms/step - loss: 0.0266 - accuracy: 0.9917 - f1_m: 0.8561 - precision_m: 0.8664 - recall_m: 0.8500 - dice_coef: 0.9050 - val_loss: 0.0316 - val_accuracy: 0.9914 - val_f1_m: 0.8367 - val_precision_m: 0.8560 - val_recall_m: 0.8253 - val_dice_coef: 0.9132 - lr: 1.0000e-06
# Epoch 671/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9919 - f1_m: 0.8505 - precision_m: 0.8621 - recall_m: 0.8426 - dice_coef: 0.9009
# Epoch 00671: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0671_val_weights.h5
# 385/385 [==============================] - 202s 524ms/step - loss: 0.0266 - accuracy: 0.9919 - f1_m: 0.8505 - precision_m: 0.8621 - recall_m: 0.8426 - dice_coef: 0.9009 - val_loss: 0.0343 - val_accuracy: 0.9920 - val_f1_m: 0.8506 - val_precision_m: 0.8740 - val_recall_m: 0.8328 - val_dice_coef: 0.9233 - lr: 1.0000e-06
# Epoch 672/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9922 - f1_m: 0.8535 - precision_m: 0.8650 - recall_m: 0.8456 - dice_coef: 0.8986
# Epoch 00672: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0672_val_weights.h5
# 385/385 [==============================] - 203s 527ms/step - loss: 0.0252 - accuracy: 0.9922 - f1_m: 0.8535 - precision_m: 0.8650 - recall_m: 0.8456 - dice_coef: 0.8986 - val_loss: 0.0246 - val_accuracy: 0.9939 - val_f1_m: 0.8705 - val_precision_m: 0.9029 - val_recall_m: 0.8455 - val_dice_coef: 0.9227 - lr: 1.0000e-06
# Epoch 673/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9918 - f1_m: 0.8538 - precision_m: 0.8654 - recall_m: 0.8482 - dice_coef: 0.9019
# Epoch 00673: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0673_val_weights.h5
# 385/385 [==============================] - 205s 533ms/step - loss: 0.0273 - accuracy: 0.9918 - f1_m: 0.8538 - precision_m: 0.8654 - recall_m: 0.8482 - dice_coef: 0.9019 - val_loss: 0.0299 - val_accuracy: 0.9918 - val_f1_m: 0.8652 - val_precision_m: 0.8959 - val_recall_m: 0.8488 - val_dice_coef: 0.9171 - lr: 1.0000e-06
# Epoch 674/900
# ...
# Epoch 875/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9922 - f1_m: 0.8594 - precision_m: 0.8688 - recall_m: 0.8565 - dice_coef: 0.9034
# Epoch 00875: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0875_val_weights.h5
# 385/385 [==============================] - 190s 494ms/step - loss: 0.0251 - accuracy: 0.9922 - f1_m: 0.8594 - precision_m: 0.8688 - recall_m: 0.8565 - dice_coef: 0.9034 - val_loss: 0.0279 - val_accuracy: 0.9928 - val_f1_m: 0.9016 - val_precision_m: 0.9392 - val_recall_m: 0.8746 - val_dice_coef: 0.9143 - lr: 5.0000e-08
# Epoch 876/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9915 - f1_m: 0.8528 - precision_m: 0.8648 - recall_m: 0.8457 - dice_coef: 0.8945
# Epoch 00876: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0876_val_weights.h5
# 385/385 [==============================] - 190s 494ms/step - loss: 0.0283 - accuracy: 0.9915 - f1_m: 0.8528 - precision_m: 0.8648 - recall_m: 0.8457 - dice_coef: 0.8945 - val_loss: 0.0286 - val_accuracy: 0.9925 - val_f1_m: 0.8679 - val_precision_m: 0.8999 - val_recall_m: 0.8467 - val_dice_coef: 0.9204 - lr: 5.0000e-08
# Epoch 877/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9915 - f1_m: 0.8528 - precision_m: 0.8641 - recall_m: 0.8466 - dice_coef: 0.9027
# Epoch 00877: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0877_val_weights.h5
# 385/385 [==============================] - 190s 494ms/step - loss: 0.0280 - accuracy: 0.9915 - f1_m: 0.8528 - precision_m: 0.8641 - recall_m: 0.8466 - dice_coef: 0.9027 - val_loss: 0.0363 - val_accuracy: 0.9908 - val_f1_m: 0.8921 - val_precision_m: 0.9053 - val_recall_m: 0.8810 - val_dice_coef: 0.9255 - lr: 5.0000e-08
# Epoch 878/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9916 - f1_m: 0.8471 - precision_m: 0.8577 - recall_m: 0.8428 - dice_coef: 0.9002
# Epoch 00878: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0878_val_weights.h5
# 385/385 [==============================] - 190s 494ms/step - loss: 0.0282 - accuracy: 0.9916 - f1_m: 0.8471 - precision_m: 0.8577 - recall_m: 0.8428 - dice_coef: 0.9002 - val_loss: 0.0326 - val_accuracy: 0.9921 - val_f1_m: 0.8441 - val_precision_m: 0.8931 - val_recall_m: 0.8135 - val_dice_coef: 0.8976 - lr: 5.0000e-08
# Epoch 879/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9918 - f1_m: 0.8434 - precision_m: 0.8534 - recall_m: 0.8387 - dice_coef: 0.8948
# Epoch 00879: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0879_val_weights.h5
# 385/385 [==============================] - 190s 495ms/step - loss: 0.0271 - accuracy: 0.9918 - f1_m: 0.8434 - precision_m: 0.8534 - recall_m: 0.8387 - dice_coef: 0.8948 - val_loss: 0.0328 - val_accuracy: 0.9917 - val_f1_m: 0.8691 - val_precision_m: 0.8883 - val_recall_m: 0.8548 - val_dice_coef: 0.9223 - lr: 5.0000e-08
# Epoch 880/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9915 - f1_m: 0.8481 - precision_m: 0.8589 - recall_m: 0.8422 - dice_coef: 0.8957
# Epoch 00880: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0880_val_weights.h5
# 385/385 [==============================] - 190s 495ms/step - loss: 0.0279 - accuracy: 0.9915 - f1_m: 0.8481 - precision_m: 0.8589 - recall_m: 0.8422 - dice_coef: 0.8957 - val_loss: 0.0348 - val_accuracy: 0.9911 - val_f1_m: 0.8727 - val_precision_m: 0.8953 - val_recall_m: 0.8562 - val_dice_coef: 0.9121 - lr: 5.0000e-08
# Epoch 881/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9913 - f1_m: 0.8516 - precision_m: 0.8632 - recall_m: 0.8455 - dice_coef: 0.8874
# Epoch 00881: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0881_val_weights.h5
# 385/385 [==============================] - 190s 494ms/step - loss: 0.0291 - accuracy: 0.9913 - f1_m: 0.8516 - precision_m: 0.8632 - recall_m: 0.8455 - dice_coef: 0.8874 - val_loss: 0.0350 - val_accuracy: 0.9902 - val_f1_m: 0.8989 - val_precision_m: 0.9070 - val_recall_m: 0.8936 - val_dice_coef: 0.9322 - lr: 5.0000e-08
# Epoch 882/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9912 - f1_m: 0.8481 - precision_m: 0.8581 - recall_m: 0.8422 - dice_coef: 0.9060
# Epoch 00882: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0882_val_weights.h5
# 385/385 [==============================] - 190s 495ms/step - loss: 0.0286 - accuracy: 0.9912 - f1_m: 0.8481 - precision_m: 0.8581 - recall_m: 0.8422 - dice_coef: 0.9060 - val_loss: 0.0353 - val_accuracy: 0.9911 - val_f1_m: 0.8527 - val_precision_m: 0.8671 - val_recall_m: 0.8413 - val_dice_coef: 0.9257 - lr: 5.0000e-08
# Epoch 883/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9921 - f1_m: 0.8495 - precision_m: 0.8637 - recall_m: 0.8409 - dice_coef: 0.9004
# Epoch 00883: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0883_val_weights.h5
# 385/385 [==============================] - 190s 494ms/step - loss: 0.0255 - accuracy: 0.9921 - f1_m: 0.8495 - precision_m: 0.8637 - recall_m: 0.8409 - dice_coef: 0.9004 - val_loss: 0.0326 - val_accuracy: 0.9917 - val_f1_m: 0.8558 - val_precision_m: 0.8816 - val_recall_m: 0.8352 - val_dice_coef: 0.8957 - lr: 5.0000e-08
# Epoch 884/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9920 - f1_m: 0.8452 - precision_m: 0.8659 - recall_m: 0.8340 - dice_coef: 0.8921
# Epoch 00884: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0884_val_weights.h5
# 385/385 [==============================] - 191s 496ms/step - loss: 0.0267 - accuracy: 0.9920 - f1_m: 0.8452 - precision_m: 0.8659 - recall_m: 0.8340 - dice_coef: 0.8921 - val_loss: 0.0443 - val_accuracy: 0.9887 - val_f1_m: 0.8424 - val_precision_m: 0.8658 - val_recall_m: 0.8311 - val_dice_coef: 0.8820 - lr: 5.0000e-08
# Epoch 885/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9911 - f1_m: 0.8587 - precision_m: 0.8683 - recall_m: 0.8542 - dice_coef: 0.9029
# Epoch 00885: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0885_val_weights.h5
# 385/385 [==============================] - 191s 495ms/step - loss: 0.0295 - accuracy: 0.9911 - f1_m: 0.8587 - precision_m: 0.8683 - recall_m: 0.8542 - dice_coef: 0.9029 - val_loss: 0.0229 - val_accuracy: 0.9940 - val_f1_m: 0.9292 - val_precision_m: 0.9517 - val_recall_m: 0.9133 - val_dice_coef: 0.9399 - lr: 5.0000e-08
# Epoch 886/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9919 - f1_m: 0.8492 - precision_m: 0.8604 - recall_m: 0.8438 - dice_coef: 0.8990
# Epoch 00886: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0886_val_weights.h5
# 385/385 [==============================] - 190s 495ms/step - loss: 0.0266 - accuracy: 0.9919 - f1_m: 0.8492 - precision_m: 0.8604 - recall_m: 0.8438 - dice_coef: 0.8990 - val_loss: 0.0330 - val_accuracy: 0.9913 - val_f1_m: 0.8967 - val_precision_m: 0.9123 - val_recall_m: 0.8845 - val_dice_coef: 0.9299 - lr: 5.0000e-08
# Epoch 887/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9917 - f1_m: 0.8489 - precision_m: 0.8616 - recall_m: 0.8403 - dice_coef: 0.8967
# Epoch 00887: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0887_val_weights.h5
# 385/385 [==============================] - 190s 494ms/step - loss: 0.0276 - accuracy: 0.9917 - f1_m: 0.8489 - precision_m: 0.8616 - recall_m: 0.8403 - dice_coef: 0.8967 - val_loss: 0.0288 - val_accuracy: 0.9923 - val_f1_m: 0.8066 - val_precision_m: 0.8266 - val_recall_m: 0.7926 - val_dice_coef: 0.9210 - lr: 5.0000e-08
# Epoch 888/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9918 - f1_m: 0.8544 - precision_m: 0.8683 - recall_m: 0.8473 - dice_coef: 0.8920
# Epoch 00888: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0888_val_weights.h5
# 385/385 [==============================] - 190s 495ms/step - loss: 0.0276 - accuracy: 0.9918 - f1_m: 0.8544 - precision_m: 0.8683 - recall_m: 0.8473 - dice_coef: 0.8920 - val_loss: 0.0325 - val_accuracy: 0.9918 - val_f1_m: 0.8732 - val_precision_m: 0.8876 - val_recall_m: 0.8621 - val_dice_coef: 0.9136 - lr: 5.0000e-08
# Epoch 889/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9922 - f1_m: 0.8564 - precision_m: 0.8742 - recall_m: 0.8470 - dice_coef: 0.9107
# Epoch 00889: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0889_val_weights.h5
# 385/385 [==============================] - 191s 495ms/step - loss: 0.0256 - accuracy: 0.9922 - f1_m: 0.8564 - precision_m: 0.8742 - recall_m: 0.8470 - dice_coef: 0.9107 - val_loss: 0.0368 - val_accuracy: 0.9904 - val_f1_m: 0.8924 - val_precision_m: 0.9076 - val_recall_m: 0.8832 - val_dice_coef: 0.9252 - lr: 5.0000e-08
# Epoch 890/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9918 - f1_m: 0.8610 - precision_m: 0.8743 - recall_m: 0.8539 - dice_coef: 0.8975
# Epoch 00890: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0890_val_weights.h5
# 385/385 [==============================] - 191s 496ms/step - loss: 0.0273 - accuracy: 0.9918 - f1_m: 0.8610 - precision_m: 0.8743 - recall_m: 0.8539 - dice_coef: 0.8975 - val_loss: 0.0284 - val_accuracy: 0.9926 - val_f1_m: 0.8745 - val_precision_m: 0.8967 - val_recall_m: 0.8586 - val_dice_coef: 0.9125 - lr: 5.0000e-08
# Epoch 891/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9920 - f1_m: 0.8541 - precision_m: 0.8649 - recall_m: 0.8464 - dice_coef: 0.9046
# Epoch 00891: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0891_val_weights.h5
# 385/385 [==============================] - 191s 496ms/step - loss: 0.0267 - accuracy: 0.9920 - f1_m: 0.8541 - precision_m: 0.8649 - recall_m: 0.8464 - dice_coef: 0.9046 - val_loss: 0.0404 - val_accuracy: 0.9894 - val_f1_m: 0.9053 - val_precision_m: 0.9224 - val_recall_m: 0.8937 - val_dice_coef: 0.9196 - lr: 5.0000e-08
# Epoch 892/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9918 - f1_m: 0.8622 - precision_m: 0.8742 - recall_m: 0.8548 - dice_coef: 0.9073
# Epoch 00892: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0892_val_weights.h5
# 385/385 [==============================] - 191s 496ms/step - loss: 0.0272 - accuracy: 0.9918 - f1_m: 0.8622 - precision_m: 0.8742 - recall_m: 0.8548 - dice_coef: 0.9073 - val_loss: 0.0282 - val_accuracy: 0.9929 - val_f1_m: 0.8532 - val_precision_m: 0.8698 - val_recall_m: 0.8384 - val_dice_coef: 0.9279 - lr: 5.0000e-08
# Epoch 893/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9917 - f1_m: 0.8435 - precision_m: 0.8492 - recall_m: 0.8406 - dice_coef: 0.9042
# Epoch 00893: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0893_val_weights.h5
# 385/385 [==============================] - 191s 496ms/step - loss: 0.0277 - accuracy: 0.9917 - f1_m: 0.8435 - precision_m: 0.8492 - recall_m: 0.8406 - dice_coef: 0.9042 - val_loss: 0.0247 - val_accuracy: 0.9931 - val_f1_m: 0.8496 - val_precision_m: 0.8681 - val_recall_m: 0.8356 - val_dice_coef: 0.9418 - lr: 5.0000e-08
# Epoch 894/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9920 - f1_m: 0.8358 - precision_m: 0.8451 - recall_m: 0.8311 - dice_coef: 0.8973
# Epoch 00894: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0894_val_weights.h5
# 385/385 [==============================] - 191s 496ms/step - loss: 0.0266 - accuracy: 0.9920 - f1_m: 0.8358 - precision_m: 0.8451 - recall_m: 0.8311 - dice_coef: 0.8973 - val_loss: 0.0294 - val_accuracy: 0.9919 - val_f1_m: 0.8644 - val_precision_m: 0.8958 - val_recall_m: 0.8438 - val_dice_coef: 0.9185 - lr: 5.0000e-08
# Epoch 895/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9912 - f1_m: 0.8482 - precision_m: 0.8607 - recall_m: 0.8411 - dice_coef: 0.8974
# Epoch 00895: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0895_val_weights.h5
# 385/385 [==============================] - 191s 496ms/step - loss: 0.0290 - accuracy: 0.9912 - f1_m: 0.8482 - precision_m: 0.8607 - recall_m: 0.8411 - dice_coef: 0.8974 - val_loss: 0.0344 - val_accuracy: 0.9913 - val_f1_m: 0.8831 - val_precision_m: 0.8974 - val_recall_m: 0.8712 - val_dice_coef: 0.9203 - lr: 5.0000e-08
# Epoch 896/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9913 - f1_m: 0.8392 - precision_m: 0.8471 - recall_m: 0.8384 - dice_coef: 0.8899
# Epoch 00896: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0896_val_weights.h5
# 385/385 [==============================] - 191s 496ms/step - loss: 0.0291 - accuracy: 0.9913 - f1_m: 0.8392 - precision_m: 0.8471 - recall_m: 0.8384 - dice_coef: 0.8899 - val_loss: 0.0368 - val_accuracy: 0.9910 - val_f1_m: 0.8748 - val_precision_m: 0.8870 - val_recall_m: 0.8657 - val_dice_coef: 0.9133 - lr: 5.0000e-08
# Epoch 897/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9919 - f1_m: 0.8629 - precision_m: 0.8778 - recall_m: 0.8561 - dice_coef: 0.9069
# Epoch 00897: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0897_val_weights.h5
# 385/385 [==============================] - 191s 496ms/step - loss: 0.0259 - accuracy: 0.9919 - f1_m: 0.8629 - precision_m: 0.8778 - recall_m: 0.8561 - dice_coef: 0.9069 - val_loss: 0.0322 - val_accuracy: 0.9917 - val_f1_m: 0.8940 - val_precision_m: 0.9241 - val_recall_m: 0.8722 - val_dice_coef: 0.9264 - lr: 5.0000e-08
# Epoch 898/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9918 - f1_m: 0.8652 - precision_m: 0.8808 - recall_m: 0.8586 - dice_coef: 0.9061
# Epoch 00898: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0898_val_weights.h5
# 385/385 [==============================] - 192s 499ms/step - loss: 0.0274 - accuracy: 0.9918 - f1_m: 0.8652 - precision_m: 0.8808 - recall_m: 0.8586 - dice_coef: 0.9061 - val_loss: 0.0319 - val_accuracy: 0.9916 - val_f1_m: 0.7958 - val_precision_m: 0.8177 - val_recall_m: 0.7818 - val_dice_coef: 0.8953 - lr: 5.0000e-08
# Epoch 899/900
# 385/385 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9920 - f1_m: 0.8629 - precision_m: 0.8721 - recall_m: 0.8593 - dice_coef: 0.9068
# Epoch 00899: saving model to /home/geoai/eodata/cloud_detect_tensorflow/shadow_only/logs/weights/checkpoints_0899_val_weights.h5
# 385/385 [==============================] - 273s 710ms/step - loss: 0.0253 - accuracy: 0.9920 - f1_m: 0.8629 - precision_m: 0.8721 - recall_m: 0.8593 - dice_coef: 0.9068 - val_loss: 0.0361 - val_accuracy: 0.9904 - val_f1_m: 0.8981 - val_precision_m: 0.9026 - val_recall_m: 0.8976 - val_dice_coef: 0.9314 - lr: 5.0000e-08
# Epoch 900/900
# 358/385 [==========================>...] - ETA: 16s - loss: 0.0283 - accuracy: 0.9916 - f1_m: 0.8383 - precision_m: 0.8554 - recall_m: 0.8292 - dice_coef: 0.8894

# %%
unet.save(os.path.join(log_dir, FMT_VALMODEL_LAST_PATH.format(PREFIX)))
